# %% [markdown]
# # VERGE batch processing 1:
# Assemble geospatial entities for a ROI.
#
# Output is in the folder `gents`. Every file contains the geospatial entities for
# one sub-ROI, which is a lon/lat box of dimensions defined below.

# %% [markdown]
# ## Processing Setup

# %%
# Google colab
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# !pip install geo_encodings osmnx
# Out:
# Mounted at /content/drive
# Collecting geo_encodings
#   Downloading geo_encodings-1.0.4-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting osmnx
#   Downloading osmnx-2.0.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from geo_encodings) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from geo_encodings) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from geo_encodings) (2.0.2)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Downloading geo_encodings-1.0.4-py2.py3-none-any.whl (6.9 kB)
# Downloading osmnx-2.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 585.2 kB/s eta 0:00:00
# Installing collected packages: geo_encodings, osmnx
# Successfully installed geo_encodings-1.0.4 osmnx-2.0.6

# %%
# Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from typing import List, Tuple, Optional

import pickle
import json
import copy
import pandas as pd
import numpy as np
import pyproj
import shapely
import osmnx
import geopandas

import sys
sys.path.append('%s/03-embeddings' % project_home)
from embedderv5 import *

sys.path.append(project_home)
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# The unique identifier of the model to be used.
transformer_run_id = '301b'
collector_run_id = '301b'

# %% [markdown]
# ## Preliminaries

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
encoding_resolution = roi['encoding_resolution']

roi
# Out:
# {'name': 'newengland',
#  'lon0': -73.564321,
#  'lat0': 41.253746,
#  'lon1': -68.058533,
#  'lat1': 45.116468,
#  'proj_def': '\n+proj=tmerc +lat_0=43.185107 +lon_0=-70.81142700000001\n+k=1.0 +x_0=231000.0 +y_0=211000.0 +datum=WGS84 +units=m +no_defs\n',
#  'tile_size': 2000,
#  'tile_shift': 1000,
#  'encoding_resolution': 100}

# %%
# Re-define the ROI. The original is taking too long.
# this just includes the more urbanized part of sourhtern New England
roi['lat0'] =  41.2
roi['lon0'] = -73.4

roi['lat1'] = 43.4
roi['lon1'] = -69.7

# # even smaller:
# roi['lat1'] = 42.0
# roi['lon1'] = -72.3

# %%
# Read the file containing labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)

# Make a lookup table to get a numerical label from a text label.
label_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
label_count = len(label_lookup)
label_lookup
# Out:
# {'amenity : commercial': 0,
#  'amenity : food and drink': 1,
#  'amenity : parking lot': 2,
#  'amenity : recreation': 3,
#  'landuse : agricultural': 4,
#  'landuse : commercial': 5,
#  'landuse : forest': 6,
#  'landuse : industrial': 7,
#  'landuse : meadow': 8,
#  'landuse : recreation': 9,
#  'landuse : residential': 10,
#  'landuse : retail': 11,
#  'railway : rail': 12,
#  'railway : rail stop': 13,
#  'route : highway': 14,
#  'route : primary road': 15,
#  'route : residential road': 16,
#  'route : secondary road': 17,
#  'route : tertiary road': 18,
#  'waterway : lakes and ponds': 19,
#  'waterway : land': 20,
#  'waterway : rivers and streams': 21}

# %%
# Define a local map projection, using the definition from the ROI file.
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse

proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# Read the coastline file.
fname = '%s/coastlines' % (roi_home)
coastlines_gdf = geopandas.read_file(fname)
print('%d coastline polygons' % len(coastlines_gdf))

def get_land_water(bounds, features):

    # Create a baseline polygon consisting of the whole AOI.
    landwater = copy.deepcopy(bounds)

    # Intersect that with the coastlines data.
    coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
    landwater = landwater.intersection(coastlines)

    # subtract out any polygonal water feature.
    for _, f in features.iterrows():
        if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
            if f['natural'] == 'water':
                landwater = shapely.difference(landwater, f['geometry'])

    return landwater
# Out:
# 3514 coastline polygons

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Pull OSM data for the area around this location

# %%
import osmnx
tags = {
    'landuse': True,
    'place': True,
    'highway': True,
    'railway': True,
    #'aeroway': True,
    'bridge': True,
    'tunnel': True,
    #'power': True,
    'natural': True,
    'waterway': True,
    'landcover': True,
    #'building': True,
    'amenity': True,
    'shop': True,
    'leisure': True
}

# %%
# We need to break up the ROI into smaller chunks for querying.

dd = 0.2 # size of query boxes, in degrees
sub_rois = []

lon0 = roi['lon0']
while lon0 < roi['lon1']:
    lon1 = lon0 + dd

    lat0 = roi['lat0']
    while lat0 < roi['lat1']:
        lat1 = lat0 + dd

        query_bounds = [lon0, lat0, lon1, lat1]
        sub_rois.append(query_bounds)

        lat0 += dd

    lon0 += dd

print('will process %d sub-rois' % len(sub_rois))
# Out:
# will process 209 sub-rois

# %%
for k, sub_roi in enumerate(sub_rois):

  print('\n%d/%d' % (k+1, len(sub_rois)))

  # Check whether an output file has already been generated for this sub-roi.
  ofname = '%s/batch/gents/gents_%+.1f_%+.1f.csv' % (roi_home, sub_roi[0], sub_roi[1])
  if os.path.exists(ofname):
    print('%s already exists; skipping' % ofname)
    continue

  query_bounds = sub_roi
  print(query_bounds)
  try:
    sub_roi_features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
    print('%d features from OSM' % len(sub_roi_features))
  except:
    print('OSM query failed')
    continue

  # Just retain the relevant columns.
  columns_in_rules = set(['id', 'geometry', 'amenity', 'highway', 'landuse', 'railway', 'water', 'waterway', 'natural'])
  columns_in_features = set(sub_roi_features.columns)
  columns_to_keep = list(columns_in_rules.intersection(columns_in_features))
  sub_roi_features = sub_roi_features[columns_to_keep]

  # Down-select and re-format any relevant geospatial entities ("gents").
  sub_roi_gents = []
  for feature in sub_roi_features.to_dict('records'):

      gtype = feature['geometry'].geom_type

      for rule in rules:
          if gtype == rule['gtype']:
              osm_key = rule['osm_key']
              if osm_key in feature:
                  osm_value = str(feature[osm_key])
                  if osm_value in rule['osm_values']:
                      geomxy = shapely.ops.transform(proj_forward, feature['geometry'])
                      if geomxy.is_empty:
                          continue
                      sub_roi_gents.append({
                          'id': feature['id'],
                          'category': rule['gent_category'],
                          'label': rule['gent_label'],
                          'geom': feature['geometry'],
                          'geomxy': geomxy,
                          'gtype': gtype
                      })


  # Create a "land/water" polygon.
  try:
    lon0, lat0, lon1, lat1 = sub_roi
    lons = [lon0, lon1, lon1, lon0, lon0]
    lats = [lat0, lat0, lat1, lat1, lat0]
    lonlat_bounds = shapely.Polygon(list(zip(lons, lats)))
    landwater = get_land_water(lonlat_bounds, sub_roi_features)
    landwaterxy = shapely.ops.transform(proj_forward, landwater)
    sub_roi_gents.append({
        'id': None,
        'category': 'waterway',
        'label': 'land',
        'geom': None,
        'geomxy': landwaterxy,
        'gtype': landwaterxy.geom_type
    })
  except:
    pass

  os.makedirs(os.path.dirname(ofname), exist_ok=True)
  sub_roi_df = pd.DataFrame(sub_roi_gents)
  sub_roi_df.to_csv(ofname, index=False)
  print('%d records to %s' % (len(sub_roi_df), ofname))
# Out:
# 1/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+41.2.csv already exists; skipping
#
# 2/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+41.4.csv already exists; skipping
#
# 3/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+41.6.csv already exists; skipping
#
# 4/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+41.8.csv already exists; skipping
#
# 5/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+42.0.csv already exists; skipping
#
# 6/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+42.2.csv already exists; skipping
#
# 7/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+42.4.csv already exists; skipping
#
# 8/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+42.6.csv already exists; skipping
#
# 9/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+42.8.csv already exists; skipping
#
# 10/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+43.0.csv already exists; skipping
#
# 11/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.4_+43.2.csv already exists; skipping
#
# 12/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+41.2.csv already exists; skipping
#
# 13/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+41.4.csv already exists; skipping
#
# 14/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+41.6.csv already exists; skipping
#
# 15/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+41.8.csv already exists; skipping
#
# 16/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+42.0.csv already exists; skipping
#
# 17/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+42.2.csv already exists; skipping
#
# 18/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+42.4.csv already exists; skipping
#
# 19/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+42.6.csv already exists; skipping
#
# 20/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+42.8.csv already exists; skipping
#
# 21/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+43.0.csv already exists; skipping
#
# 22/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.2_+43.2.csv already exists; skipping
#
# 23/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+41.2.csv already exists; skipping
#
# 24/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+41.4.csv already exists; skipping
#
# 25/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+41.6.csv already exists; skipping
#
# 26/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+41.8.csv already exists; skipping
#
# 27/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+42.0.csv already exists; skipping
#
# 28/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+42.2.csv already exists; skipping
#
# 29/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+42.4.csv already exists; skipping
#
# 30/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+42.6.csv already exists; skipping
#
# 31/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+42.8.csv already exists; skipping
#
# 32/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+43.0.csv already exists; skipping
#
# 33/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-73.0_+43.2.csv already exists; skipping
#
# 34/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+41.2.csv already exists; skipping
#
# 35/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+41.4.csv already exists; skipping
#
# 36/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+41.6.csv already exists; skipping
#
# 37/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+41.8.csv already exists; skipping
#
# 38/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+42.0.csv already exists; skipping
#
# 39/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+42.2.csv already exists; skipping
#
# 40/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+42.4.csv already exists; skipping
#
# 41/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+42.6.csv already exists; skipping
#
# 42/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+42.8.csv already exists; skipping
#
# 43/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+43.0.csv already exists; skipping
#
# 44/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.8_+43.2.csv already exists; skipping
#
# 45/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+41.2.csv already exists; skipping
#
# 46/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+41.4.csv already exists; skipping
#
# 47/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+41.6.csv already exists; skipping
#
# 48/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+41.8.csv already exists; skipping
#
# 49/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+42.0.csv already exists; skipping
#
# 50/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+42.2.csv already exists; skipping
#
# 51/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+42.4.csv already exists; skipping
#
# 52/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+42.6.csv already exists; skipping
#
# 53/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+42.8.csv already exists; skipping
#
# 54/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+43.0.csv already exists; skipping
#
# 55/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.6_+43.2.csv already exists; skipping
#
# 56/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+41.2.csv already exists; skipping
#
# 57/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+41.4.csv already exists; skipping
#
# 58/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+41.6.csv already exists; skipping
#
# 59/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+41.8.csv already exists; skipping
#
# 60/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+42.0.csv already exists; skipping
#
# 61/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+42.2.csv already exists; skipping
#
# 62/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+42.4.csv already exists; skipping
#
# 63/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+42.6.csv already exists; skipping
#
# 64/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+42.8.csv already exists; skipping
#
# 65/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+43.0.csv already exists; skipping
#
# 66/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.4_+43.2.csv already exists; skipping
#
# 67/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+41.2.csv already exists; skipping
#
# 68/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+41.4.csv already exists; skipping
#
# 69/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+41.6.csv already exists; skipping
#
# 70/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+41.8.csv already exists; skipping
#
# 71/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+42.0.csv already exists; skipping
#
# 72/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+42.2.csv already exists; skipping
#
# 73/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+42.4.csv already exists; skipping
#
# 74/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+42.6.csv already exists; skipping
#
# 75/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+42.8.csv already exists; skipping
#
# 76/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+43.0.csv already exists; skipping
#
# 77/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.2_+43.2.csv already exists; skipping
#
# 78/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+41.2.csv already exists; skipping
#
# 79/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+41.4.csv already exists; skipping
#
# 80/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+41.6.csv already exists; skipping
#
# 81/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+41.8.csv already exists; skipping
#
# 82/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+42.0.csv already exists; skipping
#
# 83/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+42.2.csv already exists; skipping
#
# 84/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+42.4.csv already exists; skipping
#
# 85/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+42.6.csv already exists; skipping
#
# 86/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+42.8.csv already exists; skipping
#
# 87/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+43.0.csv already exists; skipping
#
# 88/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-72.0_+43.2.csv already exists; skipping
#
# 89/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+41.2.csv already exists; skipping
#
# 90/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+41.4.csv already exists; skipping
#
# 91/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+41.6.csv already exists; skipping
#
# 92/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+41.8.csv already exists; skipping
#
# 93/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+42.0.csv already exists; skipping
#
# 94/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+42.2.csv already exists; skipping
#
# 95/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+42.4.csv already exists; skipping
#
# 96/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+42.6.csv already exists; skipping
#
# 97/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+42.8.csv already exists; skipping
#
# 98/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+43.0.csv already exists; skipping
#
# 99/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.8_+43.2.csv already exists; skipping
#
# 100/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+41.2.csv already exists; skipping
#
# 101/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+41.4.csv already exists; skipping
#
# 102/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+41.6.csv already exists; skipping
#
# 103/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+41.8.csv already exists; skipping
#
# 104/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+42.0.csv already exists; skipping
#
# 105/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+42.2.csv already exists; skipping
#
# 106/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+42.4.csv already exists; skipping
#
# 107/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+42.6.csv already exists; skipping
#
# 108/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+42.8.csv already exists; skipping
#
# 109/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+43.0.csv already exists; skipping
#
# 110/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.6_+43.2.csv already exists; skipping
#
# 111/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+41.2.csv already exists; skipping
#
# 112/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+41.4.csv already exists; skipping
#
# 113/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+41.6.csv already exists; skipping
#
# 114/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+41.8.csv already exists; skipping
#
# 115/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+42.0.csv already exists; skipping
#
# 116/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+42.2.csv already exists; skipping
#
# 117/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+42.4.csv already exists; skipping
#
# 118/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+42.6.csv already exists; skipping
#
# 119/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+42.8.csv already exists; skipping
#
# 120/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+43.0.csv already exists; skipping
#
# 121/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.4_+43.2.csv already exists; skipping
#
# 122/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+41.2.csv already exists; skipping
#
# 123/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+41.4.csv already exists; skipping
#
# 124/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+41.6.csv already exists; skipping
#
# 125/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+41.8.csv already exists; skipping
#
# 126/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+42.0.csv already exists; skipping
#
# 127/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+42.2.csv already exists; skipping
#
# 128/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+42.4.csv already exists; skipping
#
# 129/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+42.6.csv already exists; skipping
#
# 130/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+42.8.csv already exists; skipping
#
# 131/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+43.0.csv already exists; skipping
#
# 132/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.2_+43.2.csv already exists; skipping
#
# 133/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+41.2.csv already exists; skipping
#
# 134/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+41.4.csv already exists; skipping
#
# 135/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+41.6.csv already exists; skipping
#
# 136/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+41.8.csv already exists; skipping
#
# 137/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+42.0.csv already exists; skipping
#
# 138/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+42.2.csv already exists; skipping
#
# 139/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+42.4.csv already exists; skipping
#
# 140/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+42.6.csv already exists; skipping
#
# 141/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+42.8.csv already exists; skipping
#
# 142/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+43.0.csv already exists; skipping
#
# 143/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-71.0_+43.2.csv already exists; skipping
#
# 144/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+41.2.csv already exists; skipping
#
# 145/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+41.4.csv already exists; skipping
#
# 146/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+41.6.csv already exists; skipping
#
# 147/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+41.8.csv already exists; skipping
#
# 148/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+42.0.csv already exists; skipping
#
# 149/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+42.2.csv already exists; skipping
#
# 150/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+42.4.csv already exists; skipping
#
# 151/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+42.6.csv already exists; skipping
#
# 152/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+42.8.csv already exists; skipping
#
# 153/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+43.0.csv already exists; skipping
#
# 154/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.8_+43.2.csv already exists; skipping
#
# 155/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+41.2.csv already exists; skipping
#
# 156/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+41.4.csv already exists; skipping
#
# 157/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+41.6.csv already exists; skipping
#
# 158/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+41.8.csv already exists; skipping
#
# 159/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+42.0.csv already exists; skipping
#
# 160/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+42.2.csv already exists; skipping
#
# 161/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+42.4.csv already exists; skipping
#
# 162/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+42.6.csv already exists; skipping
#
# 163/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+42.8.csv already exists; skipping
#
# 164/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+43.0.csv already exists; skipping
#
# 165/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.6_+43.2.csv already exists; skipping
#
# 166/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+41.2.csv already exists; skipping
#
# 167/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+41.4.csv already exists; skipping
#
# 168/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+41.6.csv already exists; skipping
#
# 169/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+41.8.csv already exists; skipping
#
# 170/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+42.0.csv already exists; skipping
#
# 171/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+42.2.csv already exists; skipping
#
# 172/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+42.4.csv already exists; skipping
#
# 173/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+42.6.csv already exists; skipping
#
# 174/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+42.8.csv already exists; skipping
#
# 175/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+43.0.csv already exists; skipping
#
# 176/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.4_+43.2.csv already exists; skipping
#
# 177/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+41.2.csv already exists; skipping
#
# 178/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+41.4.csv already exists; skipping
#
# 179/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+41.6.csv already exists; skipping
#
# 180/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+41.8.csv already exists; skipping
#
# 181/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+42.0.csv already exists; skipping
#
# 182/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+42.2.csv already exists; skipping
#
# 183/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+42.4.csv already exists; skipping
#
# 184/209
# /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+42.6.csv already exists; skipping
#
# 185/209
# [-70.19999999999996, 42.800000000000026, -69.99999999999996, 43.00000000000003]
# OSM query failed
#
# 186/209
# [-70.19999999999996, 43.00000000000003, -69.99999999999996, 43.20000000000003]
# 1 features from OSM
# 0 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+43.0.csv
#
# 187/209
# [-70.19999999999996, 43.20000000000003, -69.99999999999996, 43.400000000000034]
# 2 features from OSM
# 1 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.2_+43.2.csv
#
# 188/209
# [-69.99999999999996, 41.2, -69.79999999999995, 41.400000000000006]
# 1243 features from OSM
# 208 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.0_+41.2.csv
#
# 189/209
# [-69.99999999999996, 41.400000000000006, -69.79999999999995, 41.60000000000001]
# 62 features from OSM
# 1 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.0_+41.4.csv
#
# 190/209
# [-69.99999999999996, 41.60000000000001, -69.79999999999995, 41.80000000000001]
# 7072 features from OSM
# 2124 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.0_+41.6.csv
#
# 191/209
# [-69.99999999999996, 41.80000000000001, -69.79999999999995, 42.000000000000014]
# 4357 features from OSM
# 1069 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.0_+41.8.csv
#
# 192/209
# [-69.99999999999996, 42.000000000000014, -69.79999999999995, 42.20000000000002]
# 3 features from OSM
# 0 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.0_+42.0.csv
#
# 193/209
# [-69.99999999999996, 42.20000000000002, -69.79999999999995, 42.40000000000002]
# 1 features from OSM
# 0 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-70.0_+42.2.csv
#
# 194/209
# [-69.99999999999996, 42.40000000000002, -69.79999999999995, 42.60000000000002]
# OSM query failed
#
# 195/209
# [-69.99999999999996, 42.60000000000002, -69.79999999999995, 42.800000000000026]
# OSM query failed
#
# 196/209
# [-69.99999999999996, 42.800000000000026, -69.79999999999995, 43.00000000000003]
# OSM query failed
#
# 197/209
# [-69.99999999999996, 43.00000000000003, -69.79999999999995, 43.20000000000003]
# OSM query failed
#
# 198/209
# [-69.99999999999996, 43.20000000000003, -69.79999999999995, 43.400000000000034]
# OSM query failed
#
# 199/209
# [-69.79999999999995, 41.2, -69.59999999999995, 41.400000000000006]
# 1 features from OSM
# 0 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-69.8_+41.2.csv
#
# 200/209
# [-69.79999999999995, 41.400000000000006, -69.59999999999995, 41.60000000000001]
# 1 features from OSM
# 0 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-69.8_+41.4.csv
#
# 201/209
# [-69.79999999999995, 41.60000000000001, -69.59999999999995, 41.80000000000001]
# 2 features from OSM
# 1 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-69.8_+41.6.csv
#
# 202/209
# [-69.79999999999995, 41.80000000000001, -69.59999999999995, 42.000000000000014]
# 2 features from OSM
# 1 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-69.8_+41.8.csv
#
# 203/209
# [-69.79999999999995, 42.000000000000014, -69.59999999999995, 42.20000000000002]
# 1 features from OSM
# 0 records to /content/drive/MyDrive/Projects/verge/data/newengland/batch/gents/gents_-69.8_+42.0.csv
#
# 204/209
# [-69.79999999999995, 42.20000000000002, -69.59999999999995, 42.40000000000002]
# OSM query failed
#
# 205/209
# [-69.79999999999995, 42.40000000000002, -69.59999999999995, 42.60000000000002]
# OSM query failed
#
# 206/209
# [-69.79999999999995, 42.60000000000002, -69.59999999999995, 42.800000000000026]
# OSM query failed
#
# 207/209
# [-69.79999999999995, 42.800000000000026, -69.59999999999995, 43.00000000000003]
# OSM query failed
#
# 208/209
# [-69.79999999999995, 43.00000000000003, -69.59999999999995, 43.20000000000003]
# OSM query failed
#
# 209/209
# [-69.79999999999995, 43.20000000000003, -69.59999999999995, 43.400000000000034]
# OSM query failed
