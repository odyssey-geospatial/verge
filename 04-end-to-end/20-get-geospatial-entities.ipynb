# %% [markdown]
# ### VERGE processing
# # Assemble geospatial entities for a ROI
#
# We start by reading in a definition of a region of interest.
# We loop over "sub-ROIs" which are lon/lat boxes of a size specified below.
# For each one, we use `osmnx` to pull various geospatial features for that sub-ROI.
# Then we apply some filtering for entities that we are interested in, do some
# reformatting, and save the results for further analysis.
#
# Output is in the folder `gents`. Every file contains the geospatial entities for
# one sub-ROI, which is a lon/lat box of dimensions defined below.

# %% [markdown]
# ## Processing Setup

# %%
# AWS / SageMaker
import sagemaker
project_home = 's3://odyssey-geospatial/verge'

# %%
# # Google colab
# import os
# from google.colab import drive
# drive.mount('/content/drive')
# project_home = '/content/drive/MyDrive/Projects/verge'
# os.chdir(project_home)
# !pip install geo_encodings osmnx

# %%
# Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook Setup

# %%
import os
import sys

import pandas as pd
import numpy as np
import pyproj
import boto3
import json
import s3fs

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# from torch.utils.data import DataLoader, Dataset
# from typing import List, Tuple, Optional

# import pickle
# import json
import copy
# import pandas as pd
# import numpy as np
import shapely
import osmnx
import geopandas

# import sys
# sys.path.append('%s/03-embeddings' % project_home)
# from embedderv5 import *

sys.path.append('..')
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'ne-test'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# # The unique identifier of the model to be used.
# transformer_run_id = '301b'
# collector_run_id = '301b'

# %% [markdown]
# ## Preliminaries

# %%
role = sagemaker.get_execution_role()
print(role)
# Out:
# arn:aws:iam::445567107167:role/service-role/AmazonSageMaker-ExecutionRole-20250825T121753

# %%
# Read the ROI definition

# Initialize S3 client
s3 = boto3.client('s3')

# Read the JSON file that defines the region of interest.
bucket_name = 'odyssey-geospatial'
file_key = 'verge/data/newengland/roi.json'

response = s3.get_object(Bucket=bucket_name, Key=file_key)
roi = json.loads(response['Body'].read().decode('utf-8'))
print(json.dumps(roi, indent=2))
# Out:
# {
#   "name": "newengland",
#   "lon0": -73.564321,
#   "lat0": 41.253746,
#   "lon1": -68.058533,
#   "lat1": 45.116468,
#   "proj_def": "\n+proj=tmerc +lat_0=43.185107 +lon_0=-70.81142700000001\n+k=1.0 +x_0=231000.0 +y_0=211000.0 +datum=WGS84 +units=m +no_defs\n",
#   "tile_size": 2000,
#   "tile_shift": 1000,
#   "encoding_resolution": 100
# }

# %%
# Read the file containing labels for different type of geospatial entities
# that we are interested in.

fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)

# Make a lookup table to get a numerical label from a text label.
label_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
label_count = len(label_lookup)
label_lookup
# Out:
# {'amenity : commercial': 0,
#  'amenity : food and drink': 1,
#  'amenity : parking lot': 2,
#  'amenity : recreation': 3,
#  'landuse : agricultural': 4,
#  'landuse : commercial': 5,
#  'landuse : forest': 6,
#  'landuse : industrial': 7,
#  'landuse : meadow': 8,
#  'landuse : recreation': 9,
#  'landuse : residential': 10,
#  'landuse : retail': 11,
#  'railway : rail': 12,
#  'railway : rail stop': 13,
#  'route : highway': 14,
#  'route : primary road': 15,
#  'route : residential road': 16,
#  'route : secondary road': 17,
#  'route : tertiary road': 18,
#  'waterway : lakes and ponds': 19,
#  'waterway : land': 20,
#  'waterway : rivers and streams': 21}

# %%
# Define a local map projection, using the definition from the ROI file.
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse


proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# Read the coastline file.
fname = '%s/coastlines/coastlines.shp' % (roi_home)
print(fname)
coastlines_gdf = geopandas.read_file(fname)
print('%d coastline polygons' % len(coastlines_gdf))
# Out:
# s3://odyssey-geospatial/verge/data/ne-test/coastlines/coastlines.shp
# 3514 coastline polygons

# %%
def get_land_water(bounds, features):

    # Create a baseline polygon consisting of the whole AOI.
    landwater = copy.deepcopy(bounds)

    # Intersect that with the coastlines data.
    coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
    landwater = landwater.intersection(coastlines)

    # subtract out any polygonal water feature.
    for _, f in features.iterrows():
        if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
            if f['natural'] == 'water':
                landwater = shapely.difference(landwater, f['geometry'])

    return landwater

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Pull OSM data for the area around this location

# %%
tags = {
    'landuse': True,
    'place': True,
    'highway': True,
    'railway': True,
    'bridge': True,
    'tunnel': True,
    'natural': True,
    'waterway': True,
    'landcover': True,
    'amenity': True,
    'shop': True,
    'leisure': True
}

# %%
# We need to break up the ROI into smaller chunks for querying.

dd = 0.2  # size of query boxes, in degrees
sub_rois = []

lon0 = np.ceil(roi['lon0'] / dd) * dd
while lon0 < roi['lon1'] - dd:
    lon1 = lon0 + dd

    lat0 = np.ceil(roi['lat0'] / dd) * dd
    while lat0 < roi['lat1'] - dd:
        lat1 = lat0 + dd

        query_bounds = [lon0, lat0, lon1, lat1]
        sub_rois.append(query_bounds)

        lat0 += dd

    lon0 += dd

print('will process %d sub-rois' % len(sub_rois))
# Out:
# will process 468 sub-rois

# %%
# This function does the processing for one sub-ROI. Below we
# will run this in parallel.

def process_sub_roi(sub_roi):

    # Check whether an output file has already been generated for this sub-roi.
    ofname = '%s/gents/gents_%+.1f_%+.1f.csv' % (roi_home, sub_roi[0], sub_roi[1])
    print(ofname)
    print(sub_roi)
    fs = s3fs.S3FileSystem()
    if fs.exists(ofname):
        print('--> %s already exists; skipping' % ofname)
        return ofname

    query_bounds = sub_roi
    try:
        sub_roi_features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
        print('%d features from OSM' % len(sub_roi_features))
    except:
        print('OSM query failed')
        return "fail"

    # Just retain the relevant columns.
    columns_in_rules = set(['id', 'geometry', 'amenity', 'highway', 'landuse', 'railway', 'water', 'waterway', 'natural'])
    columns_in_features = set(sub_roi_features.columns)
    columns_to_keep = list(columns_in_rules.intersection(columns_in_features))
    sub_roi_features = sub_roi_features[columns_to_keep]

    # Down-select and re-format any relevant geospatial entities ("gents").
    sub_roi_gents = []
    for feature in sub_roi_features.to_dict('records'):

        gtype = feature['geometry'].geom_type

        for rule in rules:
            if gtype == rule['gtype']:
                osm_key = rule['osm_key']
                if osm_key in feature:
                    osm_value = str(feature[osm_key])
                    if osm_value in rule['osm_values']:
                        geomxy = shapely.ops.transform(proj_forward, feature['geometry'])
                        if geomxy.is_empty:
                            continue
                        sub_roi_gents.append({
                            'id': feature['id'],
                            'category': rule['gent_category'],
                            'label': rule['gent_label'],
                            'geom': feature['geometry'],
                            'geomxy': geomxy,
                            'gtype': gtype
                        })

    # Create a "land/water" polygon.
    try:
        lon0, lat0, lon1, lat1 = sub_roi
        lons = [lon0, lon1, lon1, lon0, lon0]
        lats = [lat0, lat0, lat1, lat1, lat0]
        lonlat_bounds = shapely.Polygon(list(zip(lons, lats)))
        landwater = get_land_water(lonlat_bounds, sub_roi_features)
        landwaterxy = shapely.ops.transform(proj_forward, landwater)
        sub_roi_gents.append({
          'id': None,
          'category': 'waterway',
          'label': 'land',
          'geom': None,
          'geomxy': landwaterxy,
          'gtype': landwaterxy.geom_type
        })
    except:
        pass

    os.makedirs(os.path.dirname(ofname), exist_ok=True)
    sub_roi_df = pd.DataFrame(sub_roi_gents)
    sub_roi_df.to_csv(ofname, index=False)
    print('%d records to %s' % (len(sub_roi_df), ofname))
    return ofname

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

with ThreadPoolExecutor(max_workers=3) as executor:
    futures = {
        executor.submit(process_sub_roi, sub_roi): sub_roi
        for sub_roi in sub_rois
    }

    for future in as_completed(futures):
        try:
            result = future.result()
            # print(f"==> completed: {result}")
        except Exception as e:
            print(f"Error: {e}")
# Out:
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+41.4.csv
# [-73.4, 41.400000000000006, -73.2, 41.60000000000001]
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+41.6.csv
# [-73.4, 41.60000000000001, -73.2, 41.80000000000001]
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+41.8.csv
# [-73.4, 41.80000000000001, -73.2, 42.000000000000014]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+41.4.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.0.csv
# [-73.4, 42.000000000000014, -73.2, 42.20000000000002]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+41.8.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.2.csv
# [-73.4, 42.20000000000002, -73.2, 42.40000000000002]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+41.6.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.4.csv
# [-73.4, 42.40000000000002, -73.2, 42.60000000000002]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.0.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.6.csv
# [-73.4, 42.60000000000002, -73.2, 42.800000000000026]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.2.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.8.csv
# [-73.4, 42.800000000000026, -73.2, 43.00000000000003]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.4.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+43.0.csv
# [-73.4, 43.00000000000003, -73.2, 43.20000000000003]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.6.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+43.2.csv
# [-73.4, 43.20000000000003, -73.2, 43.400000000000034]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+42.8.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+43.4.csv
# [-73.4, 43.400000000000034, -73.2, 43.60000000000004]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.4_+43

# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+43.2.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+43.8.csv
# [-73.0, 43.80000000000004, -72.8, 44.00000000000004]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+43.4.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.0.csv
# [-73.0, 44.00000000000004, -72.8, 44.200000000000045]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+43.6.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.2.csv
# [-73.0, 44.200000000000045, -72.8, 44.40000000000005]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+43.8.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.4.csv
# [-73.0, 44.40000000000005, -72.8, 44.60000000000005]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.0.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.6.csv
# [-73.0, 44.60000000000005, -72.8, 44.800000000000054]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.2.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.8.csv
# [-73.0, 44.800000000000054, -72.8, 45.00000000000006]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.4.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+41.4.csv
# [-72.8, 41.400000000000006, -72.6, 41.60000000000001]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.6.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+41.6.csv
# [-72.8, 41.60000000000001, -72.6, 41.80000000000001]
# --> s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-73.0_+44.8.csv already exists; skipping
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+41.8.csv
# [-72.8, 41.80000000000001, -72.6, 42.000000000000014]
# 32965 features from OSM
# 35515 features from OSM
# 76098 features from OSM
# 7750 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.0.csv
# [-72.8, 42.000000000000014, -72.6, 42.20000000000002]
# 7202 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.2.csv
# [-72.8, 42.20000000000002, -72.6, 42.40000000000002]
# 16344 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.4.csv
# [-72.8, 42.40000000000002, -72.6, 42.60000000000002]
# 7354 features from OSM
# 18956 features from OSM
# 28912 features from OSM
# 2244 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.6.csv
# [-72.8, 42.60000000000002, -72.6, 42.800000000000026]
# 4385 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.8.csv
# [-72.8, 42.800000000000026, -72.6, 43.00000000000003]
# 7179 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.0.csv
# [-72.8, 43.00000000000003, -72.6, 43.20000000000003]
# 2403 features from OSM
# 2814 features from OSM
# 1307 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.2.csv
# [-72.8, 43.20000000000003, -72.6, 43.400000000000034]
# 1484 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.4.csv
# [-72.8, 43.400000000000034, -72.6, 43.60000000000004]
# 4834 features from OSM
# 2105 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.6.csv
# [-72.8, 43.60000000000004, -72.6, 43.80000000000004]
# 1408 features from OSM
# 534 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.8.csv
# [-72.8, 43.80000000000004, -72.6, 44.00000000000004]
# 1619 features from OSM
# 745 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.0.csv
# [-72.8, 44.00000000000004, -72.6, 44.200000000000045]
# 3235 features from OSM
# 922 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.2.csv
# [-72.8, 44.200000000000045, -72.6, 44.40000000000005]
# 2690 features from OSM
# 1097 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.4.csv
# [-72.8, 44.40000000000005, -72.6, 44.60000000000005]
# 3753 features from OSM
# 1414 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.6.csv
# [-72.8, 44.60000000000005, -72.6, 44.800000000000054]
# 1599 features from OSM
# 494 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.8.csv
# [-72.8, 44.800000000000054, -72.6, 45.00000000000006]
# 2099 features from OSM
# 1475 features from OSM
# 768 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+41.4.csv
# [-72.6, 41.400000000000006, -72.39999999999999, 41.60000000000001]
# 498 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+41.6.csv
# [-72.6, 41.60000000000001, -72.39999999999999, 41.80000000000001]
# 14093 features from OSM
# 25861 features from OSM
# 3057 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+41.8.csv
# [-72.6, 41.80000000000001, -72.39999999999999, 42.000000000000014]
# 5793 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.0.csv
# [-72.6, 42.000000000000014, -72.39999999999999, 42.20000000000002]
# 5948 features from OSM
# 24041 features from OSM
# 2188 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.8_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.2.csv
# [-72.6, 42.20000000000002, -72.39999999999999, 42.40000000000002]
# 34037 features from OSM
# 5284 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.4.csv
# [-72.6, 42.40000000000002, -72.39999999999999, 42.60000000000002]
# 23995 features from OSM
# 10166 features from OSM
# 4803 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.6.csv
# [-72.6, 42.60000000000002, -72.39999999999999, 42.800000000000026]
# 9957 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.8.csv
# [-72.6, 42.800000000000026, -72.39999999999999, 43.00000000000003]
# 2830 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.0.csv
# [-72.6, 43.00000000000003, -72.39999999999999, 43.20000000000003]
# 7130 features from OSM
# 7785 features from OSM
# 3868 features from OSM
# 2174 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.2.csv
# [-72.6, 43.20000000000003, -72.39999999999999, 43.400000000000034]
# 1714 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.4.csv
# [-72.6, 43.400000000000034, -72.39999999999999, 43.60000000000004]
# 2181 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.6.csv
# [-72.6, 43.60000000000004, -72.39999999999999, 43.80000000000004]
# 2431 features from OSM
# 860 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.8.csv
# [-72.6, 43.80000000000004, -72.39999999999999, 44.00000000000004]
# 2241 features from OSM
# 873 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.0.csv
# [-72.6, 44.00000000000004, -72.39999999999999, 44.200000000000045]
# 5699 features from OSM
# 1544 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.2.csv
# [-72.6, 44.200000000000045, -72.39999999999999, 44.40000000000005]
# 8564 features from OSM
# 2173 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.4.csv
# [-72.6, 44.40000000000005, -72.39999999999999, 44.60000000000005]
# 2247 features from OSM
# 826 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.6.csv
# [-72.6, 44.60000000000005, -72.39999999999999, 44.800000000000054]
# 1084 features from OSM
# 481 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.8.csv
# [-72.6, 44.800000000000054, -72.39999999999999, 45.00000000000006]
# 1269 features from OSM
# 413 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+41.4.csv
# [-72.39999999999999, 41.400000000000006, -72.19999999999999, 41.60000000000001]
# 9137 features from OSM
# 3744 features from OSM
# 12231 features from OSM
# 1038 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+41.6.csv
# [-72.39999999999999, 41.60000000000001, -72.19999999999999, 41.80000000000001]
# 2010 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.6_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+41.8.csv
# [-72.39999999999999, 41.80000000000001, -72.19999999999999, 42.000000000000014]
# 2709 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.0.csv
# [-72.39999999999999, 42.000000000000014, -72.19999999999999, 42.20000000000002]
# 18079 features from OSM
# 18944 features from OSM
# 8536 features from OSM
# 2628 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.2.csv
# [-72.39999999999999, 42.20000000000002, -72.19999999999999, 42.40000000000002]
# 3726 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.4.csv
# [-72.39999999999999, 42.40000000000002, -72.19999999999999, 42.60000000000002]
# 6251 features from OSM
# 5391 features from OSM
# 3442 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.6.csv
# [-72.39999999999999, 42.60000000000002, -72.19999999999999, 42.800000000000026]
# 1637 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.8.csv
# [-72.39999999999999, 42.800000000000026, -72.19999999999999, 43.00000000000003]
# 1667 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.0.csv
# [-72.39999999999999, 43.00000000000003, -72.19999999999999, 43.20000000000003]
# 15299 features from OSM
# 2915 features from OSM
# 2925 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.2.csv
# [-72.39999999999999, 43.20000000000003, -72.19999999999999, 43.400000000000034]
# 6109 features from OSM
# 802 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.4.csv
# [-72.39999999999999, 43.400000000000034, -72.19999999999999, 43.60000000000004]
# 2733 features from OSM
# 1267 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.6.csv
# [-72.39999999999999, 43.60000000000004, -72.19999999999999, 43.80000000000004]
# 652 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.8.csv
# [-72.39999999999999, 43.80000000000004, -72.19999999999999, 44.00000000000004]
# 5507 features from OSM
# 19653 features from OSM
# 2086 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.0.csv
# [-72.39999999999999, 44.00000000000004, -72.19999999999999, 44.200000000000045]
# 3900 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.2.csv
# [-72.39999999999999, 44.200000000000045, -72.19999999999999, 44.40000000000005]
# 770 features from OSM
# 381 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.4.csv
# [-72.39999999999999, 44.40000000000005, -72.19999999999999, 44.60000000000005]
# 2012 features from OSM
# 737 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.6.csv
# [-72.39999999999999, 44.60000000000005, -72.19999999999999, 44.800000000000054]
# 3639 features from OSM
# 1151 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.8.csv
# [-72.39999999999999, 44.800000000000054, -72.19999999999999, 45.00000000000006]
# 1854 features from OSM
# 846 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+41.4.csv
# [-72.19999999999999, 41.400000000000006, -71.99999999999999, 41.60000000000001]
# 19642 features from OSM
# 1402 features from OSM
# 560 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+41.6.csv
# [-72.19999999999999, 41.60000000000001, -71.99999999999999, 41.80000000000001]
# 5256 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+41.8.csv
# [-72.19999999999999, 41.80000000000001, -71.99999999999999, 42.000000000000014]
# 5481 features from OSM
# 13287 features from OSM
# 1405 features from OSM
# 483 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.4_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.0.csv
# [-72.19999999999999, 42.000000000000014, -71.99999999999999, 42.20000000000002]
# 1498 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.2.csv
# [-72.19999999999999, 42.20000000000002, -71.99999999999999, 42.40000000000002]
# 6941 features from OSM
# 9612 features from OSM
# 3231 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.4.csv
# [-72.19999999999999, 42.40000000000002, -71.99999999999999, 42.60000000000002]
# 2463 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.6.csv
# [-72.19999999999999, 42.60000000000002, -71.99999999999999, 42.800000000000026]
# 2804 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.8.csv
# [-72.19999999999999, 42.800000000000026, -71.99999999999999, 43.00000000000003]
# 8166 features from OSM
# 5368 features from OSM
# 11349 features from OSM
# 1945 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.0.csv
# [-72.19999999999999, 43.00000000000003, -71.99999999999999, 43.20000000000003]
# 1291 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.2.csv
# [-72.19999999999999, 43.20000000000003, -71.99999999999999, 43.400000000000034]
# 2287 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.4.csv
# [-72.19999999999999, 43.400000000000034, -71.99999999999999, 43.60000000000004]
# 2662 features from OSM
# 4601 features from OSM
# 832 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.6.csv
# [-72.19999999999999, 43.60000000000004, -71.99999999999999, 43.80000000000004]
# 1096 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.8.csv
# [-72.19999999999999, 43.80000000000004, -71.99999999999999, 44.00000000000004]
# 2692 features from OSM
# 1015 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.0.csv
# [-72.19999999999999, 44.00000000000004, -71.99999999999999, 44.200000000000045]
# 1966 features from OSM
# 709 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.2.csv
# [-72.19999999999999, 44.200000000000045, -71.99999999999999, 44.40000000000005]
# 1674 features from OSM
# 803 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.4.csv
# [-72.19999999999999, 44.40000000000005, -71.99999999999999, 44.60000000000005]
# 4164 features from OSM
# 1391 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.6.csv
# [-72.19999999999999, 44.60000000000005, -71.99999999999999, 44.800000000000054]
# 1546 features from OSM
# 589 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.8.csv
# [-72.19999999999999, 44.800000000000054, -71.99999999999999, 45.00000000000006]
# 2010 features from OSM
# 762 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+41.4.csv
# [-71.99999999999999, 41.400000000000006, -71.79999999999998, 41.60000000000001]
# 8286 features from OSM
# 2647 features from OSM
# 4739 features from OSM
# 964 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+41.6.csv
# [-71.99999999999999, 41.60000000000001, -71.79999999999998, 41.80000000000001]
# 1232 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.2_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+41.8.csv
# [-71.99999999999999, 41.80000000000001, -71.79999999999998, 42.000000000000014]
# 2242 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.0.csv
# [-71.99999999999999, 42.000000000000014, -71.79999999999998, 42.20000000000002]
# 9368 features from OSM
# 12503 features from OSM
# 16533 features from OSM
# 2805 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.2.csv
# [-71.99999999999999, 42.20000000000002, -71.79999999999998, 42.40000000000002]
# 4161 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.4.csv
# [-71.99999999999999, 42.40000000000002, -71.79999999999998, 42.60000000000002]
# 34547 features from OSM
# 3328 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.6.csv
# [-71.99999999999999, 42.60000000000002, -71.79999999999998, 42.800000000000026]
# 19437 features from OSM
# 9531 features from OSM
# 6798 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.8.csv
# [-71.99999999999999, 42.800000000000026, -71.79999999999998, 43.00000000000003]
# 4011 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.0.csv
# [-71.99999999999999, 43.00000000000003, -71.79999999999998, 43.20000000000003]
# 5881 features from OSM
# 5219 features from OSM
# 2088 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.2.csv
# [-71.99999999999999, 43.20000000000003, -71.79999999999998, 43.400000000000034]
# 1271 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.4.csv
# [-71.99999999999999, 43.400000000000034, -71.79999999999998, 43.60000000000004]
# 1130 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.6.csv
# [-71.99999999999999, 43.60000000000004, -71.79999999999998, 43.80000000000004]
# 3027 features from OSM
# 3792 features from OSM
# 608 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.8.csv
# [-71.99999999999999, 43.80000000000004, -71.79999999999998, 44.00000000000004]
# 779 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.0.csv
# [-71.99999999999999, 44.00000000000004, -71.79999999999998, 44.200000000000045]
# 1569 features from OSM
# 1638 features from OSM
# 420 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.2.csv
# [-71.99999999999999, 44.200000000000045, -71.79999999999998, 44.40000000000005]
# 533 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.4.csv
# [-71.99999999999999, 44.40000000000005, -71.79999999999998, 44.60000000000005]
# 1546 features from OSM
# 3081 features from OSM
# 295 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.6.csv
# [-71.99999999999999, 44.60000000000005, -71.79999999999998, 44.800000000000054]
# 763 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.8.csv
# [-71.99999999999999, 44.800000000000054, -71.79999999999998, 45.00000000000006]
# 1308 features from OSM
# 327 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+41.4.csv
# [-71.79999999999998, 41.400000000000006, -71.59999999999998, 41.60000000000001]
# 2445 features from OSM
# 2198 features from OSM
# 796 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+41.6.csv
# [-71.79999999999998, 41.60000000000001, -71.59999999999998, 41.80000000000001]
# 590 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-72.0_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+41.8.csv
# [-71.79999999999998, 41.80000000000001, -71.59999999999998, 42.000000000000014]
# 15185 features from OSM
# 12522 features from OSM
# 14415 features from OSM
# 5714 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.0.csv
# [-71.79999999999998, 42.000000000000014, -71.59999999999998, 42.20000000000002]
# 5476 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.2.csv
# [-71.79999999999998, 42.20000000000002, -71.59999999999998, 42.40000000000002]
# 6662 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.4.csv
# [-71.79999999999998, 42.40000000000002, -71.59999999999998, 42.60000000000002]
# 30899 features from OSM
# 16134 features from OSM
# 65648 features from OSM
# 6067 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.6.csv
# [-71.79999999999998, 42.60000000000002, -71.59999999999998, 42.800000000000026]
# 3831 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.8.csv
# [-71.79999999999998, 42.800000000000026, -71.59999999999998, 43.00000000000003]
# 10666 features from OSM
# 9523 features from OSM
# 9450 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.0.csv
# [-71.79999999999998, 43.00000000000003, -71.59999999999998, 43.20000000000003]
# 7188 features from OSM
# 1970 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.2.csv
# [-71.79999999999998, 43.20000000000003, -71.59999999999998, 43.400000000000034]
# 1906 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.4.csv
# [-71.79999999999998, 43.400000000000034, -71.59999999999998, 43.60000000000004]
# 4735 features from OSM
# 4426 features from OSM
# 1346 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.6.csv
# [-71.79999999999998, 43.60000000000004, -71.59999999999998, 43.80000000000004]
# 950 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.8.csv
# [-71.79999999999998, 43.80000000000004, -71.59999999999998, 44.00000000000004]
# 4778 features from OSM
# 822 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.0.csv
# [-71.79999999999998, 44.00000000000004, -71.59999999999998, 44.200000000000045]
# 1570 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.2.csv
# [-71.79999999999998, 44.200000000000045, -71.59999999999998, 44.40000000000005]
# 2549 features from OSM
# 866 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.4.csv
# [-71.79999999999998, 44.40000000000005, -71.59999999999998, 44.60000000000005]
# 9367 features from OSM
# 1874 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.6.csv
# [-71.79999999999998, 44.60000000000005, -71.59999999999998, 44.800000000000054]
# 1098 features from OSM
# 233 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.8.csv
# [-71.79999999999998, 44.800000000000054, -71.59999999999998, 45.00000000000006]
# 1315 features from OSM
# 4180 features from OSM
# 1095 features from OSM
# 402 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+41.4.csv
# [-71.59999999999998, 41.400000000000006, -71.39999999999998, 41.60000000000001]
# 1130 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+41.6.csv
# [-71.59999999999998, 41.60000000000001, -71.39999999999998, 41.80000000000001]
# 274 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.8_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+41.8.csv
# [-71.59999999999998, 41.80000000000001, -71.39999999999998, 42.000000000000014]
# 21349 features from OSM
# 7843 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.0.csv
# [-71.59999999999998, 42.000000000000014, -71.39999999999998, 42.20000000000002]
# 27777 features from OSM
# 56053 features from OSM
# 6668 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.2.csv
# [-71.59999999999998, 42.20000000000002, -71.39999999999998, 42.40000000000002]
# 14471 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.4.csv
# [-71.59999999999998, 42.40000000000002, -71.39999999999998, 42.60000000000002]
# 32955 features from OSM
# 38353 features from OSM
# 40844 features from OSM
# 13158 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.6.csv
# [-71.59999999999998, 42.60000000000002, -71.39999999999998, 42.800000000000026]
# 6656 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.8.csv
# [-71.59999999999998, 42.800000000000026, -71.39999999999998, 43.00000000000003]
# 8198 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.0.csv
# [-71.59999999999998, 43.00000000000003, -71.39999999999998, 43.20000000000003]
# 44153 features from OSM
# 22828 features from OSM
# 37354 features from OSM
# 4772 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.2.csv
# [-71.59999999999998, 43.20000000000003, -71.39999999999998, 43.400000000000034]
# 7038 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.4.csv
# [-71.59999999999998, 43.400000000000034, -71.39999999999998, 43.60000000000004]
# 15387 features from OSM
# 7384 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.6.csv
# [-71.59999999999998, 43.60000000000004, -71.39999999999998, 43.80000000000004]
# 3055 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.8.csv
# [-71.59999999999998, 43.80000000000004, -71.39999999999998, 44.00000000000004]
# 8517 features from OSM
# 11525 features from OSM
# 2860 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.0.csv
# [-71.59999999999998, 44.00000000000004, -71.39999999999998, 44.200000000000045]
# 1887 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.2.csv
# [-71.59999999999998, 44.200000000000045, -71.39999999999998, 44.40000000000005]
# 2040 features from OSM
# 633 features from OSM
# 2928 features from OSM
# 616 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+43.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.4.csv
# [-71.59999999999998, 44.40000000000005, -71.39999999999998, 44.60000000000005]
# 241 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.6.csv
# [-71.59999999999998, 44.60000000000005, -71.39999999999998, 44.800000000000054]
# 988 features from OSM
# 654 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.8.csv
# [-71.59999999999998, 44.800000000000054, -71.39999999999998, 45.00000000000006]
# 312 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+41.4.csv
# [-71.39999999999998, 41.400000000000006, -71.19999999999997, 41.60000000000001]
# 2283 features from OSM
# 609 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+41.6.csv
# [-71.39999999999998, 41.60000000000001, -71.19999999999997, 41.80000000000001]
# 20521 features from OSM
# 6554 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+41.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+41.8.csv
# [-71.39999999999998, 41.80000000000001, -71.19999999999997, 42.000000000000014]
# 20207 features from OSM
# 3824 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+41.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.0.csv
# [-71.39999999999998, 42.000000000000014, -71.19999999999997, 42.20000000000002]
# 38370 features from OSM
# 30775 features from OSM
# 3090 features from OSM
# 9543 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+41.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.2.csv
# [-71.39999999999998, 42.20000000000002, -71.19999999999997, 42.40000000000002]
# 682 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.6_+44.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.4.csv
# [-71.39999999999998, 42.40000000000002, -71.19999999999997, 42.60000000000002]
# 7220 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.6.csv
# [-71.39999999999998, 42.60000000000002, -71.19999999999997, 42.800000000000026]
# 49667 features from OSM
# 37252 features from OSM
# 63226 features from OSM
# 8735 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.6.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.8.csv
# [-71.39999999999998, 42.800000000000026, -71.19999999999997, 43.00000000000003]
# 9806 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.0.csv
# [-71.39999999999998, 43.00000000000003, -71.19999999999997, 43.20000000000003]
# 13216 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.2.csv
# [-71.39999999999998, 43.20000000000003, -71.19999999999997, 43.400000000000034]
# 18221 features from OSM
# 7687 features from OSM
# 10505 features from OSM
# 1559 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.0.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.4.csv
# [-71.39999999999998, 43.400000000000034, -71.19999999999997, 43.60000000000004]
# 2284 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.2.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.6.csv
# [-71.39999999999998, 43.60000000000004, -71.19999999999997, 43.80000000000004]
# 5587 features from OSM
# 3585 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+42.8.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.8.csv
# [-71.39999999999998, 43.80000000000004, -71.19999999999997, 44.00000000000004]
# 5088 features from OSM
# 2292 features from OSM
# 1449 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43.4.csv
# s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+44.0.csv
# [-71.39999999999998, 44.00000000000004, -71.19999999999997, 44.200000000000045]
# 1868 features from OSM
# 711 records to s3://odyssey-geospatial/verge/data/ne-test/gents/gents_-71.4_+43