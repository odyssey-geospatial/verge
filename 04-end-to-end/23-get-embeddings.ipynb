# %% [markdown]
# # VERGE Batch Processing 2:
#
# Get the initial embeddings for a collection of tiles.

# %% [markdown]
# ## Processing Setup

# %%
# Google colab
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# !pip install geo_encodings osmnx
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: geo_encodings in /usr/local/lib/python3.12/dist-packages (1.0.4)
# Requirement already satisfied: osmnx in /usr/local/lib/python3.12/dist-packages (2.0.6)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from geo_encodings) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from geo_encodings) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from geo_encodings) (2.0.2)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->osmnx) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)

# %%
# Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from typing import List, Tuple, Optional

import pickle
import json
import copy
import pandas as pd
import numpy as np
import pyproj
import shapely
import osmnx
import geopandas

import sys
sys.path.append('%s/03-embeddings' % project_home)
from embedderv5 import *

sys.path.append(project_home)
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# The unique identifier of the model to be used.
transformer_run_id = '301b'
collector_run_id = '301b'

# %% [markdown]
# ## Preliminaries

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
encoding_resolution = roi['encoding_resolution']

roi
# Out:
# {'name': 'newengland',
#  'lon0': -73.564321,
#  'lat0': 41.253746,
#  'lon1': -68.058533,
#  'lat1': 45.116468,
#  'proj_def': '\n+proj=tmerc +lat_0=43.185107 +lon_0=-70.81142700000001\n+k=1.0 +x_0=231000.0 +y_0=211000.0 +datum=WGS84 +units=m +no_defs\n',
#  'tile_size': 2000,
#  'tile_shift': 1000,
#  'encoding_resolution': 100}

# %%
# Re-define the ROI. The original is taking too long.
# this just includes the more urbanized part os sourhtern New England
roi['lat0'] =  41.2
roi['lon0'] = -73.4

# roi['lat1'] = 43.4
# roi['lon1'] = -69.7

# even smaller:
roi['lat1'] = 42.0
roi['lon1'] = -72.3

# %%
# Read the file containing labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)

# Make a lookup table to get a numerical label from a text label.
label_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
label_count = len(label_lookup)
label_lookup
# Out:
# {'amenity : commercial': 0,
#  'amenity : food and drink': 1,
#  'amenity : parking lot': 2,
#  'amenity : recreation': 3,
#  'landuse : agricultural': 4,
#  'landuse : commercial': 5,
#  'landuse : forest': 6,
#  'landuse : industrial': 7,
#  'landuse : meadow': 8,
#  'landuse : recreation': 9,
#  'landuse : residential': 10,
#  'landuse : retail': 11,
#  'railway : rail': 12,
#  'railway : rail stop': 13,
#  'route : highway': 14,
#  'route : primary road': 15,
#  'route : residential road': 16,
#  'route : secondary road': 17,
#  'route : tertiary road': 18,
#  'waterway : lakes and ponds': 19,
#  'waterway : land': 20,
#  'waterway : rivers and streams': 21}

# %%
# Define a local map projection, using the definition from the ROI file.
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse

proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# # Read the coastline file.
# fname = '%s/coastlines' % (roi_home)
# coastlines_gdf = geopandas.read_file(fname)
# print('%d coastline polygons' % len(coastlines_gdf))

# def get_land_water(bounds, features):

#     # Create a baseline polygon consisting of the whole AOI.
#     landwater = copy.deepcopy(bounds)

#     # Intersect that with the coastlines data.
#     coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
#     landwater = landwater.intersection(coastlines)

#     # subtract out any polygonal water feature.
#     for _, f in features.iterrows():
#         if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
#             if f['natural'] == 'water':
#                 landwater = shapely.difference(landwater, f['geometry'])

#     return landwater

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Prepare the list of geospatial entities

# %%
import glob
globstring = '%s/batch/gents/*' % roi_home
fnames = glob.glob(globstring)
print('%d geospatial entity files' % len(fnames))

# Read each of the CSV files named in the list "fnames".
# Concatenate all records into one data frame named "gents",
# de-duplicating based on the "id" field.
gents_list = []
for fname in fnames:
    df = pd.read_csv(fname)
    gents_list.append(df)

gents = pd.concat(gents_list, ignore_index=True)
print(len(gents))

gents = gents.drop_duplicates(subset=['id'])
print('%d geospatial entities after de-duplication' % len(gents))

# Create a real geometry field and use it to create a spatial index.
gents['geometry'] = gents['geomxy'].apply(shapely.wkt.loads)
gents = geopandas.GeoDataFrame(gents, geometry='geometry')
gents_sindex = gents.sindex
# Out:
# 24 geospatial entity files
# 137957
# 135617 geospatial entities after de-duplication

# %% [markdown]
# ### Prepare the list of tiles

# %%
# Get a starting x,y in projected coordinates.
x0, y0 = proj_forward(roi['lon0'], roi['lat0'])
print(x0, y0)

buffer = 3000
x0 = x0 + buffer
x0 = np.ceil(x0 / roi['tile_size']) * roi['tile_size']
y0 = y0 + buffer
y0 = np.ceil(y0 / roi['tile_size']) * roi['tile_size']
print(x0, y0)

x1, y1 = proj_forward(roi['lon1'], roi['lat1'])
x1 = x1 - buffer
x1 = np.floor(x1 / roi['tile_size']) * roi['tile_size']
y1 = y1 - buffer
y1 = np.floor(y1 / roi['tile_size']) * roi['tile_size']
print(x1, y1)

tile_list = []
for x in range(int(x0), int(x1), roi['tile_size']):
    for y in range(int(y0), int(y1), roi['tile_size']):
        tile_list.append((x, y))

print('%d tiles' % len(tile_list))
# Out:
# 13859.68607151258 -6267.680346464127
# 18000.0 -2000.0
# 104000.0 76000.0
# 1677 tiles

# %%
from geo_encodings import MPPEncoder
encoder = MPPEncoder(
    region=[0, 0, roi['tile_size'], roi['tile_size']],
    resolution=roi['encoding_resolution'],
    center=True
)
geo_encoding_dim = len(encoder)
geo_encoding_dim
# Out:
# 400

# %%
# Loop over the tiles in "tile_list".
tile_encodings = []
for tile_x, tile_y in tile_list:

    print('Processing tile %d, %d' % (tile_x, tile_y))

    # Define a bounding box for this tile in projected coordinates.
    x0, y0 = tile_x, tile_y
    x1, y1 = tile_x + roi['tile_size'], tile_y + roi['tile_size']
    xx = [x0, x1, x1, x0, x0]
    yy = [y0, y0, y1, y1, y0]
    tile_bbox = shapely.Polygon(list(zip(xx, yy)))

    # Extract all geospatial entities from "gents" using "gents_sindex".
    possible_matches_index = list(gents_sindex.intersection(tile_bbox.bounds))
    possible_matches = gents.iloc[possible_matches_index]
    intersecting_gents = possible_matches[possible_matches.intersects(tile_bbox)].copy()

    # Clip any intersecting entities to the tile, and shift their coordinates to be relative to the tile lower left corner.
    tile_gents = []
    for _, gent in intersecting_gents.iterrows():
        geomxy = gent['geometry'].intersection(tile_bbox)
        if geomxy.is_empty:
            continue
        tile_gents.append({
            'category': gent['category'],
            'label': gent['label'],
            'geometry': shapely.affinity.translate(geomxy, xoff=-x0, yoff=-y0),
            'gtype': gent['gtype'],
            'xoff': x0,
            'yoff': y0,
        })

    if not tile_gents:
        continue

    # Apply MPP encoding to each.

    for gent in tile_gents:
        gent['encoding'] = encoder.encode(gent['geometry']).values()

    # Compute a one-hot label vector for each entity.
    label_count = len(label_lookup)
    for gent in tile_gents:
        label_name = '%s : %s' % (gent['category'], gent['label'])
        label_id = label_lookup[label_name]
        label_onehot = np.full(label_count, 0, dtype=float)
        label_onehot[label_id] = 1
        gent['onehot'] = label_onehot

    # Concatenate the one-hot vectors and the MPP encodings for each matrix.
    mpps = np.vstack([z['encoding'] for z in tile_gents])
    onehots = np.vstack([z['onehot'] for z in tile_gents])
    tile_encoding = np.hstack([onehots, mpps])

    tile_encodings.append({
        'x': tile_x,
        'y': tile_y,
        'encoding': tile_encoding
    })

print(f'Generated encodings for {len(tile_encodings)} tiles.')
# Out:
# Processing tile 18000, -2000
# Processing tile 18000, 0
# Processing tile 18000, 2000
# Processing tile 18000, 4000
# Processing tile 18000, 6000
# Processing tile 18000, 8000
# Processing tile 18000, 10000
# Processing tile 18000, 12000
# Processing tile 18000, 14000
# Processing tile 18000, 16000
# Processing tile 18000, 18000
# Processing tile 18000, 20000
# Processing tile 18000, 22000
# Processing tile 18000, 24000
# Processing tile 18000, 26000
# Processing tile 18000, 28000
# Processing tile 18000, 30000
# Processing tile 18000, 32000
# Processing tile 18000, 34000
# Processing tile 18000, 36000
# Processing tile 18000, 38000
# Processing tile 18000, 40000
# Processing tile 18000, 42000
# Processing tile 18000, 44000
# Processing tile 18000, 46000
# Processing tile 18000, 48000
# Processing tile 18000, 50000
# Processing tile 18000, 52000
# Processing tile 18000, 54000
# Processing tile 18000, 56000
# Processing tile 18000, 58000
# Processing tile 18000, 60000
# Processing tile 18000, 62000
# Processing tile 18000, 64000
# Processing tile 18000, 66000
# Processing tile 18000, 68000
# Processing tile 18000, 70000
# Processing tile 18000, 72000
# Processing tile 18000, 74000
# Processing tile 20000, -2000
# Processing tile 20000, 0
# Processing tile 20000, 2000
# Processing tile 20000, 4000
# Processing tile 20000, 6000
# Processing tile 20000, 8000
# Processing tile 20000, 10000
# Processing tile 20000, 12000
# Processing tile 20000, 14000
# Processing tile 20000, 16000
# Processing tile 20000, 18000
# Processing tile 20000, 20000
# Processing tile 20000, 22000
# Processing tile 20000, 24000
# Processing tile 20000, 26000
# Processing tile 20000, 28000
# Processing tile 20000, 30000
# Processing tile 20000, 32000
# Processing tile 20000, 34000
# Processing tile 20000, 36000
# Processing tile 20000, 38000
# Processing tile 20000, 40000
# Processing tile 20000, 42000
# Processing tile 20000, 44000
# Processing tile 20000, 46000
# Processing tile 20000, 48000
# Processing tile 20000, 50000
# Processing tile 20000, 52000
# Processing tile 20000, 54000
# Processing tile 20000, 56000
# Processing tile 20000, 58000
# Processing tile 20000, 60000
# Processing tile 20000, 62000
# Processing tile 20000, 64000
# Processing tile 20000, 66000
# Processing tile 20000, 68000
# Processing tile 20000, 70000
# Processing tile 20000, 72000
# Processing tile 20000, 74000
# Processing tile 22000, -2000
# Processing tile 22000, 0
# Processing tile 22000, 2000
# Processing tile 22000, 4000
# Processing tile 22000, 6000
# Processing tile 22000, 8000
# Processing tile 22000, 10000
# Processing tile 22000, 12000
# Processing tile 22000, 14000
# Processing tile 22000, 16000
# Processing tile 22000, 18000
# Processing tile 22000, 20000
# Processing tile 22000, 22000
# Processing tile 22000, 24000
# Processing tile 22000, 26000
# Processing tile 22000, 28000
# Processing tile 22000, 30000
# Processing tile 22000, 32000
# Processing tile 22000, 34000
# Processing tile 22000, 36000
# Processing tile 22000, 38000
# Processing tile 22000, 40000
# Processing tile 22000, 42000
# Processing tile 22000, 44000
# Processing tile 22000, 46000
# Processing tile 22000, 48000
# Processing tile 22000, 50000
# Processing tile 22000, 52000
# Processing tile 22000, 54000
# Processing tile 22000, 56000
# Processing tile 22000, 58000
# Processing tile 22000, 60000
# Processing tile 22000, 62000
# Processing tile 22000, 64000
# Processing tile 22000, 66000
# Processing tile 22000, 68000
# Processing tile 22000, 70000
# Processing tile 22000, 72000
# Processing tile 22000, 74000
# Processing tile 24000, -2000
# Processing tile 24000, 0
# Processing tile 24000, 2000
# Processing tile 24000, 4000
# Processing tile 24000, 6000
# Processing tile 24000, 8000
# Processing tile 24000, 10000
# Processing tile 24000, 12000
# Processing tile 24000, 14000
# Processing tile 24000, 16000
# Processing tile 24000, 18000
# Processing tile 24000, 20000
# Processing tile 24000, 22000
# Processing tile 24000, 24000
# Processing tile 24000, 26000
# Processing tile 24000, 28000
# Processing tile 24000, 30000
# Processing tile 24000, 32000
# Processing tile 24000, 34000
# Processing tile 24000, 36000
# Processing tile 24000, 38000
# Processing tile 24000, 40000
# Processing tile 24000, 42000
# Processing tile 24000, 44000
# Processing tile 24000, 46000
# Processing tile 24000, 48000
# Processing tile 24000, 50000
# Processing tile 24000, 52000
# Processing tile 24000, 54000
# Processing tile 24000, 56000
# Processing tile 24000, 58000
# Processing tile 24000, 60000
# Processing tile 24000, 62000
# Processing tile 24000, 64000
# Processing tile 24000, 66000
# Processing tile 24000, 68000
# Processing tile 24000, 70000
# Processing tile 24000, 72000
# Processing tile 24000, 74000
# Processing tile 26000, -2000
# Processing tile 26000, 0
# Processing tile 26000, 2000
# Processing tile 26000, 4000
# Processing tile 26000, 6000
# Processing tile 26000, 8000
# Processing tile 26000, 10000
# Processing tile 26000, 12000
# Processing tile 26000, 14000
# Processing tile 26000, 16000
# Processing tile 26000, 18000
# Processing tile 26000, 20000
# Processing tile 26000, 22000
# Processing tile 26000, 24000
# Processing tile 26000, 26000
# Processing tile 26000, 28000
# Processing tile 26000, 30000
# Processing tile 26000, 32000
# Processing tile 26000, 34000
# Processing tile 26000, 36000
# Processing tile 26000, 38000
# Processing tile 26000, 40000
# Processing tile 26000, 42000
# Processing tile 26000, 44000
# Processing tile 26000, 46000
# Processing tile 26000, 48000
# Processing tile 26000, 50000
# Processing tile 26000, 52000
# Processing tile 26000, 54000
# Processing tile 26000, 56000
# Processing tile 26000, 58000
# Processing tile 26000, 60000
# Processing tile 26000, 62000
# Processing tile 26000, 64000
# Processing tile 26000, 66000
# Processing tile 26000, 68000
# Processing tile 26000, 70000
# Processing tile 26000, 72000
# Processing tile 26000, 74000
# Processing tile 28000, -2000
# Processing tile 28000, 0
# Processing tile 28000, 2000
# Processing tile 28000, 4000
# Processing tile 28000, 6000
# Processing tile 28000, 8000
# Processing tile 28000, 10000
# Processing tile 28000, 12000
# Processing tile 28000, 14000
# Processing tile 28000, 16000
# Processing tile 28000, 18000
# Processing tile 28000, 20000
# Processing tile 28000, 22000
# Processing tile 28000, 24000
# Processing tile 28000, 26000
# Processing tile 28000, 28000
# Processing tile 28000, 30000
# Processing tile 28000, 32000
# Processing tile 28000, 34000
# Processing tile 28000, 36000
# Processing tile 28000, 38000
# Processing tile 28000, 40000
# Processing tile 28000, 42000
# Processing tile 28000, 44000
# Processing tile 28000, 46000
# Processing tile 28000, 48000
# Processing tile 28000, 50000
# Processing tile 28000, 52000
# Processing tile 28000, 54000
# Processing tile 28000, 56000
# Processing tile 28000, 58000
# Processing tile 28000, 60000
# Processing tile 28000, 62000
# Processing tile 28000, 64000
# Processing tile 28000, 66000
# Processing tile 28000, 68000
# Processing tile 28000, 70000
# Processing tile 28000, 72000
# Processing tile 28000, 74000
# Processing tile 30000, -2000
# Processing tile 30000, 0
# Processing tile 30000, 2000
# Processing tile 30000, 4000
# Processing tile 30000, 6000
# Processing tile 30000, 8000
# Processing tile 30000, 10000
# Processing tile 30000, 12000
# Processing tile 30000, 14000
# Processing tile 30000, 16000
# Processing tile 30000, 18000
# Processing tile 30000, 20000
# Processing tile 30000, 22000
# Processing tile 30000, 24000
# Processing tile 30000, 26000
# Processing tile 30000, 28000
# Processing tile 30000, 30000
# Processing tile 30000, 32000
# Processing tile 30000, 34000
# Processing tile 30000, 36000
# Processing tile 30000, 38000
# Processing tile 30000, 40000
# Processing tile 30000, 42000
# Processing tile 30000, 44000
# Processing tile 30000, 46000
# Processing tile 30000, 48000
# Processing tile 30000, 50000
# Processing tile 30000, 52000
# Processing tile 30000, 54000
# Processing tile 30000, 56000
# Processing tile 30000, 58000
# Processing tile 30000, 60000
# Processing tile 30000, 62000
# Processing tile 30000, 64000
# Processing tile 30000, 66000
# Processing tile 30000, 68000
# Processing tile 30000, 70000
# Processing tile 30000, 72000
# Processing tile 30000, 74000
# Processing tile 32000, -2000
# Processing tile 32000, 0
# Processing tile 32000, 2000
# Processing tile 32000, 4000
# Processing tile 32000, 6000
# Processing tile 32000, 8000
# Processing tile 32000, 10000
# Processing tile 32000, 12000
# Processing tile 32000, 14000
# Processing tile 32000, 16000
# Processing tile 32000, 18000
# Processing tile 32000, 20000
# Processing tile 32000, 22000
# Processing tile 32000, 24000
# Processing tile 32000, 26000
# Processing tile 32000, 28000
# Processing tile 32000, 30000
# Processing tile 32000, 32000
# Processing tile 32000, 34000
# Processing tile 32000, 36000
# Processing tile 32000, 38000
# Processing tile 32000, 40000
# Processing tile 32000, 42000
# Processing tile 32000, 44000
# Processing tile 32000, 46000
# Processing tile 32000, 48000
# Processing tile 32000, 50000
# Processing tile 32000, 52000
# Processing tile 32000, 54000
# Processing tile 32000, 56000
# Processing tile 32000, 58000
# Processing tile 32000, 60000
# Processing tile 32000, 62000
# Processing tile 32000, 64000
# Processing tile 32000, 66000
# Processing tile 32000, 68000
# Processing tile 32000, 70000
# Processing tile 32000, 72000
# Processing tile 32000, 74000
# Processing tile 34000, -2000
# Processing tile 34000, 0
# Processing tile 34000, 2000
# Processing tile 34000, 4000
# Processing tile 34000, 6000
# Processing tile 34000, 8000
# Processing tile 34000, 10000
# Processing tile 34000, 12000
# Processing tile 34000, 14000
# Processing tile 34000, 16000
# Processing tile 34000, 18000
# Processing tile 34000, 20000
# Processing tile 34000, 22000
# Processing tile 34000, 24000
# Processing tile 34000, 26000
# Processing tile 34000, 28000
# Processing tile 34000, 30000
# Processing tile 34000, 32000
# Processing tile 34000, 34000
# Processing tile 34000, 36000
# Processing tile 34000, 38000
# Processing tile 34000, 40000
# Processing tile 34000, 42000
# Processing tile 34000, 44000
# Processing tile 34000, 46000
# Processing tile 34000, 48000
# Processing tile 34000, 50000
# Processing tile 34000, 52000
# Processing tile 34000, 54000
# Processing tile 34000, 56000
# Processing tile 34000, 58000
# Processing tile 34000, 60000
# Processing tile 34000, 62000
# Processing tile 34000, 64000
# Processing tile 34000, 66000
# Processing tile 34000, 68000
# Processing tile 34000, 70000
# Processing tile 34000, 72000
# Processing tile 34000, 74000
# Processing tile 36000, -2000
# Processing tile 36000, 0
# Processing tile 36000, 2000
# Processing tile 36000, 4000
# Processing tile 36000, 6000
# Processing tile 36000, 8000
# Processing tile 36000, 10000
# Processing tile 36000, 12000
# Processing tile 36000, 14000
# Processing tile 36000, 16000
# Processing tile 36000, 18000
# Processing tile 36000, 20000
# Processing tile 36000, 22000
# Processing tile 36000, 24000
# Processing tile 36000, 26000
# Processing tile 36000, 28000
# Processing tile 36000, 30000
# Processing tile 36000, 32000
# Processing tile 36000, 34000
# Processing tile 36000, 36000
# Processing tile 36000, 38000
# Processing tile 36000, 40000
# Processing tile 36000, 42000
# Processing tile 36000, 44000
# Processing tile 36000, 46000
# Processing tile 36000, 48000
# Processing tile 36000, 50000
# Processing tile 36000, 52000
# Processing tile 36000, 54000
# Processing tile 36000, 56000
# Processing tile 36000, 58000
# Processing tile 36000, 60000
# Processing tile 36000, 62000
# Processing tile 36000, 64000
# Processing tile 36000, 66000
# Processing tile 36000, 68000
# Processing tile 36000, 70000
# Processing tile 36000, 72000
# Processing tile 36000, 74000
# Processing tile 38000, -2000
# Processing tile 38000, 0
# Processing tile 38000, 2000
# Processing tile 38000, 4000
# Processing tile 38000, 6000
# Processing tile 38000, 8000
# Processing tile 38000, 10000
# Processing tile 38000, 12000
# Processing tile 38000, 14000
# Processing tile 38000, 16000
# Processing tile 38000, 18000
# Processing tile 38000, 20000
# Processing tile 38000, 22000
# Processing tile 38000, 24000
# Processing tile 38000, 26000
# Processing tile 38000, 28000
# Processing tile 38000, 30000
# Processing tile 38000, 32000
# Processing tile 38000, 34000
# Processing tile 38000, 36000
# Processing tile 38000, 38000
# Processing tile 38000, 40000
# Processing tile 38000, 42000
# Processing tile 38000, 44000
# Processing tile 38000, 46000
# Processing tile 38000, 48000
# Processing tile 38000, 50000
# Processing tile 38000, 52000
# Processing tile 38000, 54000
# Processing tile 38000, 56000
# Processing tile 38000, 58000
# Processing tile 38000, 60000
# Processing tile 38000, 62000
# Processing tile 38000, 64000
# Processing tile 38000, 66000
# Processing tile 38000, 68000
# Processing tile 38000, 70000
# Processing tile 38000, 72000
# Processing tile 38000, 74000
# Processing tile 40000, -2000
# Processing tile 40000, 0
# Processing tile 40000, 2000
# Processing tile 40000, 4000
# Processing tile 40000, 6000
# Processing tile 40000, 8000
# Processing tile 40000, 10000
# Processing tile 40000, 12000
# Processing tile 40000, 14000
# Processing tile 40000, 16000
# Processing tile 40000, 18000
# Processing tile 40000, 20000
# Processing tile 40000, 22000
# Processing tile 40000, 24000
# Processing tile 40000, 26000
# Processing tile 40000, 28000
# Processing tile 40000, 30000
# Processing tile 40000, 32000
# Processing tile 40000, 34000
# Processing tile 40000, 36000
# Processing tile 40000, 38000
# Processing tile 40000, 40000
# Processing tile 40000, 42000
# Processing tile 40000, 44000
# Processing tile 40000, 46000
# Processing tile 40000, 48000
# Processing tile 40000, 50000
# Processing tile 40000, 52000
# Processing tile 40000, 54000
# Processing tile 40000, 56000
# Processing tile 40000, 58000
# Processing tile 40000, 60000
# Processing tile 40000, 62000
# Processing tile 40000, 64000
# Processing tile 40000, 66000
# Processing tile 40000, 68000
# Processing tile 40000, 70000
# Processing tile 40000, 72000
# Processing tile 40000, 74000
# Processing tile 42000, -2000
# Processing tile 42000, 0
# Processing tile 42000, 2000
# Processing tile 42000, 4000
# Processing tile 42000, 6000
# Processing tile 42000, 8000
# Processing tile 42000, 10000
# Processing tile 42000, 12000
# Processing tile 42000, 14000
# Processing tile 42000, 16000
# Processing tile 42000, 18000
# Processing tile 42000, 20000
# Processing tile 42000, 22000
# Processing tile 42000, 24000
# Processing tile 42000, 26000
# Processing tile 42000, 28000
# Processing tile 42000, 30000
# Processing tile 42000, 32000
# Processing tile 42000, 34000
# Processing tile 42000, 36000
# Processing tile 42000, 38000
# Processing tile 42000, 40000
# Processing tile 42000, 42000
# Processing tile 42000, 44000
# Processing tile 42000, 46000
# Processing tile 42000, 48000
# Processing tile 42000, 50000
# Processing tile 42000, 52000
# Processing tile 42000, 54000
# Processing tile 42000, 56000
# Processing tile 42000, 58000
# Processing tile 42000, 60000
# Processing tile 42000, 62000
# Processing tile 42000, 64000
# Processing tile 42000, 66000
# Processing tile 42000, 68000
# Processing tile 42000, 70000
# Processing tile 42000, 72000
# Processing tile 42000, 74000
# Processing tile 44000, -2000
# Processing tile 44000, 0
# Processing tile 44000, 2000
# Processing tile 44000, 4000
# Processing tile 44000, 6000
# Processing tile 44000, 8000
# Processing tile 44000, 10000
# Processing tile 44000, 12000
# Processing tile 44000, 14000
# Processing tile 44000, 16000
# Processing tile 44000, 18000
# Processing tile 44000, 20000
# Processing tile 44000, 22000
# Processing tile 44000, 24000
# Processing tile 44000, 26000
# Processing tile 44000, 28000
# Processing tile 44000, 30000
# Processing tile 44000, 32000
# Processing tile 44000, 34000
# Processing tile 44000, 36000
# Processing tile 44000, 38000
# Processing tile 44000, 40000
# Processing tile 44000, 42000
# Processing tile 44000, 44000
# Processing tile 44000, 46000
# Processing tile 44000, 48000
# Processing tile 44000, 50000
# Processing tile 44000, 52000
# Processing tile 44000, 54000
# Processing tile 44000, 56000
# Processing tile 44000, 58000
# Processing tile 44000, 60000
# Processing tile 44000, 62000
# Processing tile 44000, 64000
# Processing tile 44000, 66000
# Processing tile 44000, 68000
# Processing tile 44000, 70000
# Processing tile 44000, 72000
# Processing tile 44000, 74000
# Processing tile 46000, -2000
# Processing tile 46000, 0
# Processing tile 46000, 2000
# Processing tile 46000, 4000
# Processing tile 46000, 6000
# Processing tile 46000, 8000
# Processing tile 46000, 10000
# Processing tile 46000, 12000
# Processing tile 46000, 14000
# Processing tile 46000, 16000
# Processing tile 46000, 18000
# Processing tile 46000, 20000
# Processing tile 46000, 22000
# Processing tile 46000, 24000
# Processing tile 46000, 26000
# Processing tile 46000, 28000
# Processing tile 46000, 30000
# Processing tile 46000, 32000
# Processing tile 46000, 34000
# Processing tile 46000, 36000
# Processing tile 46000, 38000
# Processing tile 46000, 40000
# Processing tile 46000, 42000
# Processing tile 46000, 44000
# Processing tile 46000, 46000
# Processing tile 46000, 48000
# Processing tile 46000, 50000
# Processing tile 46000, 52000
# Processing tile 46000, 54000
# Processing tile 46000, 56000
# Processing tile 46000, 58000
# Processing tile 46000, 60000
# Processing tile 46000, 62000
# Processing tile 46000, 64000
# Processing tile 46000, 66000
# Processing tile 46000, 68000
# Processing tile 46000, 70000
# Processing tile 46000, 72000
# Processing tile 46000, 74000
# Processing tile 48000, -2000
# Processing tile 48000, 0
# Processing tile 48000, 2000
# Processing tile 48000, 4000
# Processing tile 48000, 6000
# Processing tile 48000, 8000
# Processing tile 48000, 10000
# Processing tile 48000, 12000
# Processing tile 48000, 14000
# Processing tile 48000, 16000
# Processing tile 48000, 18000
# Processing tile 48000, 20000
# Processing tile 48000, 22000
# Processing tile 48000, 24000
# Processing tile 48000, 26000
# Processing tile 48000, 28000
# Processing tile 48000, 30000
# Processing tile 48000, 32000
# Processing tile 48000, 34000
# Processing tile 48000, 36000
# Processing tile 48000, 38000
# Processing tile 48000, 40000
# Processing tile 48000, 42000
# Processing tile 48000, 44000
# Processing tile 48000, 46000
# Processing tile 48000, 48000
# Processing tile 48000, 50000
# Processing tile 48000, 52000
# Processing tile 48000, 54000
# Processing tile 48000, 56000
# Processing tile 48000, 58000
# Processing tile 48000, 60000
# Processing tile 48000, 62000
# Processing tile 48000, 64000
# Processing tile 48000, 66000
# Processing tile 48000, 68000
# Processing tile 48000, 70000
# Processing tile 48000, 72000
# Processing tile 48000, 74000
# Processing tile 50000, -2000
# Processing tile 50000, 0
# Processing tile 50000, 2000
# Processing tile 50000, 4000
# Processing tile 50000, 6000
# Processing tile 50000, 8000
# Processing tile 50000, 10000
# Processing tile 50000, 12000
# Processing tile 50000, 14000
# Processing tile 50000, 16000
# Processing tile 50000, 18000
# Processing tile 50000, 20000
# Processing tile 50000, 22000
# Processing tile 50000, 24000
# Processing tile 50000, 26000
# Processing tile 50000, 28000
# Processing tile 50000, 30000
# Processing tile 50000, 32000
# Processing tile 50000, 34000
# Processing tile 50000, 36000
# Processing tile 50000, 38000
# Processing tile 50000, 40000
# Processing tile 50000, 42000
# Processing tile 50000, 44000
# Processing tile 50000, 46000
# Processing tile 50000, 48000
# Processing tile 50000, 50000
# Processing tile 50000, 52000
# Processing tile 50000, 54000
# Processing tile 50000, 56000
# Processing tile 50000, 58000
# Processing tile 50000, 60000
# Processing tile 50000, 62000
# Processing tile 50000, 64000
# Processing tile 50000, 66000
# Processing tile 50000, 68000
# Processing tile 50000, 70000
# Processing tile 50000, 72000
# Processing tile 50000, 74000
# Processing tile 52000, -2000
# Processing tile 52000, 0
# Processing tile 52000, 2000
# Processing tile 52000, 4000
# Processing tile 52000, 6000
# Processing tile 52000, 8000
# Processing tile 52000, 10000
# Processing tile 52000, 12000
# Processing tile 52000, 14000
# Processing tile 52000, 16000
# Processing tile 52000, 18000
# Processing tile 52000, 20000
# Processing tile 52000, 22000
# Processing tile 52000, 24000
# Processing tile 52000, 26000
# Processing tile 52000, 28000
# Processing tile 52000, 30000
# Processing tile 52000, 32000
# Processing tile 52000, 34000
# Processing tile 52000, 36000
# Processing tile 52000, 38000
# Processing tile 52000, 40000
# Processing tile 52000, 42000
# Processing tile 52000, 44000
# Processing tile 52000, 46000
# Processing tile 52000, 48000
# Processing tile 52000, 50000
# Processing tile 52000, 52000
# Processing tile 52000, 54000
# Processing tile 52000, 56000
# Processing tile 52000, 58000
# Processing tile 52000, 60000
# Processing tile 52000, 62000
# Processing tile 52000, 64000
# Processing tile 52000, 66000
# Processing tile 52000, 68000
# Processing tile 52000, 70000
# Processing tile 52000, 72000
# Processing tile 52000, 74000
# Processing tile 54000, -2000
# Processing tile 54000, 0
# Processing tile 54000, 2000
# Processing tile 54000, 4000
# Processing tile 54000, 6000
# Processing tile 54000, 8000
# Processing tile 54000, 10000
# Processing tile 54000, 12000
# Processing tile 54000, 14000
# Processing tile 54000, 16000
# Processing tile 54000, 18000
# Processing tile 54000, 20000
# Processing tile 54000, 22000
# Processing tile 54000, 24000
# Processing tile 54000, 26000
# Processing tile 54000, 28000
# Processing tile 54000, 30000
# Processing tile 54000, 32000
# Processing tile 54000, 34000
# Processing tile 54000, 36000
# Processing tile 54000, 38000
# Processing tile 54000, 40000
# Processing tile 54000, 42000
# Processing tile 54000, 44000
# Processing tile 54000, 46000
# Processing tile 54000, 48000
# Processing tile 54000, 50000
# Processing tile 54000, 52000
# Processing tile 54000, 54000
# Processing tile 54000, 56000
# Processing tile 54000, 58000
# Processing tile 54000, 60000
# Processing tile 54000, 62000
# Processing tile 54000, 64000
# Processing tile 54000, 66000
# Processing tile 54000, 68000
# Processing tile 54000, 70000
# Processing tile 54000, 72000
# Processing tile 54000, 74000
# Processing tile 56000, -2000
# Processing tile 56000, 0
# Processing tile 56000, 2000
# Processing tile 56000, 4000
# Processing tile 56000, 6000
# Processing tile 56000, 8000
# Processing tile 56000, 10000
# Processing tile 56000, 12000
# Processing tile 56000, 14000
# Processing tile 56000, 16000
# Processing tile 56000, 18000
# Processing tile 56000, 20000
# Processing tile 56000, 22000
# Processing tile 56000, 24000
# Processing tile 56000, 26000
# Processing tile 56000, 28000
# Processing tile 56000, 30000
# Processing tile 56000, 32000
# Processing tile 56000, 34000
# Processing tile 56000, 36000
# Processing tile 56000, 38000
# Processing tile 56000, 40000
# Processing tile 56000, 42000
# Processing tile 56000, 44000
# Processing tile 56000, 46000
# Processing tile 56000, 48000
# Processing tile 56000, 50000
# Processing tile 56000, 52000
# Processing tile 56000, 54000
# Processing tile 56000, 56000
# Processing tile 56000, 58000
# Processing tile 56000, 60000
# Processing tile 56000, 62000
# Processing tile 56000, 64000
# Processing tile 56000, 66000
# Processing tile 56000, 68000
# Processing tile 56000, 70000
# Processing tile 56000, 72000
# Processing tile 56000, 74000
# Processing tile 58000, -2000
# Processing tile 58000, 0
# Processing tile 58000, 2000
# Processing tile 58000, 4000
# Processing tile 58000, 6000
# Processing tile 58000, 8000
# Processing tile 58000, 10000
# Processing tile 58000, 12000
# Processing tile 58000, 14000
# Processing tile 58000, 16000
# Processing tile 58000, 18000
# Processing tile 58000, 20000
# Processing tile 58000, 22000
# Processing tile 58000, 24000
# Processing tile 58000, 26000
# Processing tile 58000, 28000
# Processing tile 58000, 30000
# Processing tile 58000, 32000
# Processing tile 58000, 34000
# Processing tile 58000, 36000
# Processing tile 58000, 38000
# Processing tile 58000, 40000
# Processing tile 58000, 42000
# Processing tile 58000, 44000
# Processing tile 58000, 46000
# Processing tile 58000, 48000
# Processing tile 58000, 50000
# Processing tile 58000, 52000
# Processing tile 58000, 54000
# Processing tile 58000, 56000
# Processing tile 58000, 58000
# Processing tile 58000, 60000
# Processing tile 58000, 62000
# Processing tile 58000, 64000
# Processing tile 58000, 66000
# Processing tile 58000, 68000
# Processing tile 58000, 70000
# Processing tile 58000, 72000
# Processing tile 58000, 74000
# Processing tile 60000, -2000
# Processing tile 60000, 0
# Processing tile 60000, 2000
# Processing tile 60000, 4000
# Processing tile 60000, 6000
# Processing tile 60000, 8000
# Processing tile 60000, 10000
# Processing tile 60000, 12000
# Processing tile 60000, 14000
# Processing tile 60000, 16000
# Processing tile 60000, 18000
# Processing tile 60000, 20000
# Processing tile 60000, 22000
# Processing tile 60000, 24000
# Processing tile 60000, 26000
# Processing tile 60000, 28000
# Processing tile 60000, 30000
# Processing tile 60000, 32000
# Processing tile 60000, 34000
# Processing tile 60000, 36000
# Processing tile 60000, 38000
# Processing tile 60000, 40000
# Processing tile 60000, 42000
# Processing tile 60000, 44000
# Processing tile 60000, 46000
# Processing tile 60000, 48000
# Processing tile 60000, 50000
# Processing tile 60000, 52000
# Processing tile 60000, 54000
# Processing tile 60000, 56000
# Processing tile 60000, 58000
# Processing tile 60000, 60000
# Processing tile 60000, 62000
# Processing tile 60000, 64000
# Processing tile 60000, 66000
# Processing tile 60000, 68000
# Processing tile 60000, 70000
# Processing tile 60000, 72000
# Processing tile 60000, 74000
# Processing tile 62000, -2000
# Processing tile 62000, 0
# Processing tile 62000, 2000
# Processing tile 62000, 4000
# Processing tile 62000, 6000
# Processing tile 62000, 8000
# Processing tile 62000, 10000
# Processing tile 62000, 12000
# Processing tile 62000, 14000
# Processing tile 62000, 16000
# Processing tile 62000, 18000
# Processing tile 62000, 20000
# Processing tile 62000, 22000
# Processing tile 62000, 24000
# Processing tile 62000, 26000
# Processing tile 62000, 28000
# Processing tile 62000, 30000
# Processing tile 62000, 32000
# Processing tile 62000, 34000
# Processing tile 62000, 36000
# Processing tile 62000, 38000
# Processing tile 62000, 40000
# Processing tile 62000, 42000
# Processing tile 62000, 44000
# Processing tile 62000, 46000
# Processing tile 62000, 48000
# Processing tile 62000, 50000
# Processing tile 62000, 52000
# Processing tile 62000, 54000
# Processing tile 62000, 56000
# Processing tile 62000, 58000
# Processing tile 62000, 60000
# Processing tile 62000, 62000
# Processing tile 62000, 64000
# Processing tile 62000, 66000
# Processing tile 62000, 68000
# Processing tile 62000, 70000
# Processing tile 62000, 72000
# Processing tile 62000, 74000
# Processing tile 64000, -2000
# Processing tile 64000, 0
# Processing tile 64000, 2000
# Processing tile 64000, 4000
# Processing tile 64000, 6000
# Processing tile 64000, 8000
# Processing tile 64000, 10000
# Processing tile 64000, 12000
# Processing tile 64000, 14000
# Processing tile 64000, 16000
# Processing tile 64000, 18000
# Processing tile 64000, 20000
# Processing tile 64000, 22000
# Processing tile 64000, 24000
# Processing tile 64000, 26000
# Processing tile 64000, 28000
# Processing tile 64000, 30000
# Processing tile 64000, 32000
# Processing tile 64000, 34000
# Processing tile 64000, 36000
# Processing tile 64000, 38000
# Processing tile 64000, 40000
# Processing tile 64000, 42000
# Processing tile 64000, 44000
# Processing tile 64000, 46000
# Processing tile 64000, 48000
# Processing tile 64000, 50000
# Processing tile 64000, 52000
# Processing tile 64000, 54000
# Processing tile 64000, 56000
# Processing tile 64000, 58000
# Processing tile 64000, 60000
# Processing tile 64000, 62000
# Processing tile 64000, 64000
# Processing tile 64000, 66000
# Processing tile 64000, 68000
# Processing tile 64000, 70000
# Processing tile 64000, 72000
# Processing tile 64000, 74000
# Processing tile 66000, -2000
# Processing tile 66000, 0
# Processing tile 66000, 2000
# Processing tile 66000, 4000
# Processing tile 66000, 6000
# Processing tile 66000, 8000
# Processing tile 66000, 10000
# Processing tile 66000, 12000
# Processing tile 66000, 14000
# Processing tile 66000, 16000
# Processing tile 66000, 18000
# Processing tile 66000, 20000
# Processing tile 66000, 22000
# Processing tile 66000, 24000
# Processing tile 66000, 26000
# Processing tile 66000, 28000
# Processing tile 66000, 30000
# Processing tile 66000, 32000
# Processing tile 66000, 34000
# Processing tile 66000, 36000
# Processing tile 66000, 38000
# Processing tile 66000, 40000
# Processing tile 66000, 42000
# Processing tile 66000, 44000
# Processing tile 66000, 46000
# Processing tile 66000, 48000
# Processing tile 66000, 50000
# Processing tile 66000, 52000
# Processing tile 66000, 54000
# Processing tile 66000, 56000
# Processing tile 66000, 58000
# Processing tile 66000, 60000
# Processing tile 66000, 62000
# Processing tile 66000, 64000
# Processing tile 66000, 66000
# Processing tile 66000, 68000
# Processing tile 66000, 70000
# Processing tile 66000, 72000
# Processing tile 66000, 74000
# Processing tile 68000, -2000
# Processing tile 68000, 0
# Processing tile 68000, 2000
# Processing tile 68000, 4000
# Processing tile 68000, 6000
# Processing tile 68000, 8000
# Processing tile 68000, 10000
# Processing tile 68000, 12000
# Processing tile 68000, 14000
# Processing tile 68000, 16000
# Processing tile 68000, 18000
# Processing tile 68000, 20000
# Processing tile 68000, 22000
# Processing tile 68000, 24000
# Processing tile 68000, 26000
# Processing tile 68000, 28000
# Processing tile 68000, 30000
# Processing tile 68000, 32000
# Processing tile 68000, 34000
# Processing tile 68000, 36000
# Processing tile 68000, 38000
# Processing tile 68000, 40000
# Processing tile 68000, 42000
# Processing tile 68000, 44000
# Processing tile 68000, 46000
# Processing tile 68000, 48000
# Processing tile 68000, 50000
# Processing tile 68000, 52000
# Processing tile 68000, 54000
# Processing tile 68000, 56000
# Processing tile 68000, 58000
# Processing tile 68000, 60000
# Processing tile 68000, 62000
# Processing tile 68000, 64000
# Processing tile 68000, 66000
# Processing tile 68000, 68000
# Processing tile 68000, 70000
# Processing tile 68000, 72000
# Processing tile 68000, 74000
# Processing tile 70000, -2000
# Processing tile 70000, 0
# Processing tile 70000, 2000
# Processing tile 70000, 4000
# Processing tile 70000, 6000
# Processing tile 70000, 8000
# Processing tile 70000, 10000
# Processing tile 70000, 12000
# Processing tile 70000, 14000
# Processing tile 70000, 16000
# Processing tile 70000, 18000
# Processing tile 70000, 20000
# Processing tile 70000, 22000
# Processing tile 70000, 24000
# Processing tile 70000, 26000
# Processing tile 70000, 28000
# Processing tile 70000, 30000
# Processing tile 70000, 32000
# Processing tile 70000, 34000
# Processing tile 70000, 36000
# Processing tile 70000, 38000
# Processing tile 70000, 40000
# Processing tile 70000, 42000
# Processing tile 70000, 44000
# Processing tile 70000, 46000
# Processing tile 70000, 48000
# Processing tile 70000, 50000
# Processing tile 70000, 52000
# Processing tile 70000, 54000
# Processing tile 70000, 56000
# Processing tile 70000, 58000
# Processing tile 70000, 60000
# Processing tile 70000, 62000
# Processing tile 70000, 64000
# Processing tile 70000, 66000
# Processing tile 70000, 68000
# Processing tile 70000, 70000
# Processing tile 70000, 72000
# Processing tile 70000, 74000
# Processing tile 72000, -2000
# Processing tile 72000, 0
# Processing tile 72000, 2000
# Processing tile 72000, 4000
# Processing tile 72000, 6000
# Processing tile 72000, 8000
# Processing tile 72000, 10000
# Processing tile 72000, 12000
# Processing tile 72000, 14000
# Processing tile 72000, 16000
# Processing tile 72000, 18000
# Processing tile 72000, 20000
# Processing tile 72000, 22000
# Processing tile 72000, 24000
# Processing tile 72000, 26000
# Processing tile 72000, 28000
# Processing tile 72000, 30000
# Processing tile 72000, 32000
# Processing tile 72000, 34000
# Processing tile 72000, 36000
# Processing tile 72000, 38000
# Processing tile 72000, 40000
# Processing tile 72000, 42000
# Processing tile 72000, 44000
# Processing tile 72000, 46000
# Processing tile 72000, 48000
# Processing tile 72000, 50000
# Processing tile 72000, 52000
# Processing tile 72000, 54000
# Processing tile 72000, 56000
# Processing tile 72000, 58000
# Processing tile 72000, 60000
# Processing tile 72000, 62000
# Processing tile 72000, 64000
# Processing tile 72000, 66000
# Processing tile 72000, 68000
# Processing tile 72000, 70000
# Processing tile 72000, 72000
# Processing tile 72000, 74000
# Processing tile 74000, -2000
# Processing tile 74000, 0
# Processing tile 74000, 2000
# Processing tile 74000, 4000
# Processing tile 74000, 6000
# Processing tile 74000, 8000
# Processing tile 74000, 10000
# Processing tile 74000, 12000
# Processing tile 74000, 14000
# Processing tile 74000, 16000
# Processing tile 74000, 18000
# Processing tile 74000, 20000
# Processing tile 74000, 22000
# Processing tile 74000, 24000
# Processing tile 74000, 26000
# Processing tile 74000, 28000
# Processing tile 74000, 30000
# Processing tile 74000, 32000
# Processing tile 74000, 34000
# Processing tile 74000, 36000
# Processing tile 74000, 38000
# Processing tile 74000, 40000
# Processing tile 74000, 42000
# Processing tile 74000, 44000
# Processing tile 74000, 46000
# Processing tile 74000, 48000
# Processing tile 74000, 50000
# Processing tile 74000, 52000
# Processing tile 74000, 54000
# Processing tile 74000, 56000
# Processing tile 74000, 58000
# Processing tile 74000, 60000
# Processing tile 74000, 62000
# Processing tile 74000, 64000
# Processing tile 74000, 66000
# Processing tile 74000, 68000
# Processing tile 74000, 70000
# Processing tile 74000, 72000
# Processing tile 74000, 74000
# Processing tile 76000, -2000
# Processing tile 76000, 0
# Processing tile 76000, 2000
# Processing tile 76000, 4000
# Processing tile 76000, 6000
# Processing tile 76000, 8000
# Processing tile 76000, 10000
# Processing tile 76000, 12000
# Processing tile 76000, 14000
# Processing tile 76000, 16000
# Processing tile 76000, 18000
# Processing tile 76000, 20000
# Processing tile 76000, 22000
# Processing tile 76000, 24000
# Processing tile 76000, 26000
# Processing tile 76000, 28000
# Processing tile 76000, 30000
# Processing tile 76000, 32000
# Processing tile 76000, 34000
# Processing tile 76000, 36000
# Processing tile 76000, 38000
# Processing tile 76000, 40000
# Processing tile 76000, 42000
# Processing tile 76000, 44000
# Processing tile 76000, 46000
# Processing tile 76000, 48000
# Processing tile 76000, 50000
# Processing tile 76000, 52000
# Processing tile 76000, 54000
# Processing tile 76000, 56000
# Processing tile 76000, 58000
# Processing tile 76000, 60000
# Processing tile 76000, 62000
# Processing tile 76000, 64000
# Processing tile 76000, 66000
# Processing tile 76000, 68000
# Processing tile 76000, 70000
# Processing tile 76000, 72000
# Processing tile 76000, 74000
# Processing tile 78000, -2000
# Processing tile 78000, 0
# Processing tile 78000, 2000
# Processing tile 78000, 4000
# Processing tile 78000, 6000
# Processing tile 78000, 8000
# Processing tile 78000, 10000
# Processing tile 78000, 12000
# Processing tile 78000, 14000
# Processing tile 78000, 16000
# Processing tile 78000, 18000
# Processing tile 78000, 20000
# Processing tile 78000, 22000
# Processing tile 78000, 24000
# Processing tile 78000, 26000
# Processing tile 78000, 28000
# Processing tile 78000, 30000
# Processing tile 78000, 32000
# Processing tile 78000, 34000
# Processing tile 78000, 36000
# Processing tile 78000, 38000
# Processing tile 78000, 40000
# Processing tile 78000, 42000
# Processing tile 78000, 44000
# Processing tile 78000, 46000
# Processing tile 78000, 48000
# Processing tile 78000, 50000
# Processing tile 78000, 52000
# Processing tile 78000, 54000
# Processing tile 78000, 56000
# Processing tile 78000, 58000
# Processing tile 78000, 60000
# Processing tile 78000, 62000
# Processing tile 78000, 64000
# Processing tile 78000, 66000
# Processing tile 78000, 68000
# Processing tile 78000, 70000
# Processing tile 78000, 72000
# Processing tile 78000, 74000
# Processing tile 80000, -2000
# Processing tile 80000, 0
# Processing tile 80000, 2000
# Processing tile 80000, 4000
# Processing tile 80000, 6000
# Processing tile 80000, 8000
# Processing tile 80000, 10000
# Processing tile 80000, 12000
# Processing tile 80000, 14000
# Processing tile 80000, 16000
# Processing tile 80000, 18000
# Processing tile 80000, 20000
# Processing tile 80000, 22000
# Processing tile 80000, 24000
# Processing tile 80000, 26000
# Processing tile 80000, 28000
# Processing tile 80000, 30000
# Processing tile 80000, 32000
# Processing tile 80000, 34000
# Processing tile 80000, 36000
# Processing tile 80000, 38000
# Processing tile 80000, 40000
# Processing tile 80000, 42000
# Processing tile 80000, 44000
# Processing tile 80000, 46000
# Processing tile 80000, 48000
# Processing tile 80000, 50000
# Processing tile 80000, 52000
# Processing tile 80000, 54000
# Processing tile 80000, 56000
# Processing tile 80000, 58000
# Processing tile 80000, 60000
# Processing tile 80000, 62000
# Processing tile 80000, 64000
# Processing tile 80000, 66000
# Processing tile 80000, 68000
# Processing tile 80000, 70000
# Processing tile 80000, 72000
# Processing tile 80000, 74000
# Processing tile 82000, -2000
# Processing tile 82000, 0
# Processing tile 82000, 2000
# Processing tile 82000, 4000
# Processing tile 82000, 6000
# Processing tile 82000, 8000
# Processing tile 82000, 10000
# Processing tile 82000, 12000
# Processing tile 82000, 14000
# Processing tile 82000, 16000
# Processing tile 82000, 18000
# Processing tile 82000, 20000
# Processing tile 82000, 22000
# Processing tile 82000, 24000
# Processing tile 82000, 26000
# Processing tile 82000, 28000
# Processing tile 82000, 30000
# Processing tile 82000, 32000
# Processing tile 82000, 34000
# Processing tile 82000, 36000
# Processing tile 82000, 38000
# Processing tile 82000, 40000
# Processing tile 82000, 42000
# Processing tile 82000, 44000
# Processing tile 82000, 46000
# Processing tile 82000, 48000
# Processing tile 82000, 50000
# Processing tile 82000, 52000
# Processing tile 82000, 54000
# Processing tile 82000, 56000
# Processing tile 82000, 58000
# Processing tile 82000, 60000
# Processing tile 82000, 62000
# Processing tile 82000, 64000
# Processing tile 82000, 66000
# Processing tile 82000, 68000
# Processing tile 82000, 70000
# Processing tile 82000, 72000
# Processing tile 82000, 74000
# Processing tile 84000, -2000
# Processing tile 84000, 0
# Processing tile 84000, 2000
# Processing tile 84000, 4000
# Processing tile 84000, 6000
# Processing tile 84000, 8000
# Processing tile 84000, 10000
# Processing tile 84000, 12000
# Processing tile 84000, 14000
# Processing tile 84000, 16000
# Processing tile 84000, 18000
# Processing tile 84000, 20000
# Processing tile 84000, 22000
# Processing tile 84000, 24000
# Processing tile 84000, 26000
# Processing tile 84000, 28000
# Processing tile 84000, 30000
# Processing tile 84000, 32000
# Processing tile 84000, 34000
# Processing tile 84000, 36000
# Processing tile 84000, 38000
# Processing tile 84000, 40000
# Processing tile 84000, 42000
# Processing tile 84000, 44000
# Processing tile 84000, 46000
# Processing tile 84000, 48000
# Processing tile 84000, 50000
# Processing tile 84000, 52000
# Processing tile 84000, 54000
# Processing tile 84000, 56000
# Processing tile 84000, 58000
# Processing tile 84000, 60000
# Processing tile 84000, 62000
# Processing tile 84000, 64000
# Processing tile 84000, 66000
# Processing tile 84000, 68000
# Processing tile 84000, 70000
# Processing tile 84000, 72000
# Processing tile 84000, 74000
# Processing tile 86000, -2000
# Processing tile 86000, 0
# Processing tile 86000, 2000
# Processing tile 86000, 4000
# Processing tile 86000, 6000
# Processing tile 86000, 8000
# Processing tile 86000, 10000
# Processing tile 86000, 12000
# Processing tile 86000, 14000
# Processing tile 86000, 16000
# Processing tile 86000, 18000
# Processing tile 86000, 20000
# Processing tile 86000, 22000
# Processing tile 86000, 24000
# Processing tile 86000, 26000
# Processing tile 86000, 28000
# Processing tile 86000, 30000
# Processing tile 86000, 32000
# Processing tile 86000, 34000
# Processing tile 86000, 36000
# Processing tile 86000, 38000
# Processing tile 86000, 40000
# Processing tile 86000, 42000
# Processing tile 86000, 44000
# Processing tile 86000, 46000
# Processing tile 86000, 48000
# Processing tile 86000, 50000
# Processing tile 86000, 52000
# Processing tile 86000, 54000
# Processing tile 86000, 56000
# Processing tile 86000, 58000
# Processing tile 86000, 60000
# Processing tile 86000, 62000
# Processing tile 86000, 64000
# Processing tile 86000, 66000
# Processing tile 86000, 68000
# Processing tile 86000, 70000
# Processing tile 86000, 72000
# Processing tile 86000, 74000
# Processing tile 88000, -2000
# Processing tile 88000, 0
# Processing tile 88000, 2000
# Processing tile 88000, 4000
# Processing tile 88000, 6000
# Processing tile 88000, 8000
# Processing tile 88000, 10000
# Processing tile 88000, 12000
# Processing tile 88000, 14000
# Processing tile 88000, 16000
# Processing tile 88000, 18000
# Processing tile 88000, 20000
# Processing tile 88000, 22000
# Processing tile 88000, 24000
# Processing tile 88000, 26000
# Processing tile 88000, 28000
# Processing tile 88000, 30000
# Processing tile 88000, 32000
# Processing tile 88000, 34000
# Processing tile 88000, 36000
# Processing tile 88000, 38000
# Processing tile 88000, 40000
# Processing tile 88000, 42000
# Processing tile 88000, 44000
# Processing tile 88000, 46000
# Processing tile 88000, 48000
# Processing tile 88000, 50000
# Processing tile 88000, 52000
# Processing tile 88000, 54000
# Processing tile 88000, 56000
# Processing tile 88000, 58000
# Processing tile 88000, 60000
# Processing tile 88000, 62000
# Processing tile 88000, 64000
# Processing tile 88000, 66000
# Processing tile 88000, 68000
# Processing tile 88000, 70000
# Processing tile 88000, 72000
# Processing tile 88000, 74000
# Processing tile 90000, -2000
# Processing tile 90000, 0
# Processing tile 90000, 2000
# Processing tile 90000, 4000
# Processing tile 90000, 6000
# Processing tile 90000, 8000
# Processing tile 90000, 10000
# Processing tile 90000, 12000
# Processing tile 90000, 14000
# Processing tile 90000, 16000
# Processing tile 90000, 18000
# Processing tile 90000, 20000
# Processing tile 90000, 22000
# Processing tile 90000, 24000
# Processing tile 90000, 26000
# Processing tile 90000, 28000
# Processing tile 90000, 30000
# Processing tile 90000, 32000
# Processing tile 90000, 34000
# Processing tile 90000, 36000
# Processing tile 90000, 38000
# Processing tile 90000, 40000
# Processing tile 90000, 42000
# Processing tile 90000, 44000
# Processing tile 90000, 46000
# Processing tile 90000, 48000
# Processing tile 90000, 50000
# Processing tile 90000, 52000
# Processing tile 90000, 54000
# Processing tile 90000, 56000
# Processing tile 90000, 58000
# Processing tile 90000, 60000
# Processing tile 90000, 62000
# Processing tile 90000, 64000
# Processing tile 90000, 66000
# Processing tile 90000, 68000
# Processing tile 90000, 70000
# Processing tile 90000, 72000
# Processing tile 90000, 74000
# Processing tile 92000, -2000
# Processing tile 92000, 0
# Processing tile 92000, 2000
# Processing tile 92000, 4000
# Processing tile 92000, 6000
# Processing tile 92000, 8000
# Processing tile 92000, 10000
# Processing tile 92000, 12000
# Processing tile 92000, 14000
# Processing tile 92000, 16000
# Processing tile 92000, 18000
# Processing tile 92000, 20000
# Processing tile 92000, 22000
# Processing tile 92000, 24000
# Processing tile 92000, 26000
# Processing tile 92000, 28000
# Processing tile 92000, 30000
# Processing tile 92000, 32000
# Processing tile 92000, 34000
# Processing tile 92000, 36000
# Processing tile 92000, 38000
# Processing tile 92000, 40000
# Processing tile 92000, 42000
# Processing tile 92000, 44000
# Processing tile 92000, 46000
# Processing tile 92000, 48000
# Processing tile 92000, 50000
# Processing tile 92000, 52000
# Processing tile 92000, 54000
# Processing tile 92000, 56000
# Processing tile 92000, 58000
# Processing tile 92000, 60000
# Processing tile 92000, 62000
# Processing tile 92000, 64000
# Processing tile 92000, 66000
# Processing tile 92000, 68000
# Processing tile 92000, 70000
# Processing tile 92000, 72000
# Processing tile 92000, 74000
# Processing tile 94000, -2000
# Processing tile 94000, 0
# Processing tile 94000, 2000
# Processing tile 94000, 4000
# Processing tile 94000, 6000
# Processing tile 94000, 8000
# Processing tile 94000, 10000
# Processing tile 94000, 12000
# Processing tile 94000, 14000
# Processing tile 94000, 16000
# Processing tile 94000, 18000
# Processing tile 94000, 20000
# Processing tile 94000, 22000
# Processing tile 94000, 24000
# Processing tile 94000, 26000
# Processing tile 94000, 28000
# Processing tile 94000, 30000
# Processing tile 94000, 32000
# Processing tile 94000, 34000
# Processing tile 94000, 36000
# Processing tile 94000, 38000
# Processing tile 94000, 40000
# Processing tile 94000, 42000
# Processing tile 94000, 44000
# Processing tile 94000, 46000
# Processing tile 94000, 48000
# Processing tile 94000, 50000
# Processing tile 94000, 52000
# Processing tile 94000, 54000
# Processing tile 94000, 56000
# Processing tile 94000, 58000
# Processing tile 94000, 60000
# Processing tile 94000, 62000
# Processing tile 94000, 64000
# Processing tile 94000, 66000
# Processing tile 94000, 68000
# Processing tile 94000, 70000
# Processing tile 94000, 72000
# Processing tile 94000, 74000
# Processing tile 96000, -2000
# Processing tile 96000, 0
# Processing tile 96000, 2000
# Processing tile 96000, 4000
# Processing tile 96000, 6000
# Processing tile 96000, 8000
# Processing tile 96000, 10000
# Processing tile 96000, 12000
# Processing tile 96000, 14000
# Processing tile 96000, 16000
# Processing tile 96000, 18000
# Processing tile 96000, 20000
# Processing tile 96000, 22000
# Processing tile 96000, 24000
# Processing tile 96000, 26000
# Processing tile 96000, 28000
# Processing tile 96000, 30000
# Processing tile 96000, 32000
# Processing tile 96000, 34000
# Processing tile 96000, 36000
# Processing tile 96000, 38000
# Processing tile 96000, 40000
# Processing tile 96000, 42000
# Processing tile 96000, 44000
# Processing tile 96000, 46000
# Processing tile 96000, 48000
# Processing tile 96000, 50000
# Processing tile 96000, 52000
# Processing tile 96000, 54000
# Processing tile 96000, 56000
# Processing tile 96000, 58000
# Processing tile 96000, 60000
# Processing tile 96000, 62000
# Processing tile 96000, 64000
# Processing tile 96000, 66000
# Processing tile 96000, 68000
# Processing tile 96000, 70000
# Processing tile 96000, 72000
# Processing tile 96000, 74000
# Processing tile 98000, -2000
# Processing tile 98000, 0
# Processing tile 98000, 2000
# Processing tile 98000, 4000
# Processing tile 98000, 6000
# Processing tile 98000, 8000
# Processing tile 98000, 10000
# Processing tile 98000, 12000
# Processing tile 98000, 14000
# Processing tile 98000, 16000
# Processing tile 98000, 18000
# Processing tile 98000, 20000
# Processing tile 98000, 22000
# Processing tile 98000, 24000
# Processing tile 98000, 26000
# Processing tile 98000, 28000
# Processing tile 98000, 30000
# Processing tile 98000, 32000
# Processing tile 98000, 34000
# Processing tile 98000, 36000
# Processing tile 98000, 38000
# Processing tile 98000, 40000
# Processing tile 98000, 42000
# Processing tile 98000, 44000
# Processing tile 98000, 46000
# Processing tile 98000, 48000
# Processing tile 98000, 50000
# Processing tile 98000, 52000
# Processing tile 98000, 54000
# Processing tile 98000, 56000
# Processing tile 98000, 58000
# Processing tile 98000, 60000
# Processing tile 98000, 62000
# Processing tile 98000, 64000
# Processing tile 98000, 66000
# Processing tile 98000, 68000
# Processing tile 98000, 70000
# Processing tile 98000, 72000
# Processing tile 98000, 74000
# Processing tile 100000, -2000
# Processing tile 100000, 0
# Processing tile 100000, 2000
# Processing tile 100000, 4000
# Processing tile 100000, 6000
# Processing tile 100000, 8000
# Processing tile 100000, 10000
# Processing tile 100000, 12000
# Processing tile 100000, 14000
# Processing tile 100000, 16000
# Processing tile 100000, 18000
# Processing tile 100000, 20000
# Processing tile 100000, 22000
# Processing tile 100000, 24000
# Processing tile 100000, 26000
# Processing tile 100000, 28000
# Processing tile 100000, 30000
# Processing tile 100000, 32000
# Processing tile 100000, 34000
# Processing tile 100000, 36000
# Processing tile 100000, 38000
# Processing tile 100000, 40000
# Processing tile 100000, 42000
# Processing tile 100000, 44000
# Processing tile 100000, 46000
# Processing tile 100000, 48000
# Processing tile 100000, 50000
# Processing tile 100000, 52000
# Processing tile 100000, 54000
# Processing tile 100000, 56000
# Processing tile 100000, 58000
# Processing tile 100000, 60000
# Processing tile 100000, 62000
# Processing tile 100000, 64000
# Processing tile 100000, 66000
# Processing tile 100000, 68000
# Processing tile 100000, 70000
# Processing tile 100000, 72000
# Processing tile 100000, 74000
# Processing tile 102000, -2000
# Processing tile 102000, 0
# Processing tile 102000, 2000
# Processing tile 102000, 4000
# Processing tile 102000, 6000
# Processing tile 102000, 8000
# Processing tile 102000, 10000
# Processing tile 102000, 12000
# Processing tile 102000, 14000
# Processing tile 102000, 16000
# Processing tile 102000, 18000
# Processing tile 102000, 20000
# Processing tile 102000, 22000
# Processing tile 102000, 24000
# Processing tile 102000, 26000
# Processing tile 102000, 28000
# Processing tile 102000, 30000
# Processing tile 102000, 32000
# Processing tile 102000, 34000
# Processing tile 102000, 36000
# Processing tile 102000, 38000
# Processing tile 102000, 40000
# Processing tile 102000, 42000
# Processing tile 102000, 44000
# Processing tile 102000, 46000
# Processing tile 102000, 48000
# Processing tile 102000, 50000
# Processing tile 102000, 52000
# Processing tile 102000, 54000
# Processing tile 102000, 56000
# Processing tile 102000, 58000
# Processing tile 102000, 60000
# Processing tile 102000, 62000
# Processing tile 102000, 64000
# Processing tile 102000, 66000
# Processing tile 102000, 68000
# Processing tile 102000, 70000
# Processing tile 102000, 72000
# Processing tile 102000, 74000
# Generated encodings for 1675 tiles.

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# data = e
# plt.imshow(data, cmap='viridis', aspect='equal')  # 'viridis' is a good default colormap
# plt.colorbar(label="Value")  # add a color scale bar
# plt.title("Full Encoding For Tile")
# plt.xlabel("Encoding Index")
# plt.ylabel("Entity Number")
# plt.show()

# %% [markdown]
# ### Initial embedding for this tile

# %%
# Load the initial embedding model.
from utils.geo_transformer_mem import VergeDataset, verge_collate_fn, GeospatialTransformer

transformer = GeospatialTransformer(
    feature_dim = geo_encoding_dim + label_count,
    model_dim=128,
    num_heads=4,
    num_layers=4,
    num_classes=label_count,
    dropout=0.2
)

model_fname = '%s/models/transformer-%s' % (roi_home, transformer_run_id)
transformer = torch.load(model_fname, weights_only=False, map_location=torch.device('cpu'))
print('loaded %s' % model_fname)

n_param = sum(p.numel() for p in transformer.parameters() if p.requires_grad)
print('%d trainable parameters in model' % n_param)
# Out:
# loaded /content/drive/MyDrive/Projects/verge/data/newengland/models/transformer-301b
# 850070 trainable parameters in model

# %%
initials = []
for enc in tile_encodings:
    tile_x = enc['x']
    tile_y = enc['y']
    encoding = enc['encoding']
    input_features = torch.tensor(encoding, dtype=torch.float32).unsqueeze(0)
    input_attention_mask = torch.ones(1, encoding.shape[0], dtype=torch.float32)
    transformed = transformer.embed(input_features, input_attention_mask)
    initials.append({
        'x': tile_x,
        'y': tile_y,
        'initials': transformed
    })

print(f'Generated initial encodings for {len(initials)} tiles.')
# Out:
# Generated initial encodings for 1675 tiles.

# %% [markdown]
# ### Get the final embedding for this tile

# %%
import sys
sys.path.append('%s/03-embeddings' % project_home)
from embedderv5 import ContrastivePairDataset, PermutationInvariantModel, TripletContrastiveLoss, triplet_collate_fn

# %%
# Initialize model
embedding_dim = 128
model = PermutationInvariantModel(
    input_dim=embedding_dim,
    hidden_dim=128,
    embedding_dim=embedding_dim,
    num_attention_heads=8,
    num_linear_layers=3,
    dropout=0.1
)

model_fname = '%s/models/collector-%s.pth' % (roi_home, collector_run_id)
state_dict = torch.load(model_fname, map_location='cpu')
model.load_state_dict(state_dict)
print('loaded %s' % model_fname)

n_param = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('%d trainable parameters in model' % n_param)
# Out:
# loaded /content/drive/MyDrive/Projects/verge/data/newengland/models/collector-301b.pth
# 181768 trainable parameters in model

# %%
finals = []
for item in initials:
    initial_encoding = item['initials']
    # Create a mask of ones with the correct shape
    mask = torch.ones(initial_encoding.shape[0], initial_encoding.shape[1], dtype=torch.bool)
    final_embedding = model(initial_encoding, mask)
    finals.append({
        'x': item['x'],
        'y': item['y'],
        'embedding': final_embedding
    })

print(f'Generated final embeddings for {len(finals)} tiles.')
# Out:
# Generated final embeddings for 1675 tiles.

# %%
final_embeddings_with_bbox = []
for item in finals:
    tile_x = item['x']
    tile_y = item['y']
    embedding = item['embedding']

    # Compute the projected bounding box.
    x0, y0 = tile_x, tile_y
    x1, y1 = tile_x + roi['tile_size'], tile_y + roi['tile_size']

    # Compute the lon/lat bounding box using the inverse projection.
    lon0, lat0 = proj_inverse(x0, y0)
    lon1, lat1 = proj_inverse(x1, y1)

    final_embeddings_with_bbox.append({
        'x': tile_x,
        'y': tile_y,
        'lon0': lon0,
        'lat0': lat0,
        'lon1': lon1,
        'lat1': lat1,
        'center_lon': (lon0 + lon1) / 2,
        'center_lat': (lat0 + lat1) / 2,
        'embedding': embedding.detach().numpy()
    })

print(f'Added bounding boxes to {len(final_embeddings_with_bbox)} final embeddings.')
# Out:
# Added bounding boxes to 1675 final embeddings.

# %%
# Save the final embeddings.
output_dir = '%s/batch' % roi_home
os.makedirs(output_dir, exist_ok=True)
output_fname = '%s/final_embeddings.pkl' % output_dir

with open(output_fname, 'wb') as f:
    pickle.dump(final_embeddings_with_bbox, f)

print(f'Saved final embeddings to {output_fname}')
# Out:
# Saved final embeddings to /content/drive/MyDrive/Projects/verge/data/newengland/batch/final_embeddings.pkl

# %%
final_embeddings_with_bbox[0]
# Out:
# {'x': 18000,
#  'y': -2000,
#  'lon0': -73.3521755996241,
#  'lat0': 41.23948811568884,
#  'lon1': -73.32903193563504,
#  'lat1': 41.258002984570936,
#  'center_lon': -73.34060376762957,
#  'center_lat': 41.24874555012989,
#  'embedding': tensor([[ 0.1226,  0.1253,  0.0624, -0.0276,  0.0058, -0.0468, -0.0587,  0.0276,
#            0.0735,  0.0134, -0.0315,  0.0084,  0.0529, -0.1288, -0.0113,  0.0712,
#            0.0266, -0.0669,  0.1829,  0.0249, -0.1040, -0.0464,  0.0283,  0.0196,
#            0.1110, -0.0031,  0.0448,  0.0259,  0.0220, -0.0563,  0.1468, -0.0820,
#            0.0151, -0.0379,  0.1925,  0.0358,  0.0018,  0.0738, -0.0986, -0.0453,
#           -0.1817,  0.0299,  0.1155,  0.0174,  0.0861, -0.0219, -0.1890, -0.0992,
#           -0.0563,  0.0879,  0.0296,  0.0460, -0.0008,  0.1291,  0.0423, -0.0369,
#            0.0289,  0.0357, -0.0196,  0.0557,  0.2025, -0.1655, -0.0492, -0.0721,
#            0.0910,  0.0327, -0.0842, -0.0967, -0.0874, -0.0180,  0.0937, -0.0199,
#           -0.0697,  0.0723,  0.1852,  0.0110, -0.0198,  0.1275,  0.0735,  0.0135,
#            0.0877,  0.0667, -0.1098, -0.1066, -0.0255, -0.0542,  0.0500,  0.0995,
#           -0.0409, -0.2078, -0.0313, -0.1324,  0.1130, -0.0993,  0.0272, -0.0707,
#            0.1829, -0.1064, -0.0283, -0.0438, -0.0428, -0.1193,  0.0587, -0.1019,
#            0.1425,  0.0580,  0.0106,  0.1435,  0.0006, -0.0614, -0.0703,  0.0641,
#           -0.0717, -0.0182, -0.0351,  0.0494, -0.1026,  0.1874,  0.1605,  0.0627,
#            0.1521, -0.0163, -0.0818,  0.0354,  0.0221,  0.1529,  0.1374,  0.0837]],
#         grad_fn=<DivBackward0>)}
