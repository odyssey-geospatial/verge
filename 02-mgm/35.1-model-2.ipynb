# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Encoding
# # Masked Geospatial Model Implementation
#
# Here we build and train a "masked geospatial model".
# This is a model in which each input is a set of encoded geospatial entities,
# consisting of a concatenation of a multi-point proximity encoding and a one-hot label vector.
# Modeling consists of masking the labels for a random selection of entities,
# passing the data through an encoder-based architecutre to predicte the labels of masked entities.
# The idea is that the encodings then capture information about the region.

# %% [markdown]
# ## Processing Setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# Out:
# Mounted at /content/drive

# %%
# !pip install geo_encodings
# Out:
# Collecting geo_encodings
#   Downloading geo_encodings-1.0.4-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geo_encodings) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo_encodings) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geo_encodings) (2.0.2)
# Downloading geo_encodings-1.0.4-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: geo_encodings
# Successfully installed geo_encodings-1.0.4

# %%
# Local processing setup
# project_home = '..'

# %% [markdown]
# ## Source

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import glob
import pickle
import os
import torch
import torch.nn as nn
import torch.utils
import torch.utils.data
from torch.utils.data import DataLoader
import copy
import json
from geo_encodings import MPPEncoder
from utils.geo_transformer import VergeDataset, verge_collate_fn, GeospatialTransformer

# %% [markdown]
# ## Parameters

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
encoding_resolution = roi['encoding_resolution']

# We need the dimension of the encoding.
encoder = MPPEncoder(
    region=[0, 0, tile_size, tile_size],
    resolution=encoding_resolution,
    center=True
)
geo_encoding_dim = len(encoder)
print('%d elements in encodings' % geo_encoding_dim)
# Out:
# 400 elements in encodings

# %%
# A unique identifier for this run. This will be a component of any
# output file names.
run_id = '004'

# What type of device to train on.
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('using device', device)

# Fraction of cases to use for training.
train_fraction = 0.8

# Number of epochs to run.
epoch_count = 100
# Out:
# using device cuda

# %% [markdown]
# ## Preliminaries

# %%
# Read the list of labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)
n_classes = len(labels)
print('%d labels in this dataset' % n_classes)

label_id_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}

label_name_lookup = {
    z['id']: z['label']
    for z in labels.to_dict('records')
}
# Out:
# 22 labels in this dataset

# %% [markdown]
# ## Load data

# %%
# Get a list of input data files. Each file consists of a list of encodings for
# a number of square tiles in a particluar AOI.
globstring = '%s/encodings/*' % roi_home
fnames = glob.glob(globstring)
print('%d input files with encodings' % len(fnames))
# Out:
# 263 input files with encodings

# %%
# Split the dataset into training and validation components based on AOI.
# This minimizes the possibility of spatial autocorrelation biasing performance assessments.
splits = []
for fname in fnames:
  if np.random.random() < train_fraction:
    splits.append({'fname': fname, 'type': 'train'})
  else:
    splits.append({'fname': fname, 'type': 'val'})

# Save that.
fname = '%s/split-%s.csv' % (roi_home, run_id)
pd.DataFrame(splits).to_csv(fname, index=False)
print('saved %s' % fname)
# Out:
# saved /content/drive/MyDrive/Projects/verge/data/newengland/split-004.csv

# %%
# Read all data. This input consists of the endoded geospatial features
# for individual tiles, concatenated with one-hot vectors indicating
# their class.
#
# Each input file contains data for all tiles in an AOI. We split into
# training and validation sets based on AOI to avoid
#

split_lookup = {
    z['fname'] : z['type']
    for z in splits
}

train_tiles = []
val_tiles = []

for k, fname in enumerate(fnames):
    print('reading %s (%d / %d)' % (fname, k, len(fnames)))
    with open(fname, 'rb') as source:
        data =  pickle.load(source)
        sp = split_lookup[fname]
        if sp == 'train':
            train_tiles += data
        else:
            val_tiles += data

print('%d training tiles' % len(train_tiles))
print('%d validation tiles' % len(val_tiles))
# Out:
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-413n.pkl (0 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-414n.pkl (1 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-415n.pkl (2 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-446n.pkl (3 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0734w-414n.pkl (4 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-413n.pkl (5 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-414n.pkl (6 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-423n.pkl (7 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-424n.pkl (8 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-444n.pkl (9 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-445n.pkl (10 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-413n.pkl (11 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-415n.pkl (12 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-418n.pkl (13 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-426n.pkl (14 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-444n.pkl (15 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-445n.pkl (16 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-413n.pkl (17 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-414n.pkl (18 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-415n.pkl (19 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-416n.pkl (20 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-418n.pkl (21 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-413n.pkl (22 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-414n.pkl (23 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-415n.pkl (24 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-416n.pkl (25 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-417n.pkl (26 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-436n.pkl (27 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-413n.pkl (28 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-414n.pkl (29 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-415n.pkl (30 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-416n.pkl (31 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-417n.pkl (32 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-418n.pkl (33 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-413n.pkl (34 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-414n.pkl (35 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-415n.pkl (36 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-416n.pkl (37 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-417n.pkl (38 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-418n.pkl (39 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-419n.pkl (40 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-420n.pkl (41 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-421n.pkl (42 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-413n.pkl (43 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-415n.pkl (44 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-416n.pkl (45 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-417n.pkl (46 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-418n.pkl (47 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-419n.pkl (48 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-420n.pkl (49 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-421n.pkl (50 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-422n.pkl (51 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-423n.pkl (52 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-416n.pkl (53 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-417n.pkl (54 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-418n.pkl (55 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-419n.pkl (56 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-420n.pkl (57 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-421n.pkl (58 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-422n.pkl (59 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-423n.pkl (60 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-442n.pkl (61 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-413n.pkl (62 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-418n.pkl (63 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-419n.pkl (64 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-420n.pkl (65 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-421n.pkl (66 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0724w-421n.pkl (67 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0724w-436n.pkl (68 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-413n.pkl (69 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-417n.pkl (70 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-429n.pkl (71 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-436n.pkl (72 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-413n.pkl (73 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-414n.pkl (74 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-415n.pkl (75 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-413n.pkl (76 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-414n.pkl (77 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-415n.pkl (78 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-413n.pkl (79 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-422n.pkl (80 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-425n.pkl (81 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-413n.pkl (82 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-418n.pkl (83 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-420n.pkl (84 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-421n.pkl (85 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-422n.pkl (86 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-423n.pkl (87 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-425n.pkl (88 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-421n.pkl (89 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-422n.pkl (90 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-423n.pkl (91 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-424n.pkl (92 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-425n.pkl (93 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-420n.pkl (94 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-421n.pkl (95 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-422n.pkl (96 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-423n.pkl (97 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-424n.pkl (98 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-425n.pkl (99 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-428n.pkl (100 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-416n.pkl (101 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-417n.pkl (102 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-418n.pkl (103 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-419n.pkl (104 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-420n.pkl (105 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-421n.pkl (106 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-422n.pkl (107 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-423n.pkl (108 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-424n.pkl (109 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-425n.pkl (110 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-426n.pkl (111 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-427n.pkl (112 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-428n.pkl (113 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-429n.pkl (114 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-432n.pkl (115 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-414n.pkl (116 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-415n.pkl (117 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-416n.pkl (118 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-417n.pkl (119 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-418n.pkl (120 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-419n.pkl (121 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-420n.pkl (122 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-421n.pkl (123 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-422n.pkl (124 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-423n.pkl (125 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-424n.pkl (126 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-425n.pkl (127 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-426n.pkl (128 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-427n.pkl (129 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-428n.pkl (130 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-429n.pkl (131 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-430n.pkl (132 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-435n.pkl (133 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-417n.pkl (134 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-418n.pkl (135 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-419n.pkl (136 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-420n.pkl (137 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-421n.pkl (138 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-422n.pkl (139 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-423n.pkl (140 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-424n.pkl (141 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-425n.pkl (142 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-426n.pkl (143 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-427n.pkl (144 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-428n.pkl (145 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-429n.pkl (146 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-415n.pkl (147 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-416n.pkl (148 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-417n.pkl (149 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-419n.pkl (150 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-420n.pkl (151 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-421n.pkl (152 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-422n.pkl (153 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-423n.pkl (154 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-424n.pkl (155 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-425n.pkl (156 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-426n.pkl (157 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-427n.pkl (158 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-428n.pkl (159 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-416n.pkl (160 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-417n.pkl (161 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-418n.pkl (162 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-419n.pkl (163 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-420n.pkl (164 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-421n.pkl (165 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-422n.pkl (166 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-423n.pkl (167 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-424n.pkl (168 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-425n.pkl (169 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-426n.pkl (170 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-427n.pkl (171 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-428n.pkl (172 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-416n.pkl (173 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-418n.pkl (174 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-419n.pkl (175 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-420n.pkl (176 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-421n.pkl (177 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-422n.pkl (178 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-423n.pkl (179 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-424n.pkl (180 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-425n.pkl (181 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-426n.pkl (182 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-427n.pkl (183 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-428n.pkl (184 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-416n.pkl (185 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-417n.pkl (186 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-418n.pkl (187 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-419n.pkl (188 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-420n.pkl (189 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-421n.pkl (190 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-422n.pkl (191 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-424n.pkl (192 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-425n.pkl (193 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-426n.pkl (194 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-427n.pkl (195 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-428n.pkl (196 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-429n.pkl (197 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-430n.pkl (198 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-432n.pkl (199 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-433n.pkl (200 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-416n.pkl (201 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-420n.pkl (202 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-421n.pkl (203 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-422n.pkl (204 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-425n.pkl (205 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-426n.pkl (206 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-428n.pkl (207 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-429n.pkl (208 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-430n.pkl (209 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-431n.pkl (210 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-432n.pkl (211 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-417n.pkl (212 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-419n.pkl (213 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-420n.pkl (214 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-421n.pkl (215 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-422n.pkl (216 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-430n.pkl (217 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-431n.pkl (218 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-415n.pkl (219 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-416n.pkl (220 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-417n.pkl (221 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-419n.pkl (222 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-420n.pkl (223 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-426n.pkl (224 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-431n.pkl (225 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-414n.pkl (226 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-415n.pkl (227 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-416n.pkl (228 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-417n.pkl (229 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-418n.pkl (230 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-433n.pkl (231 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-416n.pkl (232 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-417n.pkl (233 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-434n.pkl (234 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-435n.pkl (235 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-438n.pkl (236 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-416n.pkl (237 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-435n.pkl (238 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-436n.pkl (239 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-437n.pkl (240 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-416n.pkl (241 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-436n.pkl (242 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-437n.pkl (243 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-440n.pkl (244 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-416n.pkl (245 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-417n.pkl (246 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-440n.pkl (247 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-416n.pkl (248 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-417n.pkl (249 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-419n.pkl (250 / 263)
# reading /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-417n.pkl (251 / 263)

# %%
# # Test that.
# dataset = VergeDataset(train_tiles, n_classes, mask_fraction=0.15)
# batch = [dataset[k] for k in [0, 12, 17, 23]]
# batch_features, batch_labels, batch_attention_mask = verge_collate_fn(batch)
# print('test:')
# print('batch_features.shape', batch_features.shape)
# print('batch_labels.shape', batch_labels.shape)
# print('batch_attention_mask.shape', batch_attention_mask.shape)

# %%
from torch.utils.data import DataLoader

# Initialize training and validation datasets.

train_dataset = VergeDataset(train_tiles, n_classes, mask_fraction=0.15)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8, # Tune depending on GPU memory
    shuffle=True,
    collate_fn=verge_collate_fn,
    drop_last=False
)

val_dataset = VergeDataset(val_tiles, n_classes, mask_fraction=0.15)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=8, # Tune depending on GPU memory
    shuffle=True,
    collate_fn=verge_collate_fn,
    drop_last=False
)

# %% [markdown]
# ## Model definition

# %%
model = GeospatialTransformer(
    feature_dim = geo_encoding_dim + n_classes,
    model_dim=128,
    num_heads=4,
    num_layers=5,
    num_classes=n_classes,
    dropout=0.2
)
n_param = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('%d trainable parameters in model' % n_param)

# %%
# Testing
# dataset = VergeDataset(train_tiles, n_classes, mask_fraction=0.15)
# dataloader = DataLoader(
#     dataset,
#     batch_size=2,            # Tune depending on GPU memory
#     shuffle=True,
#     collate_fn=verge_collate_fn,   # Key for padding variable-length instances
#     drop_last=False
# )

# features, labels, attention_mask = dataloader.__iter__().__next__()
# print(features.shape, labels.shape, attention_mask.shape)

# %%
# model(features, attention_mask)

# %% [markdown]
# ### Training loop

# %%
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss(ignore_index=-100)

losses = []

model.train()
for epoch in range(epoch_count):

    # Training.
    model.train()
    for features, labels, attention_mask in train_dataloader:
        features = features.to(device)
        labels = labels.to(device)
        attention_mask = attention_mask.to(device)

        logits = model(features, attention_mask)
        loss = criterion(
            logits.view(-1, n_classes),
            labels.view(-1)
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Validation loss
    model.eval()
    with torch.no_grad():
        for features, labels, attention_mask in val_dataloader:
            features = features.to(device)
            labels = labels.to(device)
            attention_mask = attention_mask.to(device)
            logits = model(features, attention_mask)
            val_loss = criterion(
                logits.view(-1, n_classes),
                labels.view(-1)
            )

    losses.append({
        'epoch': epoch,
        'train_loss': loss.item(),
        'val_loss': val_loss.item()
    })

    print(f"Epoch {epoch+1}, train loss: {loss.item():.4f}, val_loss: {val_loss.item():.4f}")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 330, in _lazy_init
#     queued_call()
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 1584, in _register_triton_kernels
#     has_triton = importlib.util.find_spec("triton") is not None
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib.util>", line 104, in find_spec
#   File "<frozen importlib._bootstrap>", line 1078, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1507, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1476, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1434, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-18-1646769471.py", line 1, in <cell line: 0>
#     model.to(device)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1343, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 903, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1329, in convert
#     return t.to(
#            ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 336, in _lazy_init
#     raise DeferredCudaCallError(msg) from e
# torch.cuda.DeferredCudaCallError: CUDA call failed lazily at initialization with error: [Errno 107] Transport endpoint is not connected
#
# CUDA call was originally invoked at:
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-5-249994962.py", line 6, in <cell line: 0>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2046, in <module>
#     _C._initExtension(_manager_path())
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 1604, in <module>
#     _lazy_call(_register_triton_kernels)
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 261, in _lazy_call
#     _queued_calls.append((callable, traceback.format_stack()))
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'DeferredCudaCallError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1684, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 948, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 980, in getmodule
#     file = getabsfile(object, _filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 964, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 404, in abspath
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 330, in _lazy_init
#     queued_call()
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 1584, in _register_triton_kernels
#     has_triton = importlib.util.find_spec("triton") is not None
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib.util>", line 104, in find_spec
#   File "<frozen importlib._bootstrap>", line 1078, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1507, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1476, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1434, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-18-1646769471.py", line 1, in <cell line: 0>
#     model.to(device)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1343, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 903, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1329, in convert
#     return t.to(
#            ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 336, in _lazy_init
#     raise DeferredCudaCallError(msg) from e
# torch.cuda.DeferredCudaCallError: CUDA call failed lazily at initialization with error: [Errno 107] Transport endpoint is not connected
#
# CUDA call was originally invoked at:
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-5-249994962.py", line 6, in <cell line: 0>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2046, in <module>
#     _C._initExtension(_manager_path())
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 1604, in <module>
#     _lazy_call(_register_triton_kernels)
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 261, in _lazy_call
#     _queued_calls.append((callable, traceback.format_stack()))
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'DeferredCudaCallError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1684, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 948, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 980, in getmodule
#     file = getabsfile(object, _filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 964, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 404, in abspath
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 330, in _lazy_init
#     queued_call()
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 1584, in _register_triton_kernels
#     has_triton = importlib.util.find_spec("triton") is not None
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib.util>", line 104, in find_spec
#   File "<frozen importlib._bootstrap>", line 1078, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1507, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1476, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1434, in _path_importer_cache
# OSError: [Errno 107] Transport endpoint is not connected
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-18-1646769471.py", line 1, in <cell line: 0>
#     model.to(device)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1343, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 903, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1329, in convert
#     return t.to(
#            ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 336, in _lazy_init
#     raise DeferredCudaCallError(msg) from e
# torch.cuda.DeferredCudaCallError: CUDA call failed lazily at initialization with error: [Errno 107] Transport endpoint is not connected
#
# CUDA call was originally invoked at:
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-5-249994962.py", line 6, in <cell line: 0>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2046, in <module>
#     _C._initExtension(_manager_path())
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 1604, in <module>
#     _lazy_call(_register_triton_kernels)
#   File "/usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py", line 261, in _lazy_call
#     _queued_calls.append((callable, traceback.format_stack()))
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'DeferredCudaCallError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1684, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 948, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 980, in getmodule
#     file = getabsfile(object, _filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 964, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 404, in abspath
# OSError: [Errno 107] Transport endpoint is not connected

# %%
# Save the model.
model_fname = '%s/model-%s' % (roi_home, run_id)
torch.save(model, model_fname)
print('saved %s' % model_fname)

# %% [markdown]
# ## Loss history

# %%
import plotly
from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter

epochs = [d['epoch'] for d in losses]
train_losses = [d['train_loss'] for d in losses]
val_losses = [d['val_loss'] for d in losses]

fig = make_subplots(rows=1, cols=1)
trace = Scatter(
    x=epochs, y=train_losses, name='training loss',
    mode='markers+lines', marker_color='blue'
)
fig.append_trace(trace, 1, 1)

trace = Scatter(
    x=epochs, y=val_losses, name='validation loss',
    mode='markers+lines', marker_color='green'
)
fig.append_trace(trace, 1, 1)

fig

# %% [markdown]
# ## Validation Visualization

# %%
# Process the validation dataset, getting the class probability predictions
# for every instance.
model.to(device)
cases = []
model.eval()
for features, labels, attention_mask in val_dataloader:

    features = features.to(device)
    attention_mask = attention_mask.to(device)
    labels = labels.to(device)

    logits = model(features, attention_mask)

    batch_size = logits.shape[0]
    for i in range(batch_size):
        case_logits = logits[i]
        case_probs = torch.softmax(case_logits, dim=1)
        case_labels = labels[i]
        entity_count = len(case_labels)
        for k in range(entity_count):
            if case_labels[k].item() >= 0: # Skips the "-100" labels.
                cases.append({
                    'true_label': case_labels[k].item(),
                    'probs': torch.Tensor.cpu(case_probs[k, :]).detach().numpy()
                })

print('compiled prediction probabilities for %d validation instances' % len(cases))

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

class_count = max(d["true_label"] for d in cases) + 1
probs_by_class = defaultdict(list)

for d in cases:
    label = d["true_label"]
    probs = np.array(d["probs"])
    probs_by_class[label].append(probs)

# For each true class, compute the mean probability vector
mean_probs = []
for t in range(class_count):
    if probs_by_class[t]:
        mean = np.stack(probs_by_class[t]).mean(axis=0)
    else:
        mean = np.zeros(class_count)  # if no samples for this class
    mean_probs.append(mean)

# Convert to 2D array: [true_class, predicted_class]
matrix = np.stack(mean_probs)  # shape [C, C]

# Plot heatmap
fig, ax = plt.subplots(figsize=(9, 6))
im = ax.imshow(matrix, cmap='viridis', aspect='auto')

plt.colorbar(im, ax=ax, label='Avg Predicted Probability')
ax.set_title("Mean Predicted Probabilities by True Class")
ax.set_xlabel("Predicted Class")
ax.set_ylabel("True Class")
ax.set_xticks(range(class_count))
ax.set_yticks(range(class_count))
ax.set_yticklabels([label_name_lookup[i] for i in range(class_count)])
plt.tight_layout()
plt.show()

# %%
# class_count = max(d["true_label"] for d in cases) + 1
# print(class_count)
# cmat = np.zeros((class_count, class_count))

# for d in cases:
#     true_label = d["true_label"]
#     pred_label = np.argmax(d["probs"])
#     cmat[true_label, pred_label] += 1

# cmat = np.sqrt(cmat)

# # Plot heatmap
# fig, ax = plt.subplots(figsize=(12, 8))
# im = ax.imshow(cmat, cmap='viridis', aspect='auto')

# plt.colorbar(im, ax=ax, label='Number Of Cases')
# ax.set_title("Confusion Matrix")
# ax.set_xlabel("Predicted Class")
# ax.set_ylabel("True Class")
# ax.set_xticks(range(class_count))
# ax.set_yticks(range(class_count))
# ax.set_yticklabels(['%s [%d]' % (label_name_lookup[i], i) for i in range(class_count)])
# plt.tight_layout()
# plt.show()
