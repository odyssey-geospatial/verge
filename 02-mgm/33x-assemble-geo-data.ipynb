# %% [markdown]
# ### This version only re-creates the "tiles.csv" file.
# Delete this when that;s done.

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# !pip install osmnx pygeohash geo-encodings
# Out:
# Mounted at /content/drive
# Collecting osmnx
#   Downloading osmnx-2.0.6-py3-none-any.whl.metadata (4.9 kB)
# Collecting pygeohash
#   Downloading pygeohash-3.2.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Collecting geo-encodings
#   Downloading geo_encodings-1.0.4-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (1.16.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Downloading osmnx-2.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 1.0 MB/s eta 0:00:00
# Downloading pygeohash-3.2.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 kB 2.2 MB/s eta 0:00:00
# Downloading geo_encodings-1.0.4-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pygeohash, geo-encodings, osmnx
# Successfully installed geo-encodings-1.0.4 osmnx-2.0.6 pygeohash-3.2.0

# %%
# # Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook setup

# %%
import numpy as np
import pandas as pd
import pyproj
import shapely
import osmnx
import pygeohash
import geopandas as gpd
import os
import copy
import json

import plotly
from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter

from geo_encodings import draw_shape

import sys
sys.path.append(project_home)
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# A tile has to contain this many entities in order to be retained.
min_entity_count = 20

# Set to True if we want to include the overall land/water polygon for each tile.
include_land_water = True

# If not None, then only process this many AOIs
aoi_limit = None

# %% [markdown]
# ## Preliminaries

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %%
# Define a local map projection, using the definition from the ROI file.
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse

proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# This function gets an overall land/water polygon for an AOI.
# It does it by conasidering both the "coastlines" shapefile
# and all polygonal water features.

# Read the coastline file.
if include_land_water:
    fname = '%s/coastlines' % (roi_home)
    coastlines_gdf = gpd.read_file(fname)
    print('%d coastline polygons' % len(coastlines_gdf))

def get_land_water(bounds, features):

    # Create a baseline polygon consisting of the whole AOI.
    landwater = copy.deepcopy(bounds)

    # Intersect that with the coastlines data.
    coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
    landwater = landwater.intersection(coastlines)

    # subtract out any polygonal water feature.
    for _, f in features.iterrows():
        if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
            if f['natural'] == 'water':
                landwater = shapely.difference(landwater, f['geometry'])

    return landwater
# Out:
# 3514 coastline polygons

# %% [markdown]
# ## Processing

# %%
# Read the file with the list of AOIs
fname = '%s/aois.csv' % (roi_home)
aois = pd.read_csv(fname).to_dict('records')
# aois = np.random.permutation(aois)
print('%d areas of interest' % len(aois))
# Out:
# 263 areas of interest

# %%
aois[0]
# Out:
# {'aoi_tag': '0735w-413n',
#  'lon0': -73.5,
#  'lat0': 41.3,
#  'lon1': -73.4,
#  'lat1': 41.4}

# %%
# This will save some extra info that we will need.
tile_info = []

if aoi_limit is None:
    aoi_list = aois
else:
    aoi_list = aois[:aoi_limit]

for k, aoi in enumerate(aoi_list):

    print('\nprocessing AOI %s (%d / %d)' % (aoi['aoi_tag'], k, len(aoi_list)))

    # Use that projection to define lon/lat bounds for the query below. Make sure the bounds go
    # a little farther out than necessary to avoid edge artifacts from map projections.
    buffer = 0.01
    lon0 = aoi['lon0'] - buffer
    lat0 = aoi['lat0'] - buffer
    lon1 = aoi['lon1'] + buffer
    lat1 = aoi['lat1'] + buffer
    query_bounds = [lon0, lat0, lon1, lat1]

    # print('re-projected query bounds, with buffer:')
    # print(proj_forward(lon0, lat0))
    # print(proj_forward(lon1, lat1))

    # Query for all the geospatial entities we need within the bounding box.
    tags = {
        'landuse': True,
        'place': True,
        'highway': True,
        'railway': True,
        #'aeroway': True,
        'bridge': True,
        'tunnel': True,
        #'power': True,
        'natural': True,
        'waterway': True,
        'landcover': True,
        #'building': True,
        'amenity': True,
        'shop': True,
        'leisure': True
    }
    # features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
    # print('%d features from OSM' % len(features))

    # # Re-format and filter everything.
    # # BTW, "gents" is "geospatial entities".
    # gents = []
    # for feature in features.to_dict('records'):

    #     geomxy = shapely.ops.transform(proj_forward, feature['geometry'])
    #     if geomxy.is_empty:
    #         continue
    #     gtype = geomxy.geom_type

    #     for rule in rules:
    #         if gtype == rule['gtype']:
    #             osm_key = rule['osm_key']
    #             if osm_key in feature:
    #                 osm_value = str(feature[osm_key])
    #                 if osm_value in rule['osm_values']:
    #                     gents.append({
    #                         'feature': feature,
    #                         'category': rule['gent_category'],
    #                         'label': rule['gent_label'],
    #                         'geomxy': geomxy,
    #                         'gtype': gtype
    #                     })
    # print('%d features selected' % len(gents))

    # We need some special handling to create a general "land/water" polygon.
    # if include_land_water:
    #     lons = [lon0, lon1, lon1, lon0, lon0]
    #     lats = [lat0, lat0, lat1, lat1, lat0]
    #     lonlat_bounds = shapely.Polygon(list(zip(lons, lats)))
    #     landwater = get_land_water(lonlat_bounds, features)
    #     landwaterxy = shapely.ops.transform(proj_forward, landwater)
    #     gents.append({
    #         'category': 'waterway',
    #         'label': 'land',
    #         'geomxy': landwaterxy,
    #         'gtype': landwaterxy.geom_type
    #     })

    # Determine the AOI bounds in projected coordinates.
    aoi_x0, aoi_y0 = proj_forward(aoi['lon0'], aoi['lat0'])
    aoi_x1, aoi_y1 = proj_forward(aoi['lon1'], aoi['lat1'])

    # Loop over tiles within this AOI.
    x0 = aoi_x0
    while x0 + tile_size < aoi_x1:

        y0 = aoi_y0
        while y0 + tile_size < aoi_y1:

            # print('tile xo, yo:', x0, y0)

            # Figure out the lon/lat center of this tile. We will need it
            # for some later processing.
            tile_lon0, tile_lat0 = proj_inverse(x0, y0)
            tile_lon1, tile_lat1 = proj_inverse(x0 + tile_size, y0 + tile_size)
            tile_lon_center = (tile_lon0 + tile_lon1) / 2
            tile_lat_center = (tile_lat0 + tile_lat1) / 2
            # xc = x0 + tile_size / 2
            # yc = y0 + tile_size / 2
            # tile_lon, tile_lat = proj_inverse(xc, yc)
            # print('tile lon, lat', tile_lon, tile_lat)

            # Define a bounding box in projected coordinates. It will be used
            # to clip geospatial entities below.
            x1 = x0 + tile_size
            y1 = y0 + tile_size
            xx = [x0, x1, x1, x0, x0]
            yy = [y0, y0, y1, y1, y0]
            tile_bbox = shapely.Polygon(list(zip(xx, yy)))

            # tile_gents = []
            # for gent in gents:
            #     geomxy = shapely.affinity.translate(
            #         gent['geomxy'].intersection(tile_bbox),
            #         xoff=-x0, yoff=-y0
            #     )
            #     if geomxy.is_empty:
            #         continue
            #     tile_gents.append({
            #         'category': gent['category'],
            #         'label': gent['label'],
            #         'geometry': geomxy,
            #         'gtype': gent['gtype'],
            #         'xoff': x0,
            #         'yoff': y0,
            #     })
            # print('%d geospatial entities' % len(tile_gents))
            tx = '%03d' % (x0 / tile_shift)
            ty = '%03d' % (y0 / tile_shift)
            tile_tag = '%s-%s' % (tx, ty)
            fname = '%s/tiles/%s/%s.pq' % (roi_home, aoi['aoi_tag'], tile_tag)
            if os.path.exists(fname):
                # Save the tile info.
                tile_info.append({
                    'aoi_tag': aoi['aoi_tag'],
                    'tile_tag': tile_tag,
                    'lon0': tile_lon0,
                    'lat0': tile_lat0,
                    'lon1': tile_lon1,
                    'lat1': tile_lat1,
                    'center_lon': tile_lon_center,
                    'center_lat': tile_lat_center,
                })

            # # Save that if it's big enough.
            # if len(tile_gents) >= min_entity_count:
            #     tx = '%03d' % (x0 / tile_shift)
            #     ty = '%03d' % (y0 / tile_shift)
            #     tile_tag = '%s-%s' % (tx, ty)
            #     fname = '%s/tiles/%s/%s.pq' % (roi_home, aoi['aoi_tag'], tile_tag)
            #     os.makedirs(os.path.dirname(fname), exist_ok=True)
            #     gdf = gpd.GeoDataFrame(tile_gents).drop_duplicates()
            #     gdf.to_parquet(fname, index=False, compression="zstd")
            #     print('saved %s (%4d entities)' % (fname, len(gdf)))

            #     # Save the tile info.
            #     tile_info.append({
            #         'aoi_tag': aoi['aoi_tag'],
            #         'tile_tag': tile_tag,
            #         'lon0': tile_lon0,
            #         'lat0': tile_lat0,
            #         'lon1': tile_lon1,
            #         'lat1': tile_lat1,
            #         'center_lon': tile_lon_center,
            #         'center_lat': tile_lat_center,
            #     })

            y0 += tile_shift
        x0 += tile_shift

# Save the tile info.
fname = '%s/tiles2.csv' % roi_home
pd.DataFrame(tile_info).to_csv(fname, index=False)
print('\nsaved tile info in %s' % fname)
# Out:
# processing AOI 0735w-413n (0 / 263)
#
# processing AOI 0735w-414n (1 / 263)
#
# processing AOI 0735w-415n (2 / 263)
#
# processing AOI 0735w-446n (3 / 263)
#
# processing AOI 0734w-414n (4 / 263)
#
# processing AOI 0733w-413n (5 / 263)
#
# processing AOI 0733w-414n (6 / 263)
#
# processing AOI 0733w-423n (7 / 263)
#
# processing AOI 0733w-424n (8 / 263)
#
# processing AOI 0733w-444n (9 / 263)
#
# processing AOI 0733w-445n (10 / 263)
#
# processing AOI 0732w-413n (11 / 263)
#
# processing AOI 0732w-415n (12 / 263)
#
# processing AOI 0732w-418n (13 / 263)
#
# processing AOI 0732w-426n (14 / 263)
#
# processing AOI 0732w-444n (15 / 263)
#
# processing AOI 0732w-445n (16 / 263)
#
# processing AOI 0731w-413n (17 / 263)
#
# processing AOI 0731w-414n (18 / 263)
#
# processing AOI 0731w-415n (19 / 263)
#
# processing AOI 0731w-416n (20 / 263)
#
# processing AOI 0731w-418n (21 / 263)
#
# processing AOI 0730w-413n (22 / 263)
#
# processing AOI 0730w-414n (23 / 263)
#
# processing AOI 0730w-415n (24 / 263)
#
# processing AOI 0730w-416n (25 / 263)
#
# processing AOI 0730w-417n (26 / 263)
#
# processing AOI 0730w-436n (27 / 263)
#
# processing AOI 0729w-413n (28 / 263)
#
# processing AOI 0729w-414n (29 / 263)
#
# processing AOI 0729w-415n (30 / 263)
#
# processing AOI 0729w-416n (31 / 263)
#
# processing AOI 0729w-417n (32 / 263)
#
# processing AOI 0729w-418n (33 / 263)
#
# processing AOI 0728w-413n (34 / 263)
#
# processing AOI 0728w-414n (35 / 263)
#
# processing AOI 0728w-415n (36 / 263)
#
# processing AOI 0728w-416n (37 / 263)
#
# processing AOI 0728w-417n (38 / 263)
#
# processing AOI 0728w-418n (39 / 263)
#
# processing AOI 0728w-419n (40 / 263)
#
# processing AOI 0728w-420n (41 / 263)
#
# processing AOI 0728w-421n (42 / 263)
#
# processing AOI 0727w-413n (43 / 263)
#
# processing AOI 0727w-415n (44 / 263)
#
# processing AOI 0727w-416n (45 / 263)
#
# processing AOI 0727w-417n (46 / 263)
#
# processing AOI 0727w-418n (47 / 263)
#
# processing AOI 0727w-419n (48 / 263)
#
# processing AOI 0727w-420n (49 / 263)
#
# processing AOI 0727w-421n (50 / 263)
#
# processing AOI 0727w-422n (51 / 263)
#
# processing AOI 0727w-423n (52 / 263)
#
# processing AOI 0726w-416n (53 / 263)
#
# processing AOI 0726w-417n (54 / 263)
#
# processing AOI 0726w-418n (55 / 263)
#
# processing AOI 0726w-419n (56 / 263)
#
# processing AOI 0726w-420n (57 / 263)
#
# processing AOI 0726w-421n (58 / 263)
#
# processing AOI 0726w-422n (59 / 263)
#
# processing AOI 0726w-423n (60 / 263)
#
# processing AOI 0726w-442n (61 / 263)
#
# processing AOI 0725w-413n (62 / 263)
#
# processing AOI 0725w-418n (63 / 263)
#
# processing AOI 0725w-419n (64 / 263)
#
# processing AOI 0725w-420n (65 / 263)
#
# processing AOI 0725w-421n (66 / 263)
#
# processing AOI 0724w-421n (67 / 263)
#
# processing AOI 0724w-436n (68 / 263)
#
# processing AOI 0723w-413n (69 / 263)
#
# processing AOI 0723w-417n (70 / 263)
#
# processing AOI 0723w-429n (71 / 263)
#
# processing AOI 0723w-436n (72 / 263)
#
# processing AOI 0722w-413n (73 / 263)
#
# processing AOI 0722w-414n (74 / 263)
#
# processing AOI 0722w-415n (75 / 263)
#
# processing AOI 0721w-413n (76 / 263)
#
# processing AOI 0721w-414n (77 / 263)
#
# processing AOI 0721w-415n (78 / 263)
#
# processing AOI 0720w-413n (79 / 263)
#
# processing AOI 0720w-422n (80 / 263)
#
# processing AOI 0720w-425n (81 / 263)
#
# processing AOI 0719w-413n (82 / 263)
#
# processing AOI 0719w-418n (83 / 263)
#
# processing AOI 0719w-420n (84 / 263)
#
# processing AOI 0719w-421n (85 / 263)
#
# processing AOI 0719w-422n (86 / 263)
#
# processing AOI 0719w-423n (87 / 263)
#
# processing AOI 0719w-425n (88 / 263)
#
# processing AOI 0718w-421n (89 / 263)
#
# processing AOI 0718w-422n (90 / 263)
#
# processing AOI 0718w-423n (91 / 263)
#
# processing AOI 0718w-424n (92 / 263)
#
# processing AOI 0718w-425n (93 / 263)
#
# processing AOI 0717w-420n (94 / 263)
#
# processing AOI 0717w-421n (95 / 263)
#
# processing AOI 0717w-422n (96 / 263)
#
# processing AOI 0717w-423n (97 / 263)
#
# processing AOI 0717w-424n (98 / 263)
#
# processing AOI 0717w-425n (99 / 263)
#
# processing AOI 0717w-428n (100 / 263)
#
# processing AOI 0716w-416n (101 / 263)
#
# processing AOI 0716w-417n (102 / 263)
#
# processing AOI 0716w-418n (103 / 263)
#
# processing AOI 0716w-419n (104 / 263)
#
# processing AOI 0716w-420n (105 / 263)
#
# processing AOI 0716w-421n (106 / 263)
#
# processing AOI 0716w-422n (107 / 263)
#
# processing AOI 0716w-423n (108 / 263)
#
# processing AOI 0716w-424n (109 / 263)
#
# processing AOI 0716w-425n (110 / 263)
#
# processing AOI 0716w-426n (111 / 263)
#
# processing AOI 0716w-427n (112 / 263)
#
# processing AOI 0716w-428n (113 / 263)
#
# processing AOI 0716w-429n (114 / 263)
#
# processing AOI 0716w-432n (115 / 263)
#
# processing AOI 0715w-414n (116 / 263)
#
# processing AOI 0715w-415n (117 / 263)
#
# processing AOI 0715w-416n (118 / 263)
#
# processing AOI 0715w-417n (119 / 263)
#
# processing AOI 0715w-418n (120 / 263)
#
# processing AOI 0715w-419n (121 / 263)
#
# processing AOI 0715w-420n (122 / 263)
#
# processing AOI 0715w-421n (123 / 263)
#
# processing AOI 0715w-422n (124 / 263)
#
# processing AOI 0715w-423n (125 / 263)
#
# processing AOI 0715w-424n (126 / 263)
#
# processing AOI 0715w-425n (127 / 263)
#
# processing AOI 0715w-426n (128 / 263)
#
# processing AOI 0715w-427n (129 / 263)
#
# processing AOI 0715w-428n (130 / 263)
#
# processing AOI 0715w-429n (131 / 263)
#
# processing AOI 0715w-430n (132 / 263)
#
# processing AOI 0715w-435n (133 / 263)
#
# processing AOI 0714w-417n (134 / 263)
#
# processing AOI 0714w-418n (135 / 263)
#
# processing AOI 0714w-419n (136 / 263)
#
# processing AOI 0714w-420n (137 / 263)
#
# processing AOI 0714w-421n (138 / 263)
#
# processing AOI 0714w-422n (139 / 263)
#
# processing AOI 0714w-423n (140 / 263)
#
# processing AOI 0714w-424n (141 / 263)
#
# processing AOI 0714w-425n (142 / 263)
#
# processing AOI 0714w-426n (143 / 263)
#
# processing AOI 0714w-427n (144 / 263)
#
# processing AOI 0714w-428n (145 / 263)
#
# processing AOI 0714w-429n (146 / 263)
#
# processing AOI 0713w-415n (147 / 263)
#
# processing AOI 0713w-416n (148 / 263)
#
# processing AOI 0713w-417n (149 / 263)
#
# processing AOI 0713w-419n (150 / 263)
#
# processing AOI 0713w-420n (151 / 263)
#
# processing AOI 0713w-421n (152 / 263)
#
# processing AOI 0713w-422n (153 / 263)
#
# processing AOI 0713w-423n (154 / 263)
#
# processing AOI 0713w-424n (155 / 263)
#
# processing AOI 0713w-425n (156 / 263)
#
# processing AOI 0713w-426n (157 / 263)
#
# processing AOI 0713w-427n (158 / 263)
#
# processing AOI 0713w-428n (159 / 263)
#
# processing AOI 0712w-416n (160 / 263)
#
# processing AOI 0712w-417n (161 / 263)
#
# processing AOI 0712w-418n (162 / 263)
#
# processing AOI 0712w-419n (163 / 263)
#
# processing AOI 0712w-420n (164 / 263)
#
# processing AOI 0712w-421n (165 / 263)
#
# processing AOI 0712w-422n (166 / 263)
#
# processing AOI 0712w-423n (167 / 263)
#
# processing AOI 0712w-424n (168 / 263)
#
# processing AOI 0712w-425n (169 / 263)
#
# processing AOI 0712w-426n (170 / 263)
#
# processing AOI 0712w-427n (171 / 263)
#
# processing AOI 0712w-428n (172 / 263)
#
# processing AOI 0711w-416n (173 / 263)
#
# processing AOI 0711w-418n (174 / 263)
#
# processing AOI 0711w-419n (175 / 263)
#
# processing AOI 0711w-420n (176 / 263)
#
# processing AOI 0711w-421n (177 / 263)
#
# processing AOI 0711w-422n (178 / 263)
#
# processing AOI 0711w-423n (179 / 263)
#
# processing AOI 0711w-424n (180 / 263)
#
# processing AOI 0711w-425n (181 / 263)
#
# processing AOI 0711w-426n (182 / 263)
#
# processing AOI 0711w-427n (183 / 263)
#
# processing AOI 0711w-428n (184 / 263)
#
# processing AOI 0710w-416n (185 / 263)
#
# processing AOI 0710w-417n (186 / 263)
#
# processing AOI 0710w-418n (187 / 263)
#
# processing AOI 0710w-419n (188 / 263)
#
# processing AOI 0710w-420n (189 / 263)
#
# processing AOI 0710w-421n (190 / 263)
#
# processing AOI 0710w-422n (191 / 263)
#
# processing AOI 0710w-424n (192 / 263)
#
# processing AOI 0710w-425n (193 / 263)
#
# processing AOI 0710w-426n (194 / 263)
#
# processing AOI 0710w-427n (195 / 263)
#
# processing AOI 0710w-428n (196 / 263)
#
# processing AOI 0710w-429n (197 / 263)
#
# processing AOI 0710w-430n (198 / 263)
#
# processing AOI 0710w-432n (199 / 263)
#
# processing AOI 0710w-433n (200 / 263)
#
# processing AOI 0709w-416n (201 / 263)
#
# processing AOI 0709w-420n (202 / 263)
#
# processing AOI 0709w-421n (203 / 263)
#
# processing AOI 0709w-422n (204 / 263)
#
# processing AOI 0709w-425n (205 / 263)
#
# processing AOI 0709w-426n (206 / 263)
#
# processing AOI 0709w-428n (207 / 263)
#
# processing AOI 0709w-429n (208 / 263)
#
# processing AOI 0709w-430n (209 / 263)
#
# processing AOI 0709w-431n (210 / 263)
#
# processing AOI 0709w-432n (211 / 263)
#
# processing AOI 0708w-417n (212 / 263)
#
# processing AOI 0708w-419n (213 / 263)
#
# processing AOI 0708w-420n (214 / 263)
#
# processing AOI 0708w-421n (215 / 263)
#
# processing AOI 0708w-422n (216 / 263)
#
# processing AOI 0708w-430n (217 / 263)
#
# processing AOI 0708w-431n (218 / 263)
#
# processing AOI 0707w-415n (219 / 263)
#
# processing AOI 0707w-416n (220 / 263)
#
# processing AOI 0707w-417n (221 / 263)
#
# processing AOI 0707w-419n (222 / 263)
#
# processing AOI 0707w-420n (223 / 263)
#
# processing AOI 0707w-426n (224 / 263)
#
# processing AOI 0707w-431n (225 / 263)
#
# processing AOI 0706w-414n (226 / 263)
#
# processing AOI 0706w-415n (227 / 263)
#
# processing AOI 0706w-416n (228 / 263)
#
# processing AOI 0706w-417n (229 / 263)
#
# processing AOI 0706w-418n (230 / 263)
#
# processing AOI 0706w-433n (231 / 263)
#
# processing AOI 0705w-416n (232 / 263)
#
# processing AOI 0705w-417n (233 / 263)
#
# processing AOI 0705w-434n (234 / 263)
#
# processing AOI 0705w-435n (235 / 263)
#
# processing AOI 0705w-438n (236 / 263)
#
# processing AOI 0704w-416n (237 / 263)
#
# processing AOI 0704w-435n (238 / 263)
#
# processing AOI 0704w-436n (239 / 263)
#
# processing AOI 0704w-437n (240 / 263)
#
# processing AOI 0703w-416n (241 / 263)
#
# processing AOI 0703w-436n (242 / 263)
#
# processing AOI 0703w-437n (243 / 263)
#
# processing AOI 0703w-440n (244 / 263)
#
# processing AOI 0702w-416n (245 / 263)
#
# processing AOI 0702w-417n (246 / 263)
#
# processing AOI 0702w-440n (247 / 263)
#
# processing AOI 0701w-416n (248 / 263)
#
# processing AOI 0701w-417n (249 / 263)
#
# processing AOI 0701w-419n (250 / 263)
#
# processing AOI 0700w-417n (251 / 263)
#
# processing AOI 0700w-418n (252 / 263)
#
# processing AOI 0700w-439n (253 / 263)
#
# processing AOI 0699w-439n (254 / 263)
#
# processing AOI 0698w-442n (255 / 263)
#
# processing AOI 0698w-443n (256 / 263)
#
# processing AOI 0697w-438n (257 / 263)
#
# processing AOI 0697w-445n (258 / 263)
#
# processing AOI 0689w-447n (259 / 263)
#
# processing AOI 0688w-447n (260 / 263)
#
# processing AOI 0688w-448n (261 / 263)
#
# processing AOI 0687w-449n (262 / 263)
#
# saved tile info in /content/drive/MyDrive/Projects/verge/data/newengland/tiles2.csv
