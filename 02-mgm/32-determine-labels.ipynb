# %% [markdown]
# # Determine labels for geospatial entities
#
# We have a set of rules that define the labels for our geospatial entities.
# This file goes throught that list of rules to determine all of the possible labels.
# The it writes the list to a file along with a numberical ID.

# %% [markdown]
# ## Processing Setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # Local processing setup
# project_home = '..'

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Projects/verge

# %% [markdown]
# ## Code

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# %%
import pandas as pd
import numpy as np

import sys
sys.path.append(project_home)
from utils.verge import rules

# %%
labels = set()
for r in rules:
    label = '%s : %s' % (r['gent_category'], r['gent_label'])
    labels.add(label)

# This is a special case, that is created differently so it is not in the rule set.
labels.add('waterway : land')

# # These will be special cases.
# labels.add('token : mask')
# labels.add('token : pad')

# %%
records = []
for k, label in enumerate(sorted(labels)):
    records.append({'id': k, 'label': label, })
    print(k, label)
# Out:
# 0 amenity : commercial
# 1 amenity : food and drink
# 2 amenity : parking lot
# 3 amenity : recreation
# 4 landuse : agricultural
# 5 landuse : commercial
# 6 landuse : forest
# 7 landuse : industrial
# 8 landuse : meadow
# 9 landuse : recreation
# 10 landuse : residential
# 11 landuse : retail
# 12 railway : rail
# 13 railway : rail stop
# 14 route : highway
# 15 route : primary road
# 16 route : residential road
# 17 route : secondary road
# 18 route : tertiary road
# 19 waterway : lakes and ponds
# 20 waterway : land
# 21 waterway : rivers and streams

# %%
fname = '%s/labels.csv' % data_home
pd.DataFrame(records).to_csv(fname, index=False)
print('wrote %s' % fname)
# Out:
# wrote /content/drive/MyDrive/Projects/verge/data/labels.csv
