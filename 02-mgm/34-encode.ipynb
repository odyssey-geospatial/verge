# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Encode geospatial data for VERGE processing
#
# Elsewhere we assembled geospatial data for a bunch of tiles.
# Here we come up with encodings for each such entitiy.
# The encodings will consist of a concatenation of a Multi-Point Proximity (MPP) encoding
# and a one-hot vector indicating the entity type.

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
# import os
# from google.colab import drive
# drive.mount('/content/drive')
# project_home = '/content/drive/MyDrive/Projects/verge'
# os.chdir(project_home)

# %%
# !pip install geo-encodings

# %%
# Local processing setup
project_home = '..'

# %% [markdown]
# ## Notebook setup

# %%
import pandas as pd
import numpy as np
import glob
import geopandas
import os
import pickle
import json
from geo_encodings import MPPEncoder

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'ne-laptop'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# # A unique identifier for this run.
# run_id = '101'

# %% [markdown]
# ## Data prep

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %%
# Read the list of labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)
num_classes = len(labels)
print('%d labels' % num_classes)

label_id_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
# Out:
# 22 labels

# %%
# Set up the MPP encoder.
encoder = MPPEncoder(
    region=[0, 0, tile_size, tile_size],
    resolution=encoding_resolution,
    center=True
)
print('%d elements in encodings' % len(encoder))
# Out:
# 400 elements in encodings

# %% [markdown]
# ## Processing

# %%
fname = '%s/tiles.csv' % roi_home
tile_info = pd.read_csv(fname)
print('%d tiles in this ROI' % len(tile_info))
tile_info.head(3)
# Out:
# 1056 tiles in this ROI
#       aoi_tag tile_tag      lon0       lat0       lon1       lat1  center_lon  \
# 0  0735w-413n  005-005 -73.50000  41.300000 -73.476879  41.318544  -73.488440
# 1  0735w-413n  005-006 -73.50037  41.308994 -73.477246  41.327538  -73.488808
# 2  0735w-413n  005-007 -73.50074  41.317988 -73.477613  41.336533  -73.489176
#
#    center_lat
# 0   41.309272
# 1   41.318266
# 2   41.327260

# %%
# In the loop below, we will also accumulate a histogram of class labels.
# This will be saved and used during model training to balance sampling.
class_counts = {z: 0 for z in range(num_classes)}

# %%
aoi_tags = np.unique(tile_info['aoi_tag'].values)
aoi_tags
# Out:
# array(['0731w-413n', '0731w-414n', '0731w-415n', '0732w-413n',
#        '0732w-415n', '0732w-418n', '0732w-426n', '0732w-444n',
#        '0732w-445n', '0733w-413n', '0733w-414n', '0733w-423n',
#        '0733w-424n', '0733w-444n', '0733w-445n', '0734w-414n',
#        '0735w-413n', '0735w-414n', '0735w-415n', '0735w-446n'],
#       dtype=object)

# %%
# Loop over AOIs

for k, aoi_tag in enumerate(aoi_tags):

    # Check whether the output file already exists.
    fname = '%s/encodings/%s.pkl' % (roi_home, aoi_tag)
    if os.path.exists(fname):
      print('\nskipping %s' % (fname))
      continue

    print('\nhandling AOI %s (%d / %d)' % (aoi_tag, k, len(aoi_tags)))

    # Get a list of the tile tags for this AOI.
    iok = tile_info['aoi_tag'] == aoi_tag
    tile_tags = tile_info['tile_tag'].values[iok]

    # This will hold all encodings for this AOI
    tile_encodings_for_this_aoi = []

    # Loop over tiles.
    for tile_tag in tile_tags:

        print('tile tag %s' % tile_tag)

        tile_vectors = []
        tile_labels = []
        tile_fname = '%s/tiles/%s/%s.pq' % (roi_home, aoi_tag, tile_tag)
        gdf = geopandas.read_parquet(tile_fname)
        for _, rec in gdf.sample(frac=1).iterrows():

            # Geometric encoding vector
            encoding = encoder.encode(rec['geometry']).values()

            # One-hot label vector
            etype = np.zeros(num_classes)
            label_string = '%s : %s' % (rec['category'], rec['label'])
            label_id = label_id_lookup[label_string]
            etype[label_id] = 1.0

            # Save the label as an integer too. This will make training easier.
            tile_labels.append(label_id)

            # Keep track of class counts across all tiles.
            class_counts[label_id] += 1

            # Concatenate the encoding and type vectors.
            vector = np.hstack((etype, encoding))
            tile_vectors.append(vector)

        # Combine all per-feature vectors into one big feature matrix.
        tile_features = np.vstack(tile_vectors)

        tile_encodings_for_this_aoi.append({
            'aoi_tag': aoi_tag,
            'tile_tag': tile_tag,
            'features': tile_features,
            'labels': np.array(tile_labels),
        })

    # Save all of the encodings for this tile.
    fname = '%s/encodings/%s.pkl' % (roi_home, aoi_tag)
    os.makedirs(os.path.dirname(fname), exist_ok=True)
    with open(fname, 'wb') as dest:
        pickle.dump(tile_encodings_for_this_aoi, dest)
    print('wrote %s' % (fname))
# Out:
# handling AOI 0731w-413n (0 / 20)
# tile tag 039-004
# tile tag 039-005
# tile tag 039-006
# tile tag 039-007
# tile tag 039-008
# tile tag 039-009
# tile tag 039-010
# tile tag 039-011
# tile tag 039-012
# tile tag 040-004
# tile tag 040-005
# tile tag 040-006
# tile tag 040-007
# tile tag 040-008
# tile tag 040-009
# tile tag 040-010
# tile tag 040-011
# tile tag 040-012
# tile tag 041-004
# tile tag 041-005
# tile tag 041-006
# tile tag 041-007
# tile tag 041-008
# tile tag 041-009
# tile tag 041-010
# tile tag 041-011
# tile tag 041-012
# tile tag 042-004
# tile tag 042-005
# tile tag 042-006
# tile tag 042-007
# tile tag 042-008
# tile tag 042-009
# tile tag 042-010
# tile tag 042-011
# tile tag 042-012
# tile tag 043-004
# tile tag 043-005
# tile tag 043-006
# tile tag 043-007
# tile tag 043-008
# tile tag 043-009
# tile tag 043-010
# tile tag 043-011
# tile tag 043-012
# tile tag 044-004
# tile tag 044-005
# tile tag 044-006
# tile tag 044-007
# tile tag 044-008
# tile tag 044-009
# tile tag 044-010
# tile tag 044-011
# tile tag 044-012
# tile tag 045-004
# tile tag 045-005
# tile tag 045-006
# tile tag 045-007
# tile tag 045-008
# tile tag 045-009
# tile tag 045-010
# tile tag 045-011
# tile tag 045-012
# wrote ../data/ne-laptop/encodings/0731w-413n.pkl
#
# handling AOI 0731w-414n (1 / 20)
# tile tag 039-015
# tile tag 039-016
# tile tag 039-017
# tile tag 039-018
# tile tag 039-019
# tile tag 039-020
# tile tag 039-021
# tile tag 039-022
# tile tag 039-023
# tile tag 040-015
# tile tag 040-016
# tile tag 040-017
# tile tag 040-018
# tile tag 040-019
# tile tag 040-020
# tile tag 040-021
# tile tag 040-022
# tile tag 040-023
# tile tag 041-015
# tile tag 041-016
# tile tag 041-017
# tile tag 041-018
# tile tag 041-019
# tile tag 041-020
# tile tag 041-021
# tile tag 041-022
# tile tag 041-023
# tile tag 042-015
# tile tag 042-016
# tile tag 042-017
# tile tag 042-018
# tile tag 042-019
# tile tag 042-020
# tile tag 042-021
# tile tag 042-022
# tile tag 042-023
# tile tag 043-015
# tile tag 043-016
# tile tag 043-017
# tile tag 043-018
# tile tag 043-019
# tile tag 043-020
# tile tag 043-021
# tile tag 043-022
# tile tag 043-023
# tile tag 044-015
# tile tag 044-016
# tile tag 044-017
# tile tag 044-018
# tile tag 044-019
# tile tag 044-020
# tile tag 044-021
# tile tag 044-022
# tile tag 044-023
# tile tag 045-015
# tile tag 045-016
# tile tag 045-017
# tile tag 045-018
# tile tag 045-019
# tile tag 045-020
# tile tag 045-021
# tile tag 045-022
# tile tag 045-023
# wrote ../data/ne-laptop/encodings/0731w-414n.pkl
#
# handling AOI 0731w-415n (2 / 20)
# tile tag 039-026
# tile tag 039-027
# tile tag 039-028
# tile tag 039-029
# tile tag 039-030
# tile tag 039-031
# tile tag 039-032
# tile tag 039-033
# tile tag 039-034
# tile tag 040-026
# tile tag 040-027
# tile tag 040-028
# tile tag 040-029
# tile tag 040-030
# tile tag 040-031
# tile tag 040-032
# tile tag 040-033
# tile tag 040-034
# tile tag 041-026
# tile tag 041-027
# tile tag 041-028
# tile tag 041-029
# tile tag 041-030
# tile tag 041-031
# tile tag 041-032
# tile tag 041-033
# tile tag 041-034
# tile tag 042-026
# tile tag 042-027
# tile tag 042-028
# tile tag 042-029
# tile tag 042-030
# tile tag 042-031
# tile tag 042-032
# tile tag 042-033
# tile tag 042-034
# tile tag 043-026
# tile tag 043-027
# tile tag 043-028
# tile tag 043-029
# tile tag 043-030
# tile tag 043-031
# tile tag 043-032
# tile tag 043-033
# tile tag 043-034
# tile tag 044-026
# tile tag 044-027
# tile tag 044-028
# tile tag 044-029
# tile tag 044-030
# tile tag 044-031
# tile tag 044-032
# tile tag 044-033
# tile tag 044-034
# tile tag 045-026
# tile tag 045-027
# tile tag 045-028
# tile tag 045-029
# tile tag 045-030
# tile tag 045-031
# tile tag 045-032
# tile tag 045-033
# tile tag 045-034
# wrote ../data/ne-laptop/encodings/0731w-415n.pkl
#
# handling AOI 0732w-413n (3 / 20)
# tile tag 030-004
# tile tag 030-005
# tile tag 030-006
# tile tag 030-007
# tile tag 030-008
# tile tag 030-009
# tile tag 030-010
# tile tag 030-011
# tile tag 030-012
# tile tag 031-004
# tile tag 031-005
# tile tag 031-006
# tile tag 031-007
# tile tag 031-008
# tile tag 031-009
# tile tag 031-010
# tile tag 031-011
# tile tag 031-012
# tile tag 032-004
# tile tag 032-005
# tile tag 032-006
# tile tag 032-007
# tile tag 032-008
# tile tag 032-009
# tile tag 032-010
# tile tag 032-011
# tile tag 032-012
# tile tag 033-004
# tile tag 033-005
# tile tag 033-006
# tile tag 033-007
# tile tag 033-008
# tile tag 033-009
# tile tag 033-010
# tile tag 033-011
# tile tag 033-012
# tile tag 034-004
# tile tag 034-005
# tile tag 034-006
# tile tag 034-007
# tile tag 034-008
# tile tag 034-009
# tile tag 034-010
# tile tag 034-011
# tile tag 034-012
# tile tag 035-004
# tile tag 035-005
# tile tag 035-006
# tile tag 035-007
# tile tag 035-008
# tile tag 035-009
# tile tag 035-010
# tile tag 035-011
# tile tag 035-012
# tile tag 036-004
# tile tag 036-005
# tile tag 036-006
# tile tag 036-007
# tile tag 036-008
# tile tag 036-009
# tile tag 036-010
# tile tag 036-011
# tile tag 036-012
# wrote ../data/ne-laptop/encodings/0732w-413n.pkl
#
# handling AOI 0732w-415n (4 / 20)
# tile tag 031-026
# tile tag 031-027
# tile tag 031-028
# tile tag 031-029
# tile tag 031-030
# tile tag 031-031
# tile tag 031-032
# tile tag 031-033
# tile tag 031-034
# tile tag 032-026
# tile tag 032-027
# tile tag 032-028
# tile tag 032-029
# tile tag 032-030
# tile tag 032-031
# tile tag 032-032
# tile tag 032-033
# tile tag 032-034
# tile tag 033-026
# tile tag 033-027
# tile tag 033-028
# tile tag 033-031
# tile tag 033-032
# tile tag 033-033
# tile tag 033-034
# tile tag 034-026
# tile tag 034-027
# tile tag 034-028
# tile tag 034-029
# tile tag 034-030
# tile tag 034-032
# tile tag 034-033
# tile tag 034-034
# tile tag 035-026
# tile tag 035-027
# tile tag 035-028
# tile tag 035-029
# tile tag 035-030
# tile tag 035-031
# tile tag 035-032
# tile tag 035-033
# tile tag 035-034
# tile tag 036-026
# tile tag 036-027
# tile tag 036-028
# tile tag 036-029
# tile tag 036-030
# tile tag 036-031
# tile tag 036-032
# tile tag 036-033
# tile tag 036-034
# tile tag 037-026
# tile tag 037-027
# tile tag 037-028
# tile tag 037-029
# tile tag 037-030
# tile tag 037-031
# tile tag 037-032
# tile tag 037-033
# tile tag 037-034
# wrote ../data/ne-laptop/encodings/0732w-415n.pkl
#
# handling AOI 0732w-418n (5 / 20)
# tile tag 032-061
# tile tag 033-059
# tile tag 033-065
# tile tag 033-066
# tile tag 034-059
# tile tag 034-060
# tile tag 034-063
# tile tag 034-064
# tile tag 034-065
# tile tag 034-066
# tile tag 035-059
# tile tag 035-060
# tile tag 035-061
# tile tag 035-063
# tile tag 035-064
# tile tag 035-065
# tile tag 036-059
# tile tag 036-060
# tile tag 036-061
# tile tag 036-067
# tile tag 037-059
# tile tag 037-060
# tile tag 037-061
# tile tag 037-063
# tile tag 037-064
# tile tag 037-065
# tile tag 037-066
# tile tag 037-067
# tile tag 038-059
# tile tag 038-060
# tile tag 038-061
# tile tag 038-062
# tile tag 038-063
# tile tag 038-064
# tile tag 038-065
# tile tag 038-066
# wrote ../data/ne-laptop/encodings/0732w-418n.pkl
#
# handling AOI 0732w-426n (6 / 20)
# tile tag 035-151
# tile tag 035-152
# tile tag 036-151
# tile tag 036-152
# tile tag 037-150
# tile tag 038-148
# tile tag 038-149
# tile tag 038-150
# tile tag 038-151
# tile tag 039-148
# tile tag 039-149
# tile tag 039-150
# tile tag 039-151
# tile tag 040-148
# tile tag 040-149
# tile tag 040-150
# tile tag 040-151
# tile tag 040-152
# tile tag 040-153
# tile tag 040-154
# tile tag 040-155
# tile tag 040-156
# wrote ../data/ne-laptop/encodings/0732w-426n.pkl
#
# handling AOI 0732w-444n (7 / 20)
# tile tag 040-348
# tile tag 040-349
# tile tag 040-350
# tile tag 040-351
# tile tag 040-352
# tile tag 040-353
# tile tag 040-354
# tile tag 040-355
# tile tag 040-356
# tile tag 041-348
# tile tag 041-349
# tile tag 041-350
# tile tag 041-351
# tile tag 041-352
# tile tag 041-353
# tile tag 041-354
# tile tag 041-355
# tile tag 041-356
# tile tag 042-348
# tile tag 042-349
# tile tag 042-350
# tile tag 042-351
# tile tag 042-352
# tile tag 042-353
# tile tag 042-354
# tile tag 042-355
# tile tag 042-356
# tile tag 043-348
# tile tag 043-349
# tile tag 043-350
# tile tag 043-351
# tile tag 043-352
# tile tag 043-353
# tile tag 043-354
# tile tag 043-355
# tile tag 043-356
# tile tag 044-348
# tile tag 044-349
# tile tag 044-351
# tile tag 044-352
# tile tag 044-353
# tile tag 044-354
# tile tag 044-355
# tile tag 044-356
# tile tag 045-348
# tile tag 045-350
# tile tag 045-351
# tile tag 045-352
# tile tag 045-353
# tile tag 045-354
# tile tag 045-355
# tile tag 045-356
# tile tag 046-348
# tile tag 046-349
# tile tag 046-350
# tile tag 046-351
# tile tag 046-352
# tile tag 046-353
# tile tag 046-354
# tile tag 046-355
# tile tag 046-356
# wrote ../data/ne-laptop/encodings/0732w-444n.pkl
#
# handling AOI 0732w-445n (8 / 20)
# tile tag 041-359
# tile tag 041-360
# tile tag 041-361
# tile tag 041-362
# tile tag 041-363
# tile tag 041-364
# tile tag 041-365
# tile tag 042-359
# tile tag 042-360
# tile tag 042-361
# tile tag 042-362
# tile tag 042-363
# tile tag 042-364
# tile tag 042-365
# tile tag 042-366
# tile tag 042-367
# tile tag 043-359
# tile tag 043-360
# tile tag 043-361
# tile tag 043-362
# tile tag 043-363
# tile tag 043-364
# tile tag 043-365
# tile tag 043-366
# tile tag 043-367
# tile tag 044-359
# tile tag 044-360
# tile tag 044-361
# tile tag 044-362
# tile tag 044-363
# tile tag 044-364
# tile tag 044-365
# tile tag 044-366
# tile tag 045-359
# tile tag 045-360
# tile tag 045-361
# tile tag 045-362
# tile tag 045-363
# tile tag 045-364
# tile tag 046-359
# tile tag 046-360
# tile tag 046-361
# tile tag 046-362
# tile tag 046-363
# tile tag 046-364
# tile tag 047-359
# tile tag 047-360
# tile tag 047-361
# tile tag 047-362
# tile tag 047-363
# tile tag 047-364
# tile tag 047-367
# wrote ../data/ne-laptop/encodings/0732w-445n.pkl
#
# handling AOI 0733w-413n (9 / 20)
# tile tag 022-004
# tile tag 022-005
# tile tag 022-006
# tile tag 022-007
# tile tag 022-008
# tile tag 022-009
# tile tag 022-010
# tile tag 022-011
# tile tag 022-012
# tile tag 023-004
# tile tag 023-005
# tile tag 023-006
# tile tag 023-007
# tile tag 023-008
# tile tag 023-009
# tile tag 023-010
# tile tag 023-011
# tile tag 023-012
# tile tag 024-004
# tile tag 024-005
# tile tag 024-006
# tile tag 024-007
# tile tag 024-008
# tile tag 024-009
# tile tag 024-010
# tile tag 024-011
# tile tag 024-012
# tile tag 025-004
# tile tag 025-005
# tile tag 025-006
# tile tag 025-007
# tile tag 025-008
# tile tag 025-009
# tile tag 025-010
# tile tag 025-011
# tile tag 025-012
# tile tag 026-004
# tile tag 026-005
# tile tag 026-006
# tile tag 026-007
# tile tag 026-008
# tile tag 026-009
# tile tag 026-010
# tile tag 026-011
# tile tag 026-012
# tile tag 027-004
# tile tag 027-005
# tile tag 027-006
# tile tag 027-007
# tile tag 027-008
# tile tag 027-009
# tile tag 027-010
# tile tag 027-011
# tile tag 027-012
# tile tag 028-004
# tile tag 028-005
# tile tag 028-006
# tile tag 028-007
# tile tag 028-008
# tile tag 028-009
# tile tag 028-010
# tile tag 028-011
# tile tag 028-012
# wrote ../data/ne-laptop/encodings/0733w-413n.pkl
#
# handling AOI 0733w-414n (10 / 20)
# tile tag 022-015
# tile tag 022-016
# tile tag 022-017
# tile tag 022-018
# tile tag 022-019
# tile tag 022-020
# tile tag 022-022
# tile tag 022-023
# tile tag 023-015
# tile tag 023-016
# tile tag 023-017
# tile tag 023-018
# tile tag 023-019
# tile tag 023-020
# tile tag 023-021
# tile tag 023-022
# tile tag 023-023
# tile tag 024-015
# tile tag 024-016
# tile tag 024-017
# tile tag 024-018
# tile tag 024-019
# tile tag 024-020
# tile tag 024-021
# tile tag 024-022
# tile tag 024-023
# tile tag 025-015
# tile tag 025-016
# tile tag 025-017
# tile tag 025-018
# tile tag 025-019
# tile tag 025-020
# tile tag 025-021
# tile tag 025-022
# tile tag 025-023
# tile tag 026-015
# tile tag 026-016
# tile tag 026-017
# tile tag 026-018
# tile tag 026-019
# tile tag 026-020
# tile tag 026-021
# tile tag 026-022
# tile tag 026-023
# tile tag 027-015
# tile tag 027-016
# tile tag 027-017
# tile tag 027-018
# tile tag 027-019
# tile tag 027-020
# tile tag 027-021
# tile tag 027-022
# tile tag 027-023
# tile tag 028-015
# tile tag 028-016
# tile tag 028-017
# tile tag 028-018
# tile tag 028-019
# tile tag 028-020
# tile tag 028-021
# tile tag 028-022
# tile tag 028-023
# wrote ../data/ne-laptop/encodings/0733w-414n.pkl
#
# handling AOI 0733w-423n (11 / 20)
# tile tag 025-117
# tile tag 025-118
# tile tag 025-119
# tile tag 025-120
# tile tag 025-121
# tile tag 025-122
# tile tag 026-116
# tile tag 026-117
# tile tag 026-118
# tile tag 026-119
# tile tag 026-120
# tile tag 026-121
# tile tag 026-122
# tile tag 026-123
# tile tag 027-115
# tile tag 027-116
# tile tag 027-117
# tile tag 027-118
# tile tag 027-119
# tile tag 027-120
# tile tag 027-121
# tile tag 027-122
# tile tag 027-123
# tile tag 028-115
# tile tag 028-116
# tile tag 028-117
# tile tag 028-118
# tile tag 028-119
# tile tag 028-120
# tile tag 028-121
# tile tag 028-122
# tile tag 028-123
# tile tag 029-115
# tile tag 029-116
# tile tag 029-117
# tile tag 029-118
# tile tag 029-119
# tile tag 029-120
# tile tag 030-115
# tile tag 030-116
# tile tag 030-117
# wrote ../data/ne-laptop/encodings/0733w-423n.pkl
#
# handling AOI 0733w-424n (12 / 20)
# tile tag 026-128
# tile tag 026-129
# tile tag 026-130
# tile tag 026-131
# tile tag 026-132
# tile tag 026-133
# tile tag 026-134
# tile tag 027-126
# tile tag 027-127
# tile tag 027-128
# tile tag 027-129
# tile tag 027-130
# tile tag 027-131
# tile tag 027-132
# tile tag 027-133
# tile tag 027-134
# tile tag 028-126
# tile tag 028-127
# tile tag 028-128
# tile tag 028-129
# tile tag 028-130
# tile tag 028-131
# tile tag 028-132
# tile tag 028-133
# tile tag 028-134
# tile tag 029-126
# tile tag 029-127
# tile tag 029-128
# tile tag 029-129
# tile tag 029-130
# tile tag 029-131
# tile tag 029-132
# tile tag 029-133
# tile tag 029-134
# tile tag 030-126
# tile tag 030-127
# tile tag 030-128
# tile tag 030-129
# tile tag 030-130
# tile tag 030-131
# tile tag 030-132
# tile tag 030-133
# tile tag 030-134
# tile tag 031-127
# tile tag 031-128
# tile tag 031-129
# tile tag 031-130
# tile tag 031-131
# tile tag 031-132
# tile tag 031-133
# tile tag 031-134
# tile tag 032-127
# tile tag 032-128
# tile tag 032-129
# tile tag 032-130
# tile tag 032-131
# tile tag 032-132
# tile tag 032-133
# tile tag 032-134
# wrote ../data/ne-laptop/encodings/0733w-424n.pkl
#
# handling AOI 0733w-444n (13 / 20)
# tile tag 037-348
# tile tag 037-349
# tile tag 037-350
# tile tag 037-351
# tile tag 037-352
# tile tag 037-353
# tile tag 037-354
# tile tag 037-355
# tile tag 037-356
# tile tag 038-348
# tile tag 038-349
# tile tag 038-350
# tile tag 038-351
# tile tag 038-352
# tile tag 038-353
# tile tag 038-354
# tile tag 038-355
# tile tag 038-356
# wrote ../data/ne-laptop/encodings/0733w-444n.pkl
#
# handling AOI 0733w-445n (14 / 20)
# tile tag 033-363
# tile tag 033-364
# tile tag 033-365
# tile tag 034-360
# tile tag 034-361
# tile tag 034-362
# tile tag 034-363
# tile tag 034-364
# tile tag 034-365
# tile tag 035-360
# tile tag 035-361
# tile tag 035-362
# tile tag 035-363
# tile tag 035-364
# tile tag 035-365
# tile tag 036-360
# tile tag 036-361
# tile tag 036-362
# tile tag 036-363
# tile tag 036-364
# tile tag 036-365
# tile tag 037-360
# tile tag 037-361
# tile tag 037-362
# tile tag 037-363
# tile tag 037-364
# tile tag 037-365
# tile tag 037-366
# tile tag 037-367
# tile tag 038-360
# tile tag 038-361
# tile tag 038-362
# tile tag 038-363
# tile tag 038-364
# tile tag 038-365
# tile tag 038-366
# tile tag 038-367
# tile tag 039-360
# tile tag 039-361
# tile tag 039-362
# tile tag 039-363
# tile tag 039-364
# tile tag 039-365
# tile tag 039-368
# wrote ../data/ne-laptop/encodings/0733w-445n.pkl
#
# handling AOI 0734w-414n (15 / 20)
# tile tag 014-015
# tile tag 014-016
# tile tag 014-017
# tile tag 014-018
# tile tag 014-019
# tile tag 014-020
# tile tag 014-021
# tile tag 014-022
# tile tag 014-023
# tile tag 015-015
# tile tag 015-016
# tile tag 015-017
# tile tag 015-018
# tile tag 015-019
# tile tag 015-020
# tile tag 015-021
# tile tag 015-022
# tile tag 015-023
# tile tag 016-015
# tile tag 016-016
# tile tag 016-017
# tile tag 016-018
# tile tag 016-019
# tile tag 016-020
# tile tag 016-021
# tile tag 016-022
# tile tag 016-023
# tile tag 017-015
# tile tag 017-016
# tile tag 017-017
# tile tag 017-018
# tile tag 017-019
# tile tag 017-020
# tile tag 017-021
# tile tag 017-022
# tile tag 017-023
# tile tag 018-015
# tile tag 018-016
# tile tag 018-017
# tile tag 018-018
# tile tag 018-019
# tile tag 018-020
# tile tag 018-021
# tile tag 018-022
# tile tag 018-023
# tile tag 019-015
# tile tag 019-016
# tile tag 019-017
# tile tag 019-018
# tile tag 019-019
# tile tag 019-020
# tile tag 019-021
# tile tag 019-022
# tile tag 019-023
# tile tag 020-015
# tile tag 020-016
# tile tag 020-017
# tile tag 020-018
# tile tag 020-019
# tile tag 020-020
# tile tag 020-021
# tile tag 020-022
# tile tag 020-023
# wrote ../data/ne-laptop/encodings/0734w-414n.pkl
#
# handling AOI 0735w-413n (16 / 20)
# tile tag 005-005
# tile tag 005-006
# tile tag 005-007
# tile tag 005-008
# tile tag 005-009
# tile tag 005-010
# tile tag 005-011
# tile tag 005-012
# tile tag 005-013
# tile tag 006-005
# tile tag 006-006
# tile tag 006-007
# tile tag 006-008
# tile tag 006-009
# tile tag 006-010
# tile tag 006-011
# tile tag 006-012
# tile tag 006-013
# tile tag 007-005
# tile tag 007-006
# tile tag 007-007
# tile tag 007-008
# tile tag 007-009
# tile tag 007-010
# tile tag 007-011
# tile tag 007-012
# tile tag 007-013
# tile tag 008-005
# tile tag 008-006
# tile tag 008-007
# tile tag 008-008
# tile tag 008-009
# tile tag 008-010
# tile tag 008-011
# tile tag 008-012
# tile tag 008-013
# tile tag 009-005
# tile tag 009-006
# tile tag 009-007
# tile tag 009-008
# tile tag 009-009
# tile tag 009-010
# tile tag 009-011
# tile tag 009-012
# tile tag 009-013
# tile tag 010-005
# tile tag 010-006
# tile tag 010-007
# tile tag 010-008
# tile tag 010-009
# tile tag 010-010
# tile tag 010-011
# tile tag 010-012
# tile tag 010-013
# tile tag 011-005
# tile tag 011-006
# tile tag 011-007
# tile tag 011-008
# tile tag 011-009
# tile tag 011-010
# tile tag 011-011
# tile tag 011-012
# tile tag 011-013
# wrote ../data/ne-laptop/encodings/0735w-413n.pkl
#
# handling AOI 0735w-414n (17 / 20)
# tile tag 006-016
# tile tag 006-017
# tile tag 006-018
# tile tag 006-019
# tile tag 006-020
# tile tag 006-021
# tile tag 006-022
# tile tag 006-023
# tile tag 006-024
# tile tag 007-016
# tile tag 007-017
# tile tag 007-018
# tile tag 007-019
# tile tag 007-020
# tile tag 007-021
# tile tag 007-022
# tile tag 007-023
# tile tag 007-024
# tile tag 008-016
# tile tag 008-017
# tile tag 008-018
# tile tag 008-019
# tile tag 008-020
# tile tag 008-021
# tile tag 008-022
# tile tag 008-023
# tile tag 008-024
# tile tag 009-016
# tile tag 009-017
# tile tag 009-018
# tile tag 009-019
# tile tag 009-020
# tile tag 009-021
# tile tag 009-022
# tile tag 009-023
# tile tag 009-024
# tile tag 010-016
# tile tag 010-017
# tile tag 010-018
# tile tag 010-019
# tile tag 010-020
# tile tag 010-021
# tile tag 010-022
# tile tag 010-023
# tile tag 010-024
# tile tag 011-016
# tile tag 011-017
# tile tag 011-018
# tile tag 011-019
# tile tag 011-020
# tile tag 011-021
# tile tag 011-022
# tile tag 011-023
# tile tag 011-024
# tile tag 012-016
# tile tag 012-017
# tile tag 012-018
# tile tag 012-019
# tile tag 012-020
# tile tag 012-021
# tile tag 012-022
# tile tag 012-023
# tile tag 012-024
# wrote ../data/ne-laptop/encodings/0735w-414n.pkl
#
# handling AOI 0735w-415n (18 / 20)
# tile tag 006-027
# tile tag 006-028
# tile tag 006-029
# tile tag 006-030
# tile tag 006-031
# tile tag 006-032
# tile tag 006-033
# tile tag 006-034
# tile tag 006-035
# tile tag 007-027
# tile tag 007-028
# tile tag 007-029
# tile tag 007-030
# tile tag 007-031
# tile tag 007-032
# tile tag 007-033
# tile tag 007-034
# tile tag 007-035
# tile tag 008-027
# tile tag 008-028
# tile tag 008-029
# tile tag 008-030
# tile tag 008-031
# tile tag 008-032
# tile tag 008-033
# tile tag 008-034
# tile tag 008-035
# tile tag 009-031
# tile tag 009-032
# tile tag 009-033
# tile tag 009-035
# tile tag 010-027
# tile tag 010-028
# tile tag 010-029
# tile tag 010-030
# tile tag 010-031
# tile tag 010-032
# tile tag 010-033
# tile tag 010-034
# tile tag 010-035
# tile tag 011-027
# tile tag 011-028
# tile tag 011-029
# tile tag 011-030
# tile tag 011-031
# tile tag 011-032
# tile tag 011-033
# tile tag 011-034
# tile tag 011-035
# tile tag 012-027
# tile tag 012-028
# tile tag 012-029
# tile tag 012-030
# tile tag 012-031
# tile tag 012-032
# tile tag 012-033
# tile tag 012-034
# tile tag 012-035
# wrote ../data/ne-laptop/encodings/0735w-415n.pkl
#
# handling AOI 0735w-446n (19 / 20)
# tile tag 017-371
# tile tag 017-373
# tile tag 017-374
# tile tag 017-375
# tile tag 017-376
# tile tag 017-377
# tile tag 017-378
# tile tag 017-379
# tile tag 018-373
# tile tag 018-374
# tile tag 018-375
# tile tag 018-376
# tile tag 018-377
# tile tag 018-378
# tile tag 018-379
# tile tag 019-373
# tile tag 019-374
# tile tag 019-375
# tile tag 019-376
# tile tag 019-377
# tile tag 019-378
# tile tag 019-379
# tile tag 020-371
# tile tag 020-372
# tile tag 020-373
# tile tag 020-374
# tile tag 020-375
# tile tag 020-376
# tile tag 020-377
# tile tag 020-378
# tile tag 020-379
# tile tag 021-371
# tile tag 021-372
# tile tag 021-374
# tile tag 021-375
# tile tag 021-376
# tile tag 021-377
# tile tag 021-378
# tile tag 021-379
# wrote ../data/ne-laptop/encodings/0735w-446n.pkl

# %%
# Save the label probabilities.
total = 0.0
for key in class_counts:
    total += class_counts[key]

records = [
    {
        'label': z,
        'count': class_counts[z],
        'prob': class_counts[z] / total
    } for z in range(num_classes)
]
fname = '%s/class_info.csv' % roi_home
pd.DataFrame(records).to_csv(fname, index=False)

# %% [markdown]
# ## QA and visualizations

# %%
import glob
globstring = '%s/encodings/*.pkl' % roi_home
fnames = glob.glob(globstring)
print(len(fnames))
# Out:
# 20
