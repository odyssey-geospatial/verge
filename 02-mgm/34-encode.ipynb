# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Encode geospatial data for VERGE processing
#
# Elsewhere we assembled geospatial data for a bunch of tiles.
# Here we come up with encodings for each such entitiy.
# The encodings will consist of a concatenation of a Multi-Point Proximity (MPP) encoding
# and a one-hot vector indicating the entity type.

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install geo-encodings
# Out:
# Requirement already satisfied: geo-encodings in /usr/local/lib/python3.11/dist-packages (1.0.4)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (2.0.2)

# %%
# # Local processing setup
# project_home = '..'

# %% [markdown]
# ## Source

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import glob
import geopandas
import os
import pickle
import json
from geo_encodings import MPPEncoder

# %% [markdown]
# ## Data prep

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %%
# Read the list of labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)
label_count = len(labels)
print('%d labels' % label_count)

label_id_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
# Out:
# 22 labels

# %%
# Set up the MPP encoder.
encoder = MPPEncoder(
    region=[0, 0, tile_size, tile_size],
    resolution=encoding_resolution,
    center=True
)
print('%d elements in encodings' % len(encoder))
# Out:
# 400 elements in encodings

# %% [markdown]
# ## Processing

# %%
# Get a list of AOI tags.
globstring = '%s/tiles/*' % roi_home
tile_dnames = glob.glob(globstring)
aoi_names = [
    z[z.rfind('/') + 1 :]
    for z in tile_dnames
]
print('%d AOIs in this ROI (%s)' % (len(aoi_names), roi_name))
# Out:
# 263 AOIs in this ROI (newengland)

# %%
# Loop over tiles

for k, aoi_name in enumerate(aoi_names):

    print('\nhandling AOI %s (%d / %d)' % (aoi_name, k, len(aoi_names)))

    # This will hold all encodings for this AOI
    tile_encodings_for_aoi = []

    # Get a list of all tiles for this AOI.
    globstring = '%s/tiles/%s/*.pq' % (roi_home, aoi_name)
    fnames = glob.glob(globstring)
    print('%d tiles' % len(fnames))
    for fname in fnames:
        tile_vectors = []
        gdf = geopandas.read_parquet(fname)
        # for _, rec in gdf.iterrows():
        for _, rec in gdf.sample(frac=1).iterrows():
            encoding = encoder.encode(rec['geometry']).values()
            etype = np.zeros(label_count)
            label_string = '%s : %s' % (rec['category'], rec['label'])
            label_id = label_id_lookup[label_string]
            etype[label_id] = 1.0

            # Concatenate the encoding and type vectors.
            vector = np.hstack((etype, encoding))
            tile_vectors.append(vector)
        tile_encoding = np.vstack(tile_vectors)
        tile_encodings_for_aoi.append(tile_encoding)

    # Save all of the encodings for this tile.
    fname = '%s/encodings/%s.pkl' % (roi_home, aoi_name)
    os.makedirs(os.path.dirname(fname), exist_ok=True)
    with open(fname, 'wb') as dest:
        pickle.dump(tile_encodings_for_aoi, dest)
    print('wrote %s' % (fname))
# Out:
# handling AOI 0735w-413n (0 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-413n.pkl
#
# handling AOI 0735w-414n (1 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-414n.pkl
#
# handling AOI 0735w-415n (2 / 263)
# 58 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-415n.pkl
#
# handling AOI 0735w-446n (3 / 263)
# 39 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-446n.pkl
#
# handling AOI 0734w-414n (4 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0734w-414n.pkl
#
# handling AOI 0733w-413n (5 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-413n.pkl
#
# handling AOI 0733w-414n (6 / 263)
# 62 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-414n.pkl
#
# handling AOI 0733w-423n (7 / 263)
# 41 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-423n.pkl
#
# handling AOI 0733w-424n (8 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-424n.pkl
#
# handling AOI 0733w-444n (9 / 263)
# 18 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-444n.pkl
#
# handling AOI 0733w-445n (10 / 263)
# 44 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-445n.pkl
#
# handling AOI 0732w-413n (11 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-413n.pkl
#
# handling AOI 0732w-415n (12 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-415n.pkl
#
# handling AOI 0732w-418n (13 / 263)
# 36 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-418n.pkl
#
# handling AOI 0732w-426n (14 / 263)
# 22 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-426n.pkl
#
# handling AOI 0732w-444n (15 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-444n.pkl
#
# handling AOI 0732w-445n (16 / 263)
# 52 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-445n.pkl
#
# handling AOI 0731w-413n (17 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-413n.pkl
#
# handling AOI 0731w-414n (18 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-414n.pkl
#
# handling AOI 0731w-415n (19 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-415n.pkl
#
# handling AOI 0731w-416n (20 / 263)
# 62 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-416n.pkl
#
# handling AOI 0731w-418n (21 / 263)
# 43 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-418n.pkl
#
# handling AOI 0730w-413n (22 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-413n.pkl
#
# handling AOI 0730w-414n (23 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-414n.pkl
#
# handling AOI 0730w-415n (24 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-415n.pkl
#
# handling AOI 0730w-416n (25 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-416n.pkl
#
# handling AOI 0730w-417n (26 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-417n.pkl
#
# handling AOI 0730w-436n (27 / 263)
# 45 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-436n.pkl
#
# handling AOI 0729w-413n (28 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-413n.pkl
#
# handling AOI 0729w-414n (29 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-414n.pkl
#
# handling AOI 0729w-415n (30 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-415n.pkl
#
# handling AOI 0729w-416n (31 / 263)
# 62 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-416n.pkl
#
# handling AOI 0729w-417n (32 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-417n.pkl
#
# handling AOI 0729w-418n (33 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-418n.pkl
#
# handling AOI 0728w-413n (34 / 263)
# 54 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-413n.pkl
#
# handling AOI 0728w-414n (35 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-414n.pkl
#
# handling AOI 0728w-415n (36 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-415n.pkl
#
# handling AOI 0728w-416n (37 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-416n.pkl
#
# handling AOI 0728w-417n (38 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-417n.pkl
#
# handling AOI 0728w-418n (39 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-418n.pkl
#
# handling AOI 0728w-419n (40 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-419n.pkl
#
# handling AOI 0728w-420n (41 / 263)
# 56 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-420n.pkl
#
# handling AOI 0728w-421n (42 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-421n.pkl
#
# handling AOI 0727w-413n (43 / 263)
# 56 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-413n.pkl
#
# handling AOI 0727w-415n (44 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-415n.pkl
#
# handling AOI 0727w-416n (45 / 263)
# 62 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-416n.pkl
#
# handling AOI 0727w-417n (46 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-417n.pkl
#
# handling AOI 0727w-418n (47 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-418n.pkl
#
# handling AOI 0727w-419n (48 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-419n.pkl
#
# handling AOI 0727w-420n (49 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-420n.pkl
#
# handling AOI 0727w-421n (50 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-421n.pkl
#
# handling AOI 0727w-422n (51 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-422n.pkl
#
# handling AOI 0727w-423n (52 / 263)
# 58 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-423n.pkl
#
# handling AOI 0726w-416n (53 / 263)
# 40 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-416n.pkl
#
# handling AOI 0726w-417n (54 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-417n.pkl
#
# handling AOI 0726w-418n (55 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-418n.pkl
#
# handling AOI 0726w-419n (56 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-419n.pkl
#
# handling AOI 0726w-420n (57 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-420n.pkl
#
# handling AOI 0726w-421n (58 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-421n.pkl
#
# handling AOI 0726w-422n (59 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-422n.pkl
#
# handling AOI 0726w-423n (60 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-423n.pkl
#
# handling AOI 0726w-442n (61 / 263)
# 56 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-442n.pkl
#
# handling AOI 0725w-413n (62 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-413n.pkl
#
# handling AOI 0725w-418n (63 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-418n.pkl
#
# handling AOI 0725w-419n (64 / 263)
# 48 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-419n.pkl
#
# handling AOI 0725w-420n (65 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-420n.pkl
#
# handling AOI 0725w-421n (66 / 263)
# 62 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-421n.pkl
#
# handling AOI 0724w-421n (67 / 263)
# 53 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0724w-421n.pkl
#
# handling AOI 0724w-436n (68 / 263)
# 49 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0724w-436n.pkl
#
# handling AOI 0723w-413n (69 / 263)
# 50 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-413n.pkl
#
# handling AOI 0723w-417n (70 / 263)
# 54 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-417n.pkl
#
# handling AOI 0723w-429n (71 / 263)
# 36 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-429n.pkl
#
# handling AOI 0723w-436n (72 / 263)
# 51 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-436n.pkl
#
# handling AOI 0722w-413n (73 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-413n.pkl
#
# handling AOI 0722w-414n (74 / 263)
# 52 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-414n.pkl
#
# handling AOI 0722w-415n (75 / 263)
# 50 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-415n.pkl
#
# handling AOI 0721w-413n (76 / 263)
# 54 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-413n.pkl
#
# handling AOI 0721w-414n (77 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-414n.pkl
#
# handling AOI 0721w-415n (78 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-415n.pkl
#
# handling AOI 0720w-413n (79 / 263)
# 50 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-413n.pkl
#
# handling AOI 0720w-422n (80 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-422n.pkl
#
# handling AOI 0720w-425n (81 / 263)
# 46 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-425n.pkl
#
# handling AOI 0719w-413n (82 / 263)
# 58 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-413n.pkl
#
# handling AOI 0719w-418n (83 / 263)
# 65 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-418n.pkl
#
# handling AOI 0719w-420n (84 / 263)
# 65 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-420n.pkl
#
# handling AOI 0719w-421n (85 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-421n.pkl
#
# handling AOI 0719w-422n (86 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-422n.pkl
#
# handling AOI 0719w-423n (87 / 263)
# 65 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-423n.pkl
#
# handling AOI 0719w-425n (88 / 263)
# 55 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-425n.pkl
#
# handling AOI 0718w-421n (89 / 263)
# 58 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-421n.pkl
#
# handling AOI 0718w-422n (90 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-422n.pkl
#
# handling AOI 0718w-423n (91 / 263)
# 53 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-423n.pkl
#
# handling AOI 0718w-424n (92 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-424n.pkl
#
# handling AOI 0718w-425n (93 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-425n.pkl
#
# handling AOI 0717w-420n (94 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-420n.pkl
#
# handling AOI 0717w-421n (95 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-421n.pkl
#
# handling AOI 0717w-422n (96 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-422n.pkl
#
# handling AOI 0717w-423n (97 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-423n.pkl
#
# handling AOI 0717w-424n (98 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-424n.pkl
#
# handling AOI 0717w-425n (99 / 263)
# 65 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-425n.pkl
#
# handling AOI 0717w-428n (100 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-428n.pkl
#
# handling AOI 0716w-416n (101 / 263)
# 67 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-416n.pkl
#
# handling AOI 0716w-417n (102 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-417n.pkl
#
# handling AOI 0716w-418n (103 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-418n.pkl
#
# handling AOI 0716w-419n (104 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-419n.pkl
#
# handling AOI 0716w-420n (105 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-420n.pkl
#
# handling AOI 0716w-421n (106 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-421n.pkl
#
# handling AOI 0716w-422n (107 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-422n.pkl
#
# handling AOI 0716w-423n (108 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-423n.pkl
#
# handling AOI 0716w-424n (109 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-424n.pkl
#
# handling AOI 0716w-425n (110 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-425n.pkl
#
# handling AOI 0716w-426n (111 / 263)
# 67 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-426n.pkl
#
# handling AOI 0716w-427n (112 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-427n.pkl
#
# handling AOI 0716w-428n (113 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-428n.pkl
#
# handling AOI 0716w-429n (114 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-429n.pkl
#
# handling AOI 0716w-432n (115 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-432n.pkl
#
# handling AOI 0715w-414n (116 / 263)
# 56 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-414n.pkl
#
# handling AOI 0715w-415n (117 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-415n.pkl
#
# handling AOI 0715w-416n (118 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-416n.pkl
#
# handling AOI 0715w-417n (119 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-417n.pkl
#
# handling AOI 0715w-418n (120 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-418n.pkl
#
# handling AOI 0715w-419n (121 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-419n.pkl
#
# handling AOI 0715w-420n (122 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-420n.pkl
#
# handling AOI 0715w-421n (123 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-421n.pkl
#
# handling AOI 0715w-422n (124 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-422n.pkl
#
# handling AOI 0715w-423n (125 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-423n.pkl
#
# handling AOI 0715w-424n (126 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-424n.pkl
#
# handling AOI 0715w-425n (127 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-425n.pkl
#
# handling AOI 0715w-426n (128 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-426n.pkl
#
# handling AOI 0715w-427n (129 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-427n.pkl
#
# handling AOI 0715w-428n (130 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-428n.pkl
#
# handling AOI 0715w-429n (131 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-429n.pkl
#
# handling AOI 0715w-430n (132 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-430n.pkl
#
# handling AOI 0715w-435n (133 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-435n.pkl
#
# handling AOI 0714w-417n (134 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-417n.pkl
#
# handling AOI 0714w-418n (135 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-418n.pkl
#
# handling AOI 0714w-419n (136 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-419n.pkl
#
# handling AOI 0714w-420n (137 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-420n.pkl
#
# handling AOI 0714w-421n (138 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-421n.pkl
#
# handling AOI 0714w-422n (139 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-422n.pkl
#
# handling AOI 0714w-423n (140 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-423n.pkl
#
# handling AOI 0714w-424n (141 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-424n.pkl
#
# handling AOI 0714w-425n (142 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-425n.pkl
#
# handling AOI 0714w-426n (143 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-426n.pkl
#
# handling AOI 0714w-427n (144 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-427n.pkl
#
# handling AOI 0714w-428n (145 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-428n.pkl
#
# handling AOI 0714w-429n (146 / 263)
# 47 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-429n.pkl
#
# handling AOI 0713w-415n (147 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-415n.pkl
#
# handling AOI 0713w-416n (148 / 263)
# 53 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-416n.pkl
#
# handling AOI 0713w-417n (149 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-417n.pkl
#
# handling AOI 0713w-419n (150 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-419n.pkl
#
# handling AOI 0713w-420n (151 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-420n.pkl
#
# handling AOI 0713w-421n (152 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-421n.pkl
#
# handling AOI 0713w-422n (153 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-422n.pkl
#
# handling AOI 0713w-423n (154 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-423n.pkl
#
# handling AOI 0713w-424n (155 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-424n.pkl
#
# handling AOI 0713w-425n (156 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-425n.pkl
#
# handling AOI 0713w-426n (157 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-426n.pkl
#
# handling AOI 0713w-427n (158 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-427n.pkl
#
# handling AOI 0713w-428n (159 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-428n.pkl
#
# handling AOI 0712w-416n (160 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-416n.pkl
#
# handling AOI 0712w-417n (161 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-417n.pkl
#
# handling AOI 0712w-418n (162 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-418n.pkl
#
# handling AOI 0712w-419n (163 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-419n.pkl
#
# handling AOI 0712w-420n (164 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-420n.pkl
#
# handling AOI 0712w-421n (165 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-421n.pkl
#
# handling AOI 0712w-422n (166 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-422n.pkl
#
# handling AOI 0712w-423n (167 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-423n.pkl
#
# handling AOI 0712w-424n (168 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-424n.pkl
#
# handling AOI 0712w-425n (169 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-425n.pkl
#
# handling AOI 0712w-426n (170 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-426n.pkl
#
# handling AOI 0712w-427n (171 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-427n.pkl
#
# handling AOI 0712w-428n (172 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-428n.pkl
#
# handling AOI 0711w-416n (173 / 263)
# 67 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-416n.pkl
#
# handling AOI 0711w-418n (174 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-418n.pkl
#
# handling AOI 0711w-419n (175 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-419n.pkl
#
# handling AOI 0711w-420n (176 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-420n.pkl
#
# handling AOI 0711w-421n (177 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-421n.pkl
#
# handling AOI 0711w-422n (178 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-422n.pkl
#
# handling AOI 0711w-423n (179 / 263)
# 67 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-423n.pkl
#
# handling AOI 0711w-424n (180 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-424n.pkl
#
# handling AOI 0711w-425n (181 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-425n.pkl
#
# handling AOI 0711w-426n (182 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-426n.pkl
#
# handling AOI 0711w-427n (183 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-427n.pkl
#
# handling AOI 0711w-428n (184 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-428n.pkl
#
# handling AOI 0710w-416n (185 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-416n.pkl
#
# handling AOI 0710w-417n (186 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-417n.pkl
#
# handling AOI 0710w-418n (187 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-418n.pkl
#
# handling AOI 0710w-419n (188 / 263)
# 64 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-419n.pkl
#
# handling AOI 0710w-420n (189 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-420n.pkl
#
# handling AOI 0710w-421n (190 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-421n.pkl
#
# handling AOI 0710w-422n (191 / 263)
# 54 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-422n.pkl
#
# handling AOI 0710w-424n (192 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-424n.pkl
#
# handling AOI 0710w-425n (193 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-425n.pkl
#
# handling AOI 0710w-426n (194 / 263)
# 67 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-426n.pkl
#
# handling AOI 0710w-427n (195 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-427n.pkl
#
# handling AOI 0710w-428n (196 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-428n.pkl
#
# handling AOI 0710w-429n (197 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-429n.pkl
#
# handling AOI 0710w-430n (198 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-430n.pkl
#
# handling AOI 0710w-432n (199 / 263)
# 60 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-432n.pkl
#
# handling AOI 0710w-433n (200 / 263)
# 52 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-433n.pkl
#
# handling AOI 0709w-416n (201 / 263)
# 52 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-416n.pkl
#
# handling AOI 0709w-420n (202 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-420n.pkl
#
# handling AOI 0709w-421n (203 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-421n.pkl
#
# handling AOI 0709w-422n (204 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-422n.pkl
#
# handling AOI 0709w-425n (205 / 263)
# 58 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-425n.pkl
#
# handling AOI 0709w-426n (206 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-426n.pkl
#
# handling AOI 0709w-428n (207 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-428n.pkl
#
# handling AOI 0709w-429n (208 / 263)
# 69 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-429n.pkl
#
# handling AOI 0709w-430n (209 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-430n.pkl
#
# handling AOI 0709w-431n (210 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-431n.pkl
#
# handling AOI 0709w-432n (211 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-432n.pkl
#
# handling AOI 0708w-417n (212 / 263)
# 68 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-417n.pkl
#
# handling AOI 0708w-419n (213 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-419n.pkl
#
# handling AOI 0708w-420n (214 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-420n.pkl
#
# handling AOI 0708w-421n (215 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-421n.pkl
#
# handling AOI 0708w-422n (216 / 263)
# 26 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-422n.pkl
#
# handling AOI 0708w-430n (217 / 263)
# 67 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-430n.pkl
#
# handling AOI 0708w-431n (218 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-431n.pkl
#
# handling AOI 0707w-415n (219 / 263)
# 37 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-415n.pkl
#
# handling AOI 0707w-416n (220 / 263)
# 32 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-416n.pkl
#
# handling AOI 0707w-417n (221 / 263)
# 61 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-417n.pkl
#
# handling AOI 0707w-419n (222 / 263)
# 50 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-419n.pkl
#
# handling AOI 0707w-420n (223 / 263)
# 40 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-420n.pkl
#
# handling AOI 0707w-426n (224 / 263)
# 58 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-426n.pkl
#
# handling AOI 0707w-431n (225 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-431n.pkl
#
# handling AOI 0706w-414n (226 / 263)
# 31 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-414n.pkl
#
# handling AOI 0706w-415n (227 / 263)
# 39 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-415n.pkl
#
# handling AOI 0706w-416n (228 / 263)
# 52 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-416n.pkl
#
# handling AOI 0706w-417n (229 / 263)
# 43 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-417n.pkl
#
# handling AOI 0706w-418n (230 / 263)
# 54 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-418n.pkl
#
# handling AOI 0706w-433n (231 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-433n.pkl
#
# handling AOI 0705w-416n (232 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-416n.pkl
#
# handling AOI 0705w-417n (233 / 263)
# 41 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-417n.pkl
#
# handling AOI 0705w-434n (234 / 263)
# 62 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-434n.pkl
#
# handling AOI 0705w-435n (235 / 263)
# 66 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-435n.pkl
#
# handling AOI 0705w-438n (236 / 263)
# 49 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-438n.pkl
#
# handling AOI 0704w-416n (237 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-416n.pkl
#
# handling AOI 0704w-435n (238 / 263)
# 59 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-435n.pkl
#
# handling AOI 0704w-436n (239 / 263)
# 70 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-436n.pkl
#
# handling AOI 0704w-437n (240 / 263)
# 54 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-437n.pkl
#
# handling AOI 0703w-416n (241 / 263)
# 50 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-416n.pkl
#
# handling AOI 0703w-436n (242 / 263)
# 55 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-436n.pkl
#
# handling AOI 0703w-437n (243 / 263)
# 57 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-437n.pkl
#
# handling AOI 0703w-440n (244 / 263)
# 44 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-440n.pkl
#
# handling AOI 0702w-416n (245 / 263)
# 40 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-416n.pkl
#
# handling AOI 0702w-417n (246 / 263)
# 46 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-417n.pkl
#
# handling AOI 0702w-440n (247 / 263)
# 28 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-440n.pkl
#
# handling AOI 0701w-416n (248 / 263)
# 28 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-416n.pkl
#
# handling AOI 0701w-417n (249 / 263)
# 63 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-417n.pkl
#
# handling AOI 0701w-419n (250 / 263)
# 39 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-419n.pkl
#
# handling AOI 0700w-417n (251 / 263)
# 35 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-417n.pkl
#
# handling AOI 0700w-418n (252 / 263)
# 31 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-418n.pkl
#
# handling AOI 0700w-439n (253 / 263)
# 42 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-439n.pkl
#
# handling AOI 0699w-439n (254 / 263)
# 27 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0699w-439n.pkl
#
# handling AOI 0698w-442n (255 / 263)
# 39 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0698w-442n.pkl
#
# handling AOI 0698w-443n (256 / 263)
# 51 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0698w-443n.pkl
#
# handling AOI 0697w-438n (257 / 263)
# 45 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0697w-438n.pkl
#
# handling AOI 0697w-445n (258 / 263)
# 50 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0697w-445n.pkl
#
# handling AOI 0689w-447n (259 / 263)
# 36 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0689w-447n.pkl
#
# handling AOI 0688w-447n (260 / 263)
# 29 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0688w-447n.pkl
#
# handling AOI 0688w-448n (261 / 263)
# 37 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0688w-448n.pkl
#
# handling AOI 0687w-449n (262 / 263)
# 37 tiles
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0687w-449n.pkl

# %% [markdown]
# ## QA / visualizations

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Create a 2D array (example data)
# data = tile_encodings_for_aoi[0]

# # Plot as heatmap
# plt.imshow(data, cmap='viridis', origin='upper')
# plt.colorbar(label='Intensity')
# plt.title('encodings')
# plt.ylabel('entity number')
# plt.xlabel('encoding element')
# plt.show()

# %%
# gdf[['category', 'label']].value_counts().sort_index()
