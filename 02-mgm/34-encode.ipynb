# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Encode geospatial data for VERGE processing
#
# Elsewhere we assembled geospatial data for a bunch of tiles.
# Here we come up with encodings for each such entitiy.
# The encodings will consist of a concatenation of a Multi-Point Proximity (MPP) encoding
# and a one-hot vector indicating the entity type.
#
# ## Outputs:
# * data/encodings/*.pkl: encodings for tiles; one file per AOI

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# !pip install geo-encodings
# Out:
# Mounted at /content/drive
# Collecting geo-encodings
#   Downloading geo_encodings-1.0.4-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (2.0.2)
# Downloading geo_encodings-1.0.4-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: geo-encodings
# Successfully installed geo-encodings-1.0.4

# %%
# Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook setup

# %%
import pandas as pd
import numpy as np
import glob
import geopandas
import os
import pickle
import json
from geo_encodings import MPPEncoder

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# # A unique identifier for this run.
# run_id = '201'

# %% [markdown]
# ## Data prep

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %%
# Read the list of labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)
num_classes = len(labels)
print('%d labels' % num_classes)

label_id_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
# Out:
# 22 labels

# %%
# Set up the MPP encoder.
encoder = MPPEncoder(
    region=[0, 0, tile_size, tile_size],
    resolution=encoding_resolution,
    center=True
)
print('%d elements in encodings' % len(encoder))
# Out:
# 400 elements in encodings

# %% [markdown]
# ## Processing

# %%
fname = '%s/tiles.csv' % roi_home
tile_info = pd.read_csv(fname)
print('%d tiles in this ROI' % len(tile_info))
tile_info.head(3)
# Out:
# 15793 tiles in this ROI
#       aoi_tag tile_tag      lon0       lat0       lon1       lat1  center_lon  \
# 0  0735w-413n  005-005 -73.50000  41.300000 -73.476879  41.318544  -73.488440
# 1  0735w-413n  005-006 -73.50037  41.308994 -73.477246  41.327538  -73.488808
# 2  0735w-413n  005-007 -73.50074  41.317988 -73.477613  41.336533  -73.489176
#
#    center_lat
# 0   41.309272
# 1   41.318266
# 2   41.327260

# %%
aoi_tags = np.unique(tile_info['aoi_tag'].values)

# %%
# Loop over AOIs

for k, aoi_tag in enumerate(aoi_tags):

    # Check whether the output file already exists.
    fname = '%s/encodings/%s.pkl' % (roi_home, aoi_tag)
    if os.path.exists(fname):
      print('\nskipping %s' % (fname))
      continue

    print('\nhandling AOI %s (%d / %d)' % (aoi_tag, k, len(aoi_tags)))

    # Get a list of the tile tags for this AOI.
    iok = tile_info['aoi_tag'] == aoi_tag
    tile_tags = tile_info['tile_tag'].values[iok]

    # This will hold all encodings for this AOI
    tile_encodings_for_this_aoi = []

    # Loop over tiles.
    for tile_tag in tile_tags:

        print('tile tag %s' % tile_tag)

        tile_vectors = []
        tile_labels = []
        tile_fname = '%s/tiles/%s/%s.pq' % (roi_home, aoi_tag, tile_tag)
        gdf = geopandas.read_parquet(tile_fname)
        for _, rec in gdf.sample(frac=1).iterrows():

            # Geometric encoding vector
            encoding = encoder.encode(rec['geometry']).values()

            # One-hot label vector
            etype = np.zeros(num_classes)
            label_string = '%s : %s' % (rec['category'], rec['label'])
            label_id = label_id_lookup[label_string]
            etype[label_id] = 1.0

            # Save the label as an integer too. This will make training easier.
            tile_labels.append(label_id)

            # Concatenate the encoding and type vectors.
            vector = np.hstack((etype, encoding))
            tile_vectors.append(vector)

        # Combine all per-feature vectors into one big feature matrix.
        tile_features = np.vstack(tile_vectors)

        tile_encodings_for_this_aoi.append({
            'aoi_tag': aoi_tag,
            'tile_tag': tile_tag,
            'features': tile_features,
            'labels': np.array(tile_labels),
        })

    # Save all of the encodings for this tile.
    fname = '%s/encodings/%s.pkl' % (roi_home, aoi_tag)
    os.makedirs(os.path.dirname(fname), exist_ok=True)
    with open(fname, 'wb') as dest:
        pickle.dump(tile_encodings_for_this_aoi, dest)
    print('wrote %s' % (fname))
# Out:
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0687w-449n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0688w-447n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0688w-448n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0689w-447n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0697w-438n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0697w-445n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0698w-442n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0698w-443n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0699w-439n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0700w-439n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0701w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0702w-440n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-436n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-437n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0703w-440n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-435n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-436n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0704w-437n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-434n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-435n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0705w-438n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0706w-433n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0707w-431n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-430n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0708w-431n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-429n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-430n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-431n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0709w-432n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-429n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-430n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-432n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0710w-433n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0711w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0712w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0713w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0714w-429n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-429n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-430n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0715w-435n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-427n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-429n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0716w-432n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0717w-428n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0718w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0719w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0720w-425n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0721w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0722w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-429n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0723w-436n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0724w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0724w-436n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0725w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0726w-442n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-422n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0727w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-419n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-420n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0728w-421n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0729w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-417n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0730w-436n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-416n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0731w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-418n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-426n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-444n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0732w-445n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-423n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-424n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-444n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0733w-445n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0734w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-413n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-414n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-415n.pkl
#
# skipping /content/drive/MyDrive/Projects/verge/data/newengland/encodings/0735w-446n.pkl

# %% [markdown]
# ## QA and visualizations

# %%
import glob
globstring = '%s/encodings/*.pkl' % roi_home
fnames = glob.glob(globstring)
print(len(fnames))
# Out:
# 263
