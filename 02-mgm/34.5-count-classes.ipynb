# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Count classes
#
# ## Outputs:
# * dat/class_info.csv: info on distribution of classes

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# !pip install geo-encodings
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: geo-encodings in /usr/local/lib/python3.11/dist-packages (1.0.4)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (2.0.2)

# %%
# Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook setup

# %%
import pandas as pd
import numpy as np
import glob
import geopandas
import os
import pickle
import json
from geo_encodings import MPPEncoder

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# Sample this many tiles.
sample_size = 1000

# %% [markdown]
# ## Data prep

# %%
# Read the list of labels.
fname = '%s/labels.csv' % data_home
labels = pd.read_csv(fname)
num_classes = len(labels)
print('%d labels' % num_classes)

label_id_lookup = {
    z['label']: z['id']
    for z in labels.to_dict('records')
}
# Out:
# 22 labels

# %% [markdown]
# ## Processing

# %%
fname = '%s/tiles.csv' % roi_home
tile_info = pd.read_csv(fname)
print('%d tiles in this ROI' % len(tile_info))
tile_info.head(3)
# Out:
# 15793 tiles in this ROI
#       aoi_tag tile_tag      lon0       lat0       lon1       lat1  center_lon  \
# 0  0735w-413n  005-005 -73.50000  41.300000 -73.476879  41.318544  -73.488440
# 1  0735w-413n  005-006 -73.50037  41.308994 -73.477246  41.327538  -73.488808
# 2  0735w-413n  005-007 -73.50074  41.317988 -73.477613  41.336533  -73.489176
#
#    center_lat
# 0   41.309272
# 1   41.318266
# 2   41.327260

# %%
# In the loop below, we will also accumulate a histogram of class labels.
# This will be saved and used during model training to balance sampling.
class_counts = {z: 0 for z in range(num_classes)}

# %%
tile_records = tile_info.to_dict('records')
for k, rec in enumerate(np.random.choice(tile_records, sample_size)):
    if k % 10 == 0:
      print('sampling tile %d / %d' % (k, sample_size))
    tile_fname = '%s/tiles/%s/%s.pq' % (roi_home, rec['aoi_tag'], rec['tile_tag'])
    gdf = geopandas.read_parquet(tile_fname)
    for _, gent in gdf.iterrows():

        etype = np.zeros(num_classes)
        label_string = '%s : %s' % (gent['category'], gent['label'])
        label_id = label_id_lookup[label_string]
        class_counts[label_id] += 1

#
# Out:
# sampling tile 0 / 1000
# sampling tile 1 / 1000
# sampling tile 2 / 1000
# sampling tile 3 / 1000
# sampling tile 4 / 1000
# sampling tile 5 / 1000
# sampling tile 6 / 1000
# sampling tile 7 / 1000
# sampling tile 8 / 1000
# sampling tile 9 / 1000
# sampling tile 10 / 1000
# sampling tile 11 / 1000
# sampling tile 12 / 1000
# sampling tile 13 / 1000
# sampling tile 14 / 1000
# sampling tile 15 / 1000
# sampling tile 16 / 1000
# sampling tile 17 / 1000
# sampling tile 18 / 1000
# sampling tile 19 / 1000
# sampling tile 20 / 1000
# sampling tile 21 / 1000
# sampling tile 22 / 1000
# sampling tile 23 / 1000
# sampling tile 24 / 1000
# sampling tile 25 / 1000
# sampling tile 26 / 1000
# sampling tile 27 / 1000
# sampling tile 28 / 1000
# sampling tile 29 / 1000
# sampling tile 30 / 1000
# sampling tile 31 / 1000
# sampling tile 32 / 1000
# sampling tile 33 / 1000
# sampling tile 34 / 1000
# sampling tile 35 / 1000
# sampling tile 36 / 1000
# sampling tile 37 / 1000
# sampling tile 38 / 1000
# sampling tile 39 / 1000
# sampling tile 40 / 1000
# sampling tile 41 / 1000
# sampling tile 42 / 1000
# sampling tile 43 / 1000
# sampling tile 44 / 1000
# sampling tile 45 / 1000
# sampling tile 46 / 1000
# sampling tile 47 / 1000
# sampling tile 48 / 1000
# sampling tile 49 / 1000
# sampling tile 50 / 1000
# sampling tile 51 / 1000
# sampling tile 52 / 1000
# sampling tile 53 / 1000
# sampling tile 54 / 1000
# sampling tile 55 / 1000
# sampling tile 56 / 1000
# sampling tile 57 / 1000
# sampling tile 58 / 1000
# sampling tile 59 / 1000
# sampling tile 60 / 1000
# sampling tile 61 / 1000
# sampling tile 62 / 1000
# sampling tile 63 / 1000
# sampling tile 64 / 1000
# sampling tile 65 / 1000
# sampling tile 66 / 1000
# sampling tile 67 / 1000
# sampling tile 68 / 1000
# sampling tile 69 / 1000
# sampling tile 70 / 1000
# sampling tile 71 / 1000
# sampling tile 72 / 1000
# sampling tile 73 / 1000
# sampling tile 74 / 1000
# sampling tile 75 / 1000
# sampling tile 76 / 1000
# sampling tile 77 / 1000
# sampling tile 78 / 1000
# sampling tile 79 / 1000
# sampling tile 80 / 1000
# sampling tile 81 / 1000
# sampling tile 82 / 1000
# sampling tile 83 / 1000
# sampling tile 84 / 1000
# sampling tile 85 / 1000
# sampling tile 86 / 1000
# sampling tile 87 / 1000
# sampling tile 88 / 1000
# sampling tile 89 / 1000
# sampling tile 90 / 1000
# sampling tile 91 / 1000
# sampling tile 92 / 1000
# sampling tile 93 / 1000
# sampling tile 94 / 1000
# sampling tile 95 / 1000
# sampling tile 96 / 1000
# sampling tile 97 / 1000
# sampling tile 98 / 1000
# sampling tile 99 / 1000
# sampling tile 100 / 1000
# sampling tile 101 / 1000
# sampling tile 102 / 1000
# sampling tile 103 / 1000
# sampling tile 104 / 1000
# sampling tile 105 / 1000
# sampling tile 106 / 1000
# sampling tile 107 / 1000
# sampling tile 108 / 1000
# sampling tile 109 / 1000
# sampling tile 110 / 1000
# sampling tile 111 / 1000
# sampling tile 112 / 1000
# sampling tile 113 / 1000
# sampling tile 114 / 1000
# sampling tile 115 / 1000
# sampling tile 116 / 1000
# sampling tile 117 / 1000
# sampling tile 118 / 1000
# sampling tile 119 / 1000
# sampling tile 120 / 1000
# sampling tile 121 / 1000
# sampling tile 122 / 1000
# sampling tile 123 / 1000
# sampling tile 124 / 1000
# sampling tile 125 / 1000
# sampling tile 126 / 1000
# sampling tile 127 / 1000
# sampling tile 128 / 1000
# sampling tile 129 / 1000
# sampling tile 130 / 1000
# sampling tile 131 / 1000
# sampling tile 132 / 1000
# sampling tile 133 / 1000
# sampling tile 134 / 1000
# sampling tile 135 / 1000
# sampling tile 136 / 1000
# sampling tile 137 / 1000
# sampling tile 138 / 1000
# sampling tile 139 / 1000
# sampling tile 140 / 1000
# sampling tile 141 / 1000
# sampling tile 142 / 1000
# sampling tile 143 / 1000
# sampling tile 144 / 1000
# sampling tile 145 / 1000
# sampling tile 146 / 1000
# sampling tile 147 / 1000
# sampling tile 148 / 1000
# sampling tile 149 / 1000
# sampling tile 150 / 1000
# sampling tile 151 / 1000
# sampling tile 152 / 1000
# sampling tile 153 / 1000
# sampling tile 154 / 1000
# sampling tile 155 / 1000
# sampling tile 156 / 1000
# sampling tile 157 / 1000
# sampling tile 158 / 1000
# sampling tile 159 / 1000
# sampling tile 160 / 1000
# sampling tile 161 / 1000
# sampling tile 162 / 1000
# sampling tile 163 / 1000
# sampling tile 164 / 1000
# sampling tile 165 / 1000
# sampling tile 166 / 1000
# sampling tile 167 / 1000
# sampling tile 168 / 1000
# sampling tile 169 / 1000
# sampling tile 170 / 1000
# sampling tile 171 / 1000
# sampling tile 172 / 1000
# sampling tile 173 / 1000
# sampling tile 174 / 1000
# sampling tile 175 / 1000
# sampling tile 176 / 1000
# sampling tile 177 / 1000
# sampling tile 178 / 1000
# sampling tile 179 / 1000
# sampling tile 180 / 1000
# sampling tile 181 / 1000
# sampling tile 182 / 1000
# sampling tile 183 / 1000
# sampling tile 184 / 1000
# sampling tile 185 / 1000
# sampling tile 186 / 1000
# sampling tile 187 / 1000
# sampling tile 188 / 1000
# sampling tile 189 / 1000
# sampling tile 190 / 1000
# sampling tile 191 / 1000
# sampling tile 192 / 1000
# sampling tile 193 / 1000
# sampling tile 194 / 1000
# sampling tile 195 / 1000
# sampling tile 196 / 1000
# sampling tile 197 / 1000
# sampling tile 198 / 1000
# sampling tile 199 / 1000
# sampling tile 200 / 1000
# sampling tile 201 / 1000
# sampling tile 202 / 1000
# sampling tile 203 / 1000
# sampling tile 204 / 1000
# sampling tile 205 / 1000
# sampling tile 206 / 1000
# sampling tile 207 / 1000
# sampling tile 208 / 1000
# sampling tile 209 / 1000
# sampling tile 210 / 1000
# sampling tile 211 / 1000
# sampling tile 212 / 1000
# sampling tile 213 / 1000
# sampling tile 214 / 1000
# sampling tile 215 / 1000
# sampling tile 216 / 1000
# sampling tile 217 / 1000
# sampling tile 218 / 1000
# sampling tile 219 / 1000
# sampling tile 220 / 1000
# sampling tile 221 / 1000
# sampling tile 222 / 1000
# sampling tile 223 / 1000
# sampling tile 224 / 1000
# sampling tile 225 / 1000
# sampling tile 226 / 1000
# sampling tile 227 / 1000
# sampling tile 228 / 1000
# sampling tile 229 / 1000
# sampling tile 230 / 1000
# sampling tile 231 / 1000
# sampling tile 232 / 1000
# sampling tile 233 / 1000
# sampling tile 234 / 1000
# sampling tile 235 / 1000
# sampling tile 236 / 1000
# sampling tile 237 / 1000
# sampling tile 238 / 1000
# sampling tile 239 / 1000
# sampling tile 240 / 1000
# sampling tile 241 / 1000
# sampling tile 242 / 1000
# sampling tile 243 / 1000
# sampling tile 244 / 1000
# sampling tile 245 / 1000
# sampling tile 246 / 1000
# sampling tile 247 / 1000
# sampling tile 248 / 1000
# sampling tile 249 / 1000
# sampling tile 250 / 1000
# sampling tile 251 / 1000
# sampling tile 252 / 1000
# sampling tile 253 / 1000
# sampling tile 254 / 1000
# sampling tile 255 / 1000
# sampling tile 256 / 1000
# sampling tile 257 / 1000
# sampling tile 258 / 1000
# sampling tile 259 / 1000
# sampling tile 260 / 1000
# sampling tile 261 / 1000
# sampling tile 262 / 1000
# sampling tile 263 / 1000
# sampling tile 264 / 1000
# sampling tile 265 / 1000
# sampling tile 266 / 1000
# sampling tile 267 / 1000
# sampling tile 268 / 1000
# sampling tile 269 / 1000
# sampling tile 270 / 1000
# sampling tile 271 / 1000
# sampling tile 272 / 1000
# sampling tile 273 / 1000
# sampling tile 274 / 1000
# sampling tile 275 / 1000
# sampling tile 276 / 1000
# sampling tile 277 / 1000
# sampling tile 278 / 1000
# sampling tile 279 / 1000
# sampling tile 280 / 1000
# sampling tile 281 / 1000
# sampling tile 282 / 1000
# sampling tile 283 / 1000
# sampling tile 284 / 1000
# sampling tile 285 / 1000
# sampling tile 286 / 1000
# sampling tile 287 / 1000
# sampling tile 288 / 1000
# sampling tile 289 / 1000
# sampling tile 290 / 1000
# sampling tile 291 / 1000
# sampling tile 292 / 1000
# sampling tile 293 / 1000
# sampling tile 294 / 1000
# sampling tile 295 / 1000
# sampling tile 296 / 1000
# sampling tile 297 / 1000
# sampling tile 298 / 1000
# sampling tile 299 / 1000
# sampling tile 300 / 1000
# sampling tile 301 / 1000
# sampling tile 302 / 1000
# sampling tile 303 / 1000
# sampling tile 304 / 1000
# sampling tile 305 / 1000
# sampling tile 306 / 1000
# sampling tile 307 / 1000
# sampling tile 308 / 1000
# sampling tile 309 / 1000
# sampling tile 310 / 1000
# sampling tile 311 / 1000
# sampling tile 312 / 1000
# sampling tile 313 / 1000
# sampling tile 314 / 1000
# sampling tile 315 / 1000
# sampling tile 316 / 1000
# sampling tile 317 / 1000
# sampling tile 318 / 1000
# sampling tile 319 / 1000
# sampling tile 320 / 1000
# sampling tile 321 / 1000
# sampling tile 322 / 1000
# sampling tile 323 / 1000
# sampling tile 324 / 1000
# sampling tile 325 / 1000
# sampling tile 326 / 1000
# sampling tile 327 / 1000
# sampling tile 328 / 1000
# sampling tile 329 / 1000
# sampling tile 330 / 1000
# sampling tile 331 / 1000
# sampling tile 332 / 1000
# sampling tile 333 / 1000
# sampling tile 334 / 1000
# sampling tile 335 / 1000
# sampling tile 336 / 1000
# sampling tile 337 / 1000
# sampling tile 338 / 1000
# sampling tile 339 / 1000
# sampling tile 340 / 1000
# sampling tile 341 / 1000
# sampling tile 342 / 1000
# sampling tile 343 / 1000
# sampling tile 344 / 1000
# sampling tile 345 / 1000
# sampling tile 346 / 1000
# sampling tile 347 / 1000
# sampling tile 348 / 1000
# sampling tile 349 / 1000
# sampling tile 350 / 1000
# sampling tile 351 / 1000
# sampling tile 352 / 1000
# sampling tile 353 / 1000
# sampling tile 354 / 1000
# sampling tile 355 / 1000
# sampling tile 356 / 1000
# sampling tile 357 / 1000
# sampling tile 358 / 1000
# sampling tile 359 / 1000
# sampling tile 360 / 1000
# sampling tile 361 / 1000
# sampling tile 362 / 1000
# sampling tile 363 / 1000
# sampling tile 364 / 1000
# sampling tile 365 / 1000
# sampling tile 366 / 1000
# sampling tile 367 / 1000
# sampling tile 368 / 1000
# sampling tile 369 / 1000
# sampling tile 370 / 1000
# sampling tile 371 / 1000
# sampling tile 372 / 1000
# sampling tile 373 / 1000
# sampling tile 374 / 1000
# sampling tile 375 / 1000
# sampling tile 376 / 1000
# sampling tile 377 / 1000
# sampling tile 378 / 1000
# sampling tile 379 / 1000
# sampling tile 380 / 1000
# sampling tile 381 / 1000
# sampling tile 382 / 1000
# sampling tile 383 / 1000
# sampling tile 384 / 1000
# sampling tile 385 / 1000
# sampling tile 386 / 1000
# sampling tile 387 / 1000
# sampling tile 388 / 1000
# sampling tile 389 / 1000
# sampling tile 390 / 1000
# sampling tile 391 / 1000
# sampling tile 392 / 1000
# sampling tile 393 / 1000
# sampling tile 394 / 1000
# sampling tile 395 / 1000
# sampling tile 396 / 1000
# sampling tile 397 / 1000
# sampling tile 398 / 1000
# sampling tile 399 / 1000
# sampling tile 400 / 1000
# sampling tile 401 / 1000
# sampling tile 402 / 1000
# sampling tile 403 / 1000
# sampling tile 404 / 1000
# sampling tile 405 / 1000
# sampling tile 406 / 1000
# sampling tile 407 / 1000
# sampling tile 408 / 1000
# sampling tile 409 / 1000
# sampling tile 410 / 1000
# sampling tile 411 / 1000
# sampling tile 412 / 1000
# sampling tile 413 / 1000
# sampling tile 414 / 1000
# sampling tile 415 / 1000
# sampling tile 416 / 1000
# sampling tile 417 / 1000
# sampling tile 418 / 1000
# sampling tile 419 / 1000
# sampling tile 420 / 1000
# sampling tile 421 / 1000
# sampling tile 422 / 1000
# sampling tile 423 / 1000
# sampling tile 424 / 1000
# sampling tile 425 / 1000
# sampling tile 426 / 1000
# sampling tile 427 / 1000
# sampling tile 428 / 1000
# sampling tile 429 / 1000
# sampling tile 430 / 1000
# sampling tile 431 / 1000
# sampling tile 432 / 1000
# sampling tile 433 / 1000
# sampling tile 434 / 1000
# sampling tile 435 / 1000
# sampling tile 436 / 1000
# sampling tile 437 / 1000
# sampling tile 438 / 1000
# sampling tile 439 / 1000
# sampling tile 440 / 1000
# sampling tile 441 / 1000
# sampling tile 442 / 1000
# sampling tile 443 / 1000
# sampling tile 444 / 1000
# sampling tile 445 / 1000
# sampling tile 446 / 1000
# sampling tile 447 / 1000
# sampling tile 448 / 1000
# sampling tile 449 / 1000
# sampling tile 450 / 1000
# sampling tile 451 / 1000
# sampling tile 452 / 1000
# sampling tile 453 / 1000
# sampling tile 454 / 1000
# sampling tile 455 / 1000
# sampling tile 456 / 1000
# sampling tile 457 / 1000
# sampling tile 458 / 1000
# sampling tile 459 / 1000
# sampling tile 460 / 1000
# sampling tile 461 / 1000
# sampling tile 462 / 1000
# sampling tile 463 / 1000
# sampling tile 464 / 1000
# sampling tile 465 / 1000
# sampling tile 466 / 1000
# sampling tile 467 / 1000
# sampling tile 468 / 1000
# sampling tile 469 / 1000
# sampling tile 470 / 1000
# sampling tile 471 / 1000
# sampling tile 472 / 1000
# sampling tile 473 / 1000
# sampling tile 474 / 1000
# sampling tile 475 / 1000
# sampling tile 476 / 1000
# sampling tile 477 / 1000
# sampling tile 478 / 1000
# sampling tile 479 / 1000
# sampling tile 480 / 1000
# sampling tile 481 / 1000
# sampling tile 482 / 1000
# sampling tile 483 / 1000
# sampling tile 484 / 1000
# sampling tile 485 / 1000
# sampling tile 486 / 1000
# sampling tile 487 / 1000
# sampling tile 488 / 1000
# sampling tile 489 / 1000
# sampling tile 490 / 1000
# sampling tile 491 / 1000
# sampling tile 492 / 1000
# sampling tile 493 / 1000
# sampling tile 494 / 1000
# sampling tile 495 / 1000
# sampling tile 496 / 1000
# sampling tile 497 / 1000
# sampling tile 498 / 1000
# sampling tile 499 / 1000
# sampling tile 500 / 1000
# sampling tile 501 / 1000
# sampling tile 502 / 1000
# sampling tile 503 / 1000
# sampling tile 504 / 1000
# sampling tile 505 / 1000
# sampling tile 506 / 1000
# sampling tile 507 / 1000
# sampling tile 508 / 1000
# sampling tile 509 / 1000
# sampling tile 510 / 1000
# sampling tile 511 / 1000
# sampling tile 512 / 1000
# sampling tile 513 / 1000
# sampling tile 514 / 1000
# sampling tile 515 / 1000
# sampling tile 516 / 1000
# sampling tile 517 / 1000
# sampling tile 518 / 1000
# sampling tile 519 / 1000
# sampling tile 520 / 1000
# sampling tile 521 / 1000
# sampling tile 522 / 1000
# sampling tile 523 / 1000
# sampling tile 524 / 1000
# sampling tile 525 / 1000
# sampling tile 526 / 1000
# sampling tile 527 / 1000
# sampling tile 528 / 1000
# sampling tile 529 / 1000
# sampling tile 530 / 1000
# sampling tile 531 / 1000
# sampling tile 532 / 1000
# sampling tile 533 / 1000
# sampling tile 534 / 1000
# sampling tile 535 / 1000
# sampling tile 536 / 1000
# sampling tile 537 / 1000
# sampling tile 538 / 1000
# sampling tile 539 / 1000
# sampling tile 540 / 1000
# sampling tile 541 / 1000
# sampling tile 542 / 1000
# sampling tile 543 / 1000
# sampling tile 544 / 1000
# sampling tile 545 / 1000
# sampling tile 546 / 1000
# sampling tile 547 / 1000
# sampling tile 548 / 1000
# sampling tile 549 / 1000
# sampling tile 550 / 1000
# sampling tile 551 / 1000
# sampling tile 552 / 1000
# sampling tile 553 / 1000
# sampling tile 554 / 1000
# sampling tile 555 / 1000
# sampling tile 556 / 1000
# sampling tile 557 / 1000
# sampling tile 558 / 1000
# sampling tile 559 / 1000
# sampling tile 560 / 1000
# sampling tile 561 / 1000
# sampling tile 562 / 1000
# sampling tile 563 / 1000
# sampling tile 564 / 1000
# sampling tile 565 / 1000
# sampling tile 566 / 1000
# sampling tile 567 / 1000
# sampling tile 568 / 1000
# sampling tile 569 / 1000
# sampling tile 570 / 1000
# sampling tile 571 / 1000
# sampling tile 572 / 1000
# sampling tile 573 / 1000
# sampling tile 574 / 1000
# sampling tile 575 / 1000
# sampling tile 576 / 1000
# sampling tile 577 / 1000
# sampling tile 578 / 1000
# sampling tile 579 / 1000
# sampling tile 580 / 1000
# sampling tile 581 / 1000
# sampling tile 582 / 1000
# sampling tile 583 / 1000
# sampling tile 584 / 1000
# sampling tile 585 / 1000
# sampling tile 586 / 1000
# sampling tile 587 / 1000
# sampling tile 588 / 1000
# sampling tile 589 / 1000
# sampling tile 590 / 1000
# sampling tile 591 / 1000
# sampling tile 592 / 1000
# sampling tile 593 / 1000
# sampling tile 594 / 1000
# sampling tile 595 / 1000
# sampling tile 596 / 1000
# sampling tile 597 / 1000
# sampling tile 598 / 1000
# sampling tile 599 / 1000
# sampling tile 600 / 1000
# sampling tile 601 / 1000
# sampling tile 602 / 1000
# sampling tile 603 / 1000
# sampling tile 604 / 1000
# sampling tile 605 / 1000
# sampling tile 606 / 1000
# sampling tile 607 / 1000
# sampling tile 608 / 1000
# sampling tile 609 / 1000
# sampling tile 610 / 1000
# sampling tile 611 / 1000
# sampling tile 612 / 1000
# sampling tile 613 / 1000
# sampling tile 614 / 1000
# sampling tile 615 / 1000
# sampling tile 616 / 1000
# sampling tile 617 / 1000
# sampling tile 618 / 1000
# sampling tile 619 / 1000
# sampling tile 620 / 1000
# sampling tile 621 / 1000
# sampling tile 622 / 1000
# sampling tile 623 / 1000
# sampling tile 624 / 1000
# sampling tile 625 / 1000
# sampling tile 626 / 1000
# sampling tile 627 / 1000
# sampling tile 628 / 1000
# sampling tile 629 / 1000
# sampling tile 630 / 1000
# sampling tile 631 / 1000
# sampling tile 632 / 1000
# sampling tile 633 / 1000
# sampling tile 634 / 1000
# sampling tile 635 / 1000
# sampling tile 636 / 1000
# sampling tile 637 / 1000
# sampling tile 638 / 1000
# sampling tile 639 / 1000
# sampling tile 640 / 1000
# sampling tile 641 / 1000
# sampling tile 642 / 1000
# sampling tile 643 / 1000
# sampling tile 644 / 1000
# sampling tile 645 / 1000
# sampling tile 646 / 1000
# sampling tile 647 / 1000
# sampling tile 648 / 1000
# sampling tile 649 / 1000
# sampling tile 650 / 1000
# sampling tile 651 / 1000
# sampling tile 652 / 1000
# sampling tile 653 / 1000
# sampling tile 654 / 1000
# sampling tile 655 / 1000
# sampling tile 656 / 1000
# sampling tile 657 / 1000
# sampling tile 658 / 1000
# sampling tile 659 / 1000
# sampling tile 660 / 1000
# sampling tile 661 / 1000
# sampling tile 662 / 1000
# sampling tile 663 / 1000
# sampling tile 664 / 1000
# sampling tile 665 / 1000
# sampling tile 666 / 1000
# sampling tile 667 / 1000
# sampling tile 668 / 1000
# sampling tile 669 / 1000
# sampling tile 670 / 1000
# sampling tile 671 / 1000
# sampling tile 672 / 1000
# sampling tile 673 / 1000
# sampling tile 674 / 1000
# sampling tile 675 / 1000
# sampling tile 676 / 1000
# sampling tile 677 / 1000
# sampling tile 678 / 1000
# sampling tile 679 / 1000
# sampling tile 680 / 1000
# sampling tile 681 / 1000
# sampling tile 682 / 1000
# sampling tile 683 / 1000
# sampling tile 684 / 1000
# sampling tile 685 / 1000
# sampling tile 686 / 1000
# sampling tile 687 / 1000
# sampling tile 688 / 1000
# sampling tile 689 / 1000
# sampling tile 690 / 1000
# sampling tile 691 / 1000
# sampling tile 692 / 1000
# sampling tile 693 / 1000
# sampling tile 694 / 1000
# sampling tile 695 / 1000
# sampling tile 696 / 1000
# sampling tile 697 / 1000
# sampling tile 698 / 1000
# sampling tile 699 / 1000
# sampling tile 700 / 1000
# sampling tile 701 / 1000
# sampling tile 702 / 1000
# sampling tile 703 / 1000
# sampling tile 704 / 1000
# sampling tile 705 / 1000
# sampling tile 706 / 1000
# sampling tile 707 / 1000
# sampling tile 708 / 1000
# sampling tile 709 / 1000
# sampling tile 710 / 1000
# sampling tile 711 / 1000
# sampling tile 712 / 1000
# sampling tile 713 / 1000
# sampling tile 714 / 1000
# sampling tile 715 / 1000
# sampling tile 716 / 1000
# sampling tile 717 / 1000
# sampling tile 718 / 1000
# sampling tile 719 / 1000
# sampling tile 720 / 1000
# sampling tile 721 / 1000
# sampling tile 722 / 1000
# sampling tile 723 / 1000
# sampling tile 724 / 1000
# sampling tile 725 / 1000
# sampling tile 726 / 1000
# sampling tile 727 / 1000
# sampling tile 728 / 1000
# sampling tile 729 / 1000
# sampling tile 730 / 1000
# sampling tile 731 / 1000
# sampling tile 732 / 1000
# sampling tile 733 / 1000
# sampling tile 734 / 1000
# sampling tile 735 / 1000
# sampling tile 736 / 1000
# sampling tile 737 / 1000
# sampling tile 738 / 1000
# sampling tile 739 / 1000
# sampling tile 740 / 1000
# sampling tile 741 / 1000
# sampling tile 742 / 1000
# sampling tile 743 / 1000
# sampling tile 744 / 1000
# sampling tile 745 / 1000
# sampling tile 746 / 1000
# sampling tile 747 / 1000
# sampling tile 748 / 1000
# sampling tile 749 / 1000
# sampling tile 750 / 1000
# sampling tile 751 / 1000
# sampling tile 752 / 1000
# sampling tile 753 / 1000
# sampling tile 754 / 1000
# sampling tile 755 / 1000
# sampling tile 756 / 1000
# sampling tile 757 / 1000
# sampling tile 758 / 1000
# sampling tile 759 / 1000
# sampling tile 760 / 1000
# sampling tile 761 / 1000
# sampling tile 762 / 1000
# sampling tile 763 / 1000
# sampling tile 764 / 1000
# sampling tile 765 / 1000
# sampling tile 766 / 1000
# sampling tile 767 / 1000
# sampling tile 768 / 1000
# sampling tile 769 / 1000
# sampling tile 770 / 1000
# sampling tile 771 / 1000
# sampling tile 772 / 1000
# sampling tile 773 / 1000
# sampling tile 774 / 1000
# sampling tile 775 / 1000
# sampling tile 776 / 1000
# sampling tile 777 / 1000
# sampling tile 778 / 1000
# sampling tile 779 / 1000
# sampling tile 780 / 1000
# sampling tile 781 / 1000
# sampling tile 782 / 1000
# sampling tile 783 / 1000
# sampling tile 784 / 1000
# sampling tile 785 / 1000
# sampling tile 786 / 1000
# sampling tile 787 / 1000
# sampling tile 788 / 1000
# sampling tile 789 / 1000
# sampling tile 790 / 1000
# sampling tile 791 / 1000
# sampling tile 792 / 1000
# sampling tile 793 / 1000
# sampling tile 794 / 1000
# sampling tile 795 / 1000
# sampling tile 796 / 1000
# sampling tile 797 / 1000
# sampling tile 798 / 1000
# sampling tile 799 / 1000
# sampling tile 800 / 1000
# sampling tile 801 / 1000
# sampling tile 802 / 1000
# sampling tile 803 / 1000
# sampling tile 804 / 1000
# sampling tile 805 / 1000
# sampling tile 806 / 1000
# sampling tile 807 / 1000
# sampling tile 808 / 1000
# sampling tile 809 / 1000
# sampling tile 810 / 1000
# sampling tile 811 / 1000
# sampling tile 812 / 1000
# sampling tile 813 / 1000
# sampling tile 814 / 1000
# sampling tile 815 / 1000
# sampling tile 816 / 1000
# sampling tile 817 / 1000
# sampling tile 818 / 1000
# sampling tile 819 / 1000
# sampling tile 820 / 1000
# sampling tile 821 / 1000
# sampling tile 822 / 1000
# sampling tile 823 / 1000
# sampling tile 824 / 1000
# sampling tile 825 / 1000
# sampling tile 826 / 1000
# sampling tile 827 / 1000
# sampling tile 828 / 1000
# sampling tile 829 / 1000
# sampling tile 830 / 1000
# sampling tile 831 / 1000
# sampling tile 832 / 1000
# sampling tile 833 / 1000
# sampling tile 834 / 1000
# sampling tile 835 / 1000
# sampling tile 836 / 1000
# sampling tile 837 / 1000
# sampling tile 838 / 1000
# sampling tile 839 / 1000
# sampling tile 840 / 1000
# sampling tile 841 / 1000
# sampling tile 842 / 1000
# sampling tile 843 / 1000
# sampling tile 844 / 1000
# sampling tile 845 / 1000
# sampling tile 846 / 1000
# sampling tile 847 / 1000
# sampling tile 848 / 1000
# sampling tile 849 / 1000
# sampling tile 850 / 1000
# sampling tile 851 / 1000
# sampling tile 852 / 1000
# sampling tile 853 / 1000
# sampling tile 854 / 1000
# sampling tile 855 / 1000
# sampling tile 856 / 1000
# sampling tile 857 / 1000
# sampling tile 858 / 1000
# sampling tile 859 / 1000
# sampling tile 860 / 1000
# sampling tile 861 / 1000
# sampling tile 862 / 1000
# sampling tile 863 / 1000
# sampling tile 864 / 1000
# sampling tile 865 / 1000
# sampling tile 866 / 1000
# sampling tile 867 / 1000
# sampling tile 868 / 1000
# sampling tile 869 / 1000
# sampling tile 870 / 1000
# sampling tile 871 / 1000
# sampling tile 872 / 1000
# sampling tile 873 / 1000
# sampling tile 874 / 1000
# sampling tile 875 / 1000
# sampling tile 876 / 1000
# sampling tile 877 / 1000
# sampling tile 878 / 1000
# sampling tile 879 / 1000
# sampling tile 880 / 1000
# sampling tile 881 / 1000
# sampling tile 882 / 1000
# sampling tile 883 / 1000
# sampling tile 884 / 1000
# sampling tile 885 / 1000
# sampling tile 886 / 1000
# sampling tile 887 / 1000
# sampling tile 888 / 1000
# sampling tile 889 / 1000
# sampling tile 890 / 1000
# sampling tile 891 / 1000
# sampling tile 892 / 1000
# sampling tile 893 / 1000
# sampling tile 894 / 1000
# sampling tile 895 / 1000
# sampling tile 896 / 1000
# sampling tile 897 / 1000
# sampling tile 898 / 1000
# sampling tile 899 / 1000
# sampling tile 900 / 1000
# sampling tile 901 / 1000
# sampling tile 902 / 1000
# sampling tile 903 / 1000
# sampling tile 904 / 1000
# sampling tile 905 / 1000
# sampling tile 906 / 1000
# sampling tile 907 / 1000
# sampling tile 908 / 1000
# sampling tile 909 / 1000
# sampling tile 910 / 1000
# sampling tile 911 / 1000
# sampling tile 912 / 1000
# sampling tile 913 / 1000
# sampling tile 914 / 1000
# sampling tile 915 / 1000
# sampling tile 916 / 1000
# sampling tile 917 / 1000
# sampling tile 918 / 1000
# sampling tile 919 / 1000
# sampling tile 920 / 1000
# sampling tile 921 / 1000
# sampling tile 922 / 1000
# sampling tile 923 / 1000
# sampling tile 924 / 1000
# sampling tile 925 / 1000
# sampling tile 926 / 1000
# sampling tile 927 / 1000
# sampling tile 928 / 1000
# sampling tile 929 / 1000
# sampling tile 930 / 1000
# sampling tile 931 / 1000
# sampling tile 932 / 1000
# sampling tile 933 / 1000
# sampling tile 934 / 1000
# sampling tile 935 / 1000
# sampling tile 936 / 1000
# sampling tile 937 / 1000
# sampling tile 938 / 1000
# sampling tile 939 / 1000
# sampling tile 940 / 1000
# sampling tile 941 / 1000
# sampling tile 942 / 1000
# sampling tile 943 / 1000
# sampling tile 944 / 1000
# sampling tile 945 / 1000
# sampling tile 946 / 1000
# sampling tile 947 / 1000
# sampling tile 948 / 1000
# sampling tile 949 / 1000
# sampling tile 950 / 1000
# sampling tile 951 / 1000
# sampling tile 952 / 1000
# sampling tile 953 / 1000
# sampling tile 954 / 1000
# sampling tile 955 / 1000
# sampling tile 956 / 1000
# sampling tile 957 / 1000
# sampling tile 958 / 1000
# sampling tile 959 / 1000
# sampling tile 960 / 1000
# sampling tile 961 / 1000
# sampling tile 962 / 1000
# sampling tile 963 / 1000
# sampling tile 964 / 1000
# sampling tile 965 / 1000
# sampling tile 966 / 1000
# sampling tile 967 / 1000
# sampling tile 968 / 1000
# sampling tile 969 / 1000
# sampling tile 970 / 1000
# sampling tile 971 / 1000
# sampling tile 972 / 1000
# sampling tile 973 / 1000
# sampling tile 974 / 1000
# sampling tile 975 / 1000
# sampling tile 976 / 1000
# sampling tile 977 / 1000
# sampling tile 978 / 1000
# sampling tile 979 / 1000
# sampling tile 980 / 1000
# sampling tile 981 / 1000
# sampling tile 982 / 1000
# sampling tile 983 / 1000
# sampling tile 984 / 1000
# sampling tile 985 / 1000
# sampling tile 986 / 1000
# sampling tile 987 / 1000
# sampling tile 988 / 1000
# sampling tile 989 / 1000
# sampling tile 990 / 1000
# sampling tile 991 / 1000
# sampling tile 992 / 1000
# sampling tile 993 / 1000
# sampling tile 994 / 1000
# sampling tile 995 / 1000
# sampling tile 996 / 1000
# sampling tile 997 / 1000
# sampling tile 998 / 1000
# sampling tile 999 / 1000

# %%
class_counts
# Out:
# {0: 1024,
#  1: 1423,
#  2: 12499,
#  3: 57,
#  4: 1593,
#  5: 732,
#  6: 558,
#  7: 672,
#  8: 540,
#  9: 659,
#  10: 3822,
#  11: 425,
#  12: 2033,
#  13: 150,
#  14: 4458,
#  15: 6261,
#  16: 48741,
#  17: 6914,
#  18: 5119,
#  19: 1716,
#  20: 1000,
#  21: 11196}

# %%
# Save the label probabilities.
total = 0.0
for key in class_counts:
    total += class_counts[key]

records = [
    {
        'label': z,
        'count': class_counts[z],
        'prob': class_counts[z] / total
    } for z in range(num_classes)
]
fname = '%s/class_info.csv' % roi_home
pd.DataFrame(records).to_csv(fname, index=False)
print('wrote %s' % fname)
# Out:
# wrote /content/drive/MyDrive/Projects/verge/data/newengland/class_info.csv
