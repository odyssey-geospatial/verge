# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Assemble geographical data for the VERGE project
#
# This notebook pulls and organizes the geospatial data that we will use in this effort.
#
# We have a list of AOIs, defined as lon/lat bounding boxes. Here we pull data for each one,
# and divide it up into tiles of a given size.

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
# import os
# from google.colab import drive
# drive.mount('/content/drive')
# project_home = '/content/drive/MyDrive/Projects/verge'
# os.chdir(project_home)

# %%
# !pip install osmnx pygeohash geo-encodings

# %%
# # Local processing setup
project_home = '..'

# %%
# !pwd
# Out:
# /Users/john/dev/projects/verge/02-mgm

# %% [markdown]
# ## Notebook setup

# %%
import numpy as np
import pandas as pd
import pyproj
import shapely
import osmnx
import pygeohash
import geopandas as gpd
import os
import copy
import json

import plotly
from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter

from geo_encodings import draw_shape

import sys
sys.path.append(project_home)
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'ne-laptop'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# A tile has to contain this many entities in order to be retained.
min_entity_count = 20

# Set to True if we want to include the overall land/water polygon for each tile.
include_land_water = True

# If not None, then only process this many AOIs
aoi_limit = 20

# %% [markdown]
# ## Preliminaries

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %%
# Define a local map projection, using the definition from the ROI file.
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse

proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# This function gets an overall land/water polygon for an AOI.
# It does it by conasidering both the "coastlines" shapefile
# and all polygonal water features.

# Read the coastline file.
if include_land_water:
    fname = '%s/coastlines' % (roi_home)
    coastlines_gdf = gpd.read_file(fname)
    print('%d coastline polygons' % len(coastlines_gdf))

def get_land_water(bounds, features):

    # Create a baseline polygon consisting of the whole AOI.
    landwater = copy.deepcopy(bounds)

    # Intersect that with the coastlines data.
    coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
    landwater = landwater.intersection(coastlines)

    # subtract out any polygonal water feature.
    for _, f in features.iterrows():
        if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
            if f['natural'] == 'water':
                landwater = shapely.difference(landwater, f['geometry'])

    return landwater
# Out:
# 3514 coastline polygons

# %% [markdown]
# ## Processing

# %%
# Read the file with the list of AOIs
fname = '%s/aois.csv' % (roi_home)
aois = pd.read_csv(fname).to_dict('records')
# aois = np.random.permutation(aois)
print('%d areas of interest' % len(aois))
# Out:
# 263 areas of interest

# %%
aois[0]
# Out:
# {'aoi_tag': '0735w-413n',
#  'lon0': -73.5,
#  'lat0': 41.3,
#  'lon1': -73.4,
#  'lat1': 41.4}

# %%
# This will save some extra info that we will need.
tile_info = []

if aoi_limit is None:
    aoi_list = aois
else:
    aoi_list = aois[:aoi_limit]

for k, aoi in enumerate(aoi_list):

    print('\nprocessing AOI %s (%d / %d)' % (aoi['aoi_tag'], k, len(aoi_list)))

    # Use that projection to define lon/lat bounds for the query below. Make sure the bounds go
    # a little farther out than necessary to avoid edge artifacts from map projections.
    buffer = 0.01
    lon0 = aoi['lon0'] - buffer
    lat0 = aoi['lat0'] - buffer
    lon1 = aoi['lon1'] + buffer
    lat1 = aoi['lat1'] + buffer
    query_bounds = [lon0, lat0, lon1, lat1]

    # print('re-projected query bounds, with buffer:')
    # print(proj_forward(lon0, lat0))
    # print(proj_forward(lon1, lat1))

    # Query for all the geospatial entities we need within the bounding box.
    tags = {
        'landuse': True,
        'place': True,
        'highway': True,
        'railway': True,
        #'aeroway': True,
        'bridge': True,
        'tunnel': True,
        #'power': True,
        'natural': True,
        'waterway': True,
        'landcover': True,
        #'building': True,
        'amenity': True,
        'shop': True,
        'leisure': True
    }
    features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
    print('%d features from OSM' % len(features))

    # Re-format and filter everything.
    # BTW, "gents" is "geospatial entities".
    gents = []
    for feature in features.to_dict('records'):

        geomxy = shapely.ops.transform(proj_forward, feature['geometry'])
        if geomxy.is_empty:
            continue
        gtype = geomxy.geom_type

        for rule in rules:
            if gtype == rule['gtype']:
                osm_key = rule['osm_key']
                if osm_key in feature:
                    osm_value = str(feature[osm_key])
                    if osm_value in rule['osm_values']:
                        gents.append({
                            'feature': feature,
                            'category': rule['gent_category'],
                            'label': rule['gent_label'],
                            'geomxy': geomxy,
                            'gtype': gtype
                        })
    print('%d features selected' % len(gents))

    # We need some special handling to create a general "land/water" polygon.
    if include_land_water:
        lons = [lon0, lon1, lon1, lon0, lon0]
        lats = [lat0, lat0, lat1, lat1, lat0]
        lonlat_bounds = shapely.Polygon(list(zip(lons, lats)))
        landwater = get_land_water(lonlat_bounds, features)
        landwaterxy = shapely.ops.transform(proj_forward, landwater)
        gents.append({
            'category': 'waterway',
            'label': 'land',
            'geomxy': landwaterxy,
            'gtype': landwaterxy.geom_type
        })

    # Determine the AOI bounds in projected coordinates.
    aoi_x0, aoi_y0 = proj_forward(aoi['lon0'], aoi['lat0'])
    aoi_x1, aoi_y1 = proj_forward(aoi['lon1'], aoi['lat1'])

    # Loop over tiles within this AOI.
    x0 = aoi_x0
    while x0 + tile_size < aoi_x1:

        y0 = aoi_y0
        while y0 + tile_size < aoi_y1:

            # print('tile xo, yo:', x0, y0)

            # Figure out the lon/lat center of this tile. We will need it
            # for some later processing.
            tile_lon0, tile_lat0 = proj_inverse(x0, y0)
            tile_lon1, tile_lat1 = proj_inverse(x0 + tile_size, y0 + tile_size)
            tile_lon_center = (tile_lon0 + tile_lon1) / 2
            tile_lat_center = (tile_lat0 + tile_lat1) / 2
            # xc = x0 + tile_size / 2
            # yc = y0 + tile_size / 2
            # tile_lon, tile_lat = proj_inverse(xc, yc)
            # print('tile lon, lat', tile_lon, tile_lat)

            # Define a bounding box in projected coordinates. It will be used
            # to clip geospatial entities below.
            x1 = x0 + tile_size
            y1 = y0 + tile_size
            xx = [x0, x1, x1, x0, x0]
            yy = [y0, y0, y1, y1, y0]
            tile_bbox = shapely.Polygon(list(zip(xx, yy)))

            tile_gents = []
            for gent in gents:
                geomxy = shapely.affinity.translate(
                    gent['geomxy'].intersection(tile_bbox),
                    xoff=-x0, yoff=-y0
                )
                if geomxy.is_empty:
                    continue
                tile_gents.append({
                    'category': gent['category'],
                    'label': gent['label'],
                    'geometry': geomxy,
                    'gtype': gent['gtype'],
                    'xoff': x0,
                    'yoff': y0,
                })
            # print('%d geospatial entities' % len(tile_gents))

            # Save that if it's big enough.
            if len(tile_gents) >= min_entity_count:
                tx = '%03d' % (x0 / tile_shift)
                ty = '%03d' % (y0 / tile_shift)
                tile_tag = '%s-%s' % (tx, ty)
                fname = '%s/tiles/%s/%s.pq' % (roi_home, aoi['aoi_tag'], tile_tag)
                os.makedirs(os.path.dirname(fname), exist_ok=True)
                gdf = gpd.GeoDataFrame(tile_gents).drop_duplicates()
                gdf.to_parquet(fname, index=False, compression="zstd")
                print('saved %s (%4d entities)' % (fname, len(gdf)))

                # Save the tile info.
                tile_info.append({
                    'aoi_tag': aoi['aoi_tag'],
                    'tile_tag': tile_tag,
                    'lon0': tile_lon0,
                    'lat0': tile_lat0,
                    'lon1': tile_lon1,
                    'lat1': tile_lat1,
                    'center_lon': tile_lon_center,
                    'center_lat': tile_lat_center,
                })

            y0 += tile_shift
        x0 += tile_shift

# Save the tile info.
fname = '%s/tiles.csv' % roi_home
pd.DataFrame(tile_info).to_csv(fname, index=False)
print('\nsaved tile info in %s' % fname)
# Out:
# processing AOI 0735w-413n (0 / 20)
# 11830 features from OSM
# 3256 features selected
# saved ../data/ne-laptop/tiles/0735w-413n/005-005.pq (  71 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-006.pq (  57 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-007.pq (  68 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-008.pq (  87 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-009.pq (  48 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-010.pq (  23 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-011.pq (  53 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-012.pq ( 130 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/005-013.pq ( 210 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-005.pq (  81 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-006.pq (  64 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-007.pq (  53 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-008.pq (  45 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-009.pq (  31 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-010.pq (  26 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-011.pq (  62 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-012.pq ( 176 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/006-013.pq ( 274 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-005.pq (  65 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-006.pq (  44 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-007.pq (  41 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-008.pq (  35 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-009.pq (  44 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-010.pq (  38 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-011.pq (  53 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-012.pq ( 143 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/007-013.pq ( 246 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-005.pq (  64 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-006.pq (  41 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-007.pq (  47 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-008.pq (  43 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-009.pq (  44 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-010.pq (  49 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-011.pq (  28 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-012.pq (  64 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/008-013.pq ( 247 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-005.pq (  52 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-006.pq (  66 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-007.pq (  79 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-008.pq (  47 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-009.pq (  27 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-010.pq (  40 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-011.pq (  41 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-012.pq (  87 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/009-013.pq ( 253 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-005.pq (  23 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-006.pq (  68 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-007.pq (  85 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-008.pq (  41 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-009.pq (  28 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-010.pq (  46 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-011.pq (  77 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-012.pq ( 142 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/010-013.pq ( 178 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-005.pq (  24 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-006.pq (  48 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-007.pq (  58 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-008.pq (  34 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-009.pq (  40 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-010.pq (  68 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-011.pq ( 208 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-012.pq ( 265 entities)
# saved ../data/ne-laptop/tiles/0735w-413n/011-013.pq ( 176 entities)
#
# processing AOI 0735w-414n (1 / 20)
# 16295 features from OSM
# 3352 features selected
# saved ../data/ne-laptop/tiles/0735w-414n/006-016.pq (  68 entities)
# saved ../data/ne-laptop/tiles/0735w-414n
pq (  54 entities)
# saved ../data/ne-laptop/tiles/0733w-413n/028-012.pq (  47 entities)
#
# processing AOI 0733w-414n (6 / 20)
# 9261 features from OSM
# 2060 features selected
# saved ../data/ne-laptop/tiles/0733w-414n/022-015.pq ( 162 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-016.pq ( 152 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-017.pq (  95 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-018.pq (  45 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-019.pq (  49 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-020.pq (  32 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-022.pq (  26 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/022-023.pq (  47 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-015.pq ( 128 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-016.pq ( 129 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-017.pq (  97 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-018.pq (  67 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-019.pq (  64 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-020.pq (  49 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-021.pq (  28 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-022.pq (  37 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/023-023.pq (  52 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-015.pq ( 102 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-016.pq (  73 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-017.pq (  74 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-018.pq (  86 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-019.pq (  67 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-020.pq (  41 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-021.pq (  27 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-022.pq (  38 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/024-023.pq (  66 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-015.pq (  67 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-016.pq (  48 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-017.pq (  90 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-018.pq ( 127 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-019.pq (  82 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-020.pq (  38 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-021.pq (  39 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-022.pq (  48 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/025-023.pq (  65 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-015.pq (  46 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-016.pq (  48 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-017.pq (  86 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-018.pq ( 107 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-019.pq (  69 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-020.pq (  91 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-021.pq ( 105 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-022.pq (  64 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/026-023.pq (  69 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-015.pq (  39 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-016.pq (  40 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-017.pq (  57 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-018.pq (  50 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-019.pq (  32 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-020.pq (  93 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-021.pq ( 174 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-022.pq ( 169 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/027-023.pq ( 151 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-015.pq (  23 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-016.pq (  24 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-017.pq (  45 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-018.pq (  51 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-019.pq (  35 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-020.pq (  43 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-021.pq ( 133 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-022.pq ( 326 entities)
# saved ../data/ne-laptop/tiles/0733w-414n/028-023.pq ( 284 entities)
#
# processing AOI 0733w-423n (7 / 20)
# 3078 features from OSM
# 928 features selected
# saved ../data/ne-laptop/tiles/0733w-423n/025-117.pq (  34 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/025-118.pq (  42 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/025-119.pq (  43 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/025-120.pq ( 104 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/025-121.pq (  97 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/025-122.pq (  26 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-116.pq (  20 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-117.pq (  39 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-118.pq (  83 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-119.pq (  88 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-120.pq ( 138 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-121.pq ( 126 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-122.pq (  41 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/026-123.pq (  28 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-115.pq (  70 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-116.pq (  54 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-117.pq (  35 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-118.pq (  76 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-119.pq (  83 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-120.pq (  69 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-121.pq (  62 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-122.pq (  37 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/027-123.pq (  29 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-115.pq ( 128 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-116.pq (  87 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-117.pq (  71 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-118.pq (  68 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-119.pq (  74 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-120.pq (  57 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-121.pq (  34 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-122.pq (  26 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/028-123.pq (  21 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/029-115.pq (  94 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/029-116.pq (  74 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/029-117.pq (  72 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/029-118.pq (  54 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/029-119.pq (  52 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/029-120.pq (  40 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/030-115.pq (  25 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/030-116.pq (  35 entities)
# saved ../data/ne-laptop/tiles/0733w-423n/030-117.pq (  29 entities)
#
# processing AOI 0733w-424n (8 / 20)
# 5874 features from OSM
# 2192 features selected
# saved ../data/ne-laptop/tiles/0733w-424n/026-128.pq (  25 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/026-129.pq (  79 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/026-130.pq (  95 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/026-131.pq (  39 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/026-132.pq (  21 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/026-133.pq (  21 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/026-134.pq (  30 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-126.pq (  31 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-127.pq (  21 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-128.pq (  25 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-129.pq (  72 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-130.pq (  89 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-131.pq (  60 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-132.pq (  35 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-133.pq (  46 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/027-134.pq (  45 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-126.pq (  87 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-127.pq (  91 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-128.pq (  82 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-129.pq ( 130 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-130.pq ( 276 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-131.pq ( 258 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-132.pq (  94 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-133.pq (  88 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/028-134.pq (  95 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/029-126.pq (  77 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/029-127.pq ( 100 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/029-128.pq ( 124 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/029-129.pq ( 187 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/029-130.pq ( 416 entities)
# saved ../data/ne-laptop/tiles/0733w-424n/029-131.pq ( 418 entities)
# saved ../data/ne-laptop/tiles/0733w-424n
entities)
# saved ../data/ne-laptop/tiles/0731w-415n/040-034.pq ( 185 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-026.pq ( 196 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-027.pq ( 105 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-028.pq ( 103 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-029.pq ( 132 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-030.pq ( 234 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-031.pq ( 275 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-032.pq ( 216 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-033.pq ( 169 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/041-034.pq ( 146 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-026.pq ( 236 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-027.pq ( 122 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-028.pq ( 134 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-029.pq ( 232 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-030.pq ( 407 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-031.pq ( 548 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-032.pq ( 417 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-033.pq ( 201 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/042-034.pq ( 178 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-026.pq ( 196 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-027.pq ( 134 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-028.pq ( 175 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-029.pq ( 274 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-030.pq ( 524 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-031.pq ( 707 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-032.pq ( 482 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-033.pq ( 245 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/043-034.pq ( 220 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-026.pq ( 106 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-027.pq ( 105 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-028.pq ( 160 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-029.pq ( 205 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-030.pq ( 383 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-031.pq ( 486 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-032.pq ( 339 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-033.pq ( 227 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/044-034.pq ( 168 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-026.pq ( 102 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-027.pq (  83 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-028.pq ( 133 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-029.pq ( 225 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-030.pq ( 298 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-031.pq ( 287 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-032.pq ( 203 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-033.pq ( 137 entities)
# saved ../data/ne-laptop/tiles/0731w-415n/045-034.pq (  90 entities)
#
# saved tile info in ../data/ne-laptop/tiles.csv

# %%
# for g in tile_gents:
#     print(g['geometry'].bounds)

# %%
# For debugging.

# def pr_feature(f):
#     print('feature')
#     for k in f:
#         if str(f[k]) != 'nan':
#             print('    ', k, f[k])

# def pr_gent(g):
#     for k in g:
#         if k == 'feature':
#             pr_feature(g[k])
#         else:
#             print(k, g[k])
#         geomxy = shapely.ops.transform(proj_inverse, feature['geometry'])

# pr_gent(gents[121])

# %%
pd.DataFrame(gents)[['category', 'label', 'gtype']].value_counts().sort_index()
# Out:
# category  label               gtype
# amenity   commercial          Point             31
#           food and drink      Point              9
#           parking lot         Polygon          667
#           recreation          Point              3
# landuse   agricultural        Polygon            4
#           commercial          Polygon            3
#           industrial          Polygon           24
#           meadow              Polygon            8
#           recreation          Polygon            8
#           residential         Polygon           14
#           retail              Polygon           16
# railway   rail                LineString        74
#           rail stop           Point              5
# route     highway             LineString       353
#           primary road        LineString       153
#           residential road    LineString      2302
#           secondary road      LineString       388
#           tertiary road       LineString       194
# waterway  lakes and ponds     Polygon           74
#           land                MultiPolygon       1
#           rivers and streams  LineString       394
#                               Polygon           10
# Name: count, dtype: int64

# %% [markdown]
# ## QA Check

# %%
# # Take a look at the land/water polygons.
# import folium
# center_lon = (lon0 + lon1) / 2.0
# center_lat = (lat0 + lat1) / 2.0

# map_center = [center_lat, center_lon]
# m = folium.Map(location=map_center, zoom_start=10)
# geo_json = folium.GeoJson(landwater)
# geo_json.add_to(m)
# m

# %%
# import folium
# center_lon = (lon0 + lon1) / 2.0
# center_lat = (lat0 + lat1) / 2.0

# map_center = [center_lat, center_lon]
# m = folium.Map(location=map_center, zoom_start=10)
# for gent in tile_gents:
#     g0 = gent['geometry']
#     g1 = shapely.affinity.translate(g0, xoff=gent['xoff'], yoff=gent['yoff'])
#     g2 = shapely.ops.transform(proj_inverse, g1)
#     geo_json = folium.GeoJson(g2)
#     geo_json.add_to(m)
# m
