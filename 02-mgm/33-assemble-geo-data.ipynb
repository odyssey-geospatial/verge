# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Assemble geographical data for the VERGE project
#
# This notebook pulls and organizes the geospatial data that we will use in this effort.
#
# We have a list of AOIs, defined as lon/lat bounding boxes. Here we pull data for each one,
# and divide it up into tiles of a given size.

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install osmnx pygeohash geo-encodings
# Out:
# Requirement already satisfied: osmnx in /usr/local/lib/python3.11/dist-packages (2.0.5)
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: geo-encodings in /usr/local/lib/python3.11/dist-packages (1.0.4)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (1.16.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)

# %%
# # Local processing setup
# project_home = '..'

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Projects/verge

# %% [markdown]
# ## Code

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import pyproj
import shapely
import osmnx
import pygeohash
import geopandas as gpd
import os
import copy
import json

import plotly
from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter

from geo_encodings import draw_shape

import sys
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# A tile has to contain this many entities in order to be retained.
min_entity_count = 20

# Set to True if we want to include the overall land/water polygon for each tile.
include_land_water = True

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %% [markdown]
# ## Preliminaries

# %%
# Define a local map projection
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse

proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# This function gets an overall land/water polygon for an AOI.
# It does it by conasidering both the "coastlines" shapefile
# and all polygonal water features.

# Read the coastline file.
if include_land_water:
    fname = '%s/coastlines' % (roi_home)
    coastlines_gdf = gpd.read_file(fname)
    print('%d coastline polygons' % len(coastlines_gdf))

def get_land_water(bounds, features):

    # Create a baseline polygon consisting of the whole AOI.
    landwater = copy.deepcopy(bounds)

    # Intersect that with the coastlines data.
    coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
    landwater = landwater.intersection(coastlines)

    # subtract out any polygonal water feature.
    for _, f in features.iterrows():
        if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
            if f['natural'] == 'water':
                landwater = shapely.difference(landwater, f['geometry'])

    return landwater
# Out:
# 3514 coastline polygons

# %% [markdown]
# ## Processing

# %%
# Read the file with the list of AOIs
fname = '%s/aois.csv' % (roi_home)
aois = pd.read_csv(fname).to_dict('records')
# aois = np.random.permutation(aois)
print('%d areas of interest' % len(aois))
# Out:
# 263 areas of interest

# %%
# This will save some extra info that we will need.
tile_info = []

for k, aoi in enumerate(aois):

    print('\nprocessing AOI %s (%d / %d)' % (aoi['name'], k, len(aois)))

    # Use that projection to define lon/lat bounds for the query below. Make sure the bounds go
    # a little farther out than necessary to avoid edge artifacts from map projections.
    buffer = 0.01
    lon0 = aoi['lon0'] - buffer
    lat0 = aoi['lat0'] - buffer
    lon1 = aoi['lon1'] + buffer
    lat1 = aoi['lat1'] + buffer
    query_bounds = [lon0, lat0, lon1, lat1]

    # print('re-projected query bounds, with buffer:')
    # print(proj_forward(lon0, lat0))
    # print(proj_forward(lon1, lat1))

    # Query for all the geospatial entities we need within the bounding box.
    print('getting OSM features')
    tags = {
        'landuse': True,
        'place': True,
        'highway': True,
        'railway': True,
        #'aeroway': True,
        'bridge': True,
        'tunnel': True,
        #'power': True,
        'natural': True,
        'waterway': True,
        'landcover': True,
        #'building': True,
        'amenity': True,
        'shop': True,
        'leisure': True
    }
    features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
    print('%d features from OSM' % len(features))

    # Re-format and filter everything.
    # BTW, "gents" is "geospatial entities".
    gents = []
    for feature in features.to_dict('records'):

        geomxy = shapely.ops.transform(proj_forward, feature['geometry'])
        if geomxy.is_empty:
            continue
        gtype = geomxy.geom_type

        for rule in rules:
            if gtype == rule['gtype']:
                osm_key = rule['osm_key']
                if osm_key in feature:
                    osm_value = str(feature[osm_key])
                    if osm_value in rule['osm_values']:
                        gents.append({
                            'feature': feature,
                            'category': rule['gent_category'],
                            'label': rule['gent_label'],
                            'geomxy': geomxy,
                            'gtype': gtype
                        })
    print('%d features selected' % len(gents))

    # We need some special handling to create a general "land/water" polygon.
    if include_land_water:
        lons = [lon0, lon1, lon1, lon0, lon0]
        lats = [lat0, lat0, lat1, lat1, lat0]
        lonlat_bounds = shapely.Polygon(list(zip(lons, lats)))
        landwater = get_land_water(lonlat_bounds, features)
        landwaterxy = shapely.ops.transform(proj_forward, landwater)
        gents.append({
            'category': 'waterway',
            'label': 'land',
            'geomxy': landwaterxy,
            'gtype': landwaterxy.geom_type
        })

    # Determine the AOI bounds in projected coordinates.
    aoi_x0, aoi_y0 = proj_forward(aoi['lon0'], aoi['lat0'])
    aoi_x1, aoi_y1 = proj_forward(aoi['lon1'], aoi['lat1'])

    # Loop over tiles within this AOI.
    x0 = aoi_x0
    while x0 + tile_size < aoi_x1:

        y0 = aoi_y0
        while y0 + tile_size < aoi_y1:

            # Figure out the lon/lat center of this tile. We will need it
            # for some later processing.
            xc = x0 + tile_size / 2
            yc = y0 + tile_size / 2
            tile_lon, tile_lat = proj_inverse(xc, yc)

            x1 = x0 + tile_size
            y1 = y0 + tile_size
            xx = [x0, x1, x1, x0, x0]
            yy = [y0, y0, y1, y1, y0]
            tile_bbox = shapely.Polygon(list(zip(xx, yy)))

            tile_gents = []
            for gent in gents:
                geomxy = shapely.affinity.translate(
                    gent['geomxy'].intersection(tile_bbox),
                    xoff=-x0, yoff=-y0
                )
                if geomxy.is_empty:
                    continue
                tile_gents.append({
                    'category': gent['category'],
                    'label': gent['label'],
                    'geometry': geomxy,
                    'gtype': gent['gtype'],
                    'xoff': x0,
                    'yoff': y0,
                })

            # Save that if it's big enough.
            if len(tile_gents) >= min_entity_count:
                tx = '%03d' % (x0 / tile_shift)
                ty = '%03d' % (y0 / tile_shift)
                fname = '%s/tiles/%s/%s-%s.pq' % (roi_home, aoi['name'], tx, ty)
                os.makedirs(os.path.dirname(fname), exist_ok=True)
                gdf = gpd.GeoDataFrame(tile_gents).drop_duplicates()
                gdf.to_parquet(fname, index=False, compression="zstd")
                # print('wrote %s (%d)' % (fname, len(gdf)))

                # Save the tile info.
                tile_info.append({
                    'fname': fname,
                    'center_lon': tile_lon,
                    'center_lat': tile_lat
                })

            y0 += tile_shift
        x0 += tile_shift

# Save the tile info.
fname = '%s/tile_info.csv' % roi_home
pd.DataFrame(tile_info).to_csv(fname, index=False)
print('saved tile info in %s' % fname)
# Out:
# processing AOI: 0735w-413n
# getting OSM features
# 11827 features from OSM
# 3254 features selected
#
# processing AOI: 0735w-414n
# getting OSM features
# 16283 features from OSM
# 3349 features selected
#
# processing AOI: 0735w-415n
# getting OSM features
# 6819 features from OSM
# 1550 features selected
#
# processing AOI: 0735w-446n
# getting OSM features
# 3536 features from OSM
# 938 features selected
#
# processing AOI: 0734w-414n
# getting OSM features
# 11773 features from OSM
# 2084 features selected
#
# processing AOI: 0733w-413n
# getting OSM features
# 8413 features from OSM
# 2041 features selected
#
# processing AOI: 0733w-414n
# getting OSM features
# 9025 features from OSM
# 2048 features selected
#
# processing AOI: 0733w-423n
# getting OSM features
# 3077 features from OSM
# 927 features selected
#
# processing AOI: 0733w-424n
# getting OSM features
# 5860 features from OSM
# 2191 features selected
#
# processing AOI: 0733w-444n
# getting OSM features
# 13191 features from OSM
# 2271 features selected
#
# processing AOI: 0733w-445n
# getting OSM features
# 4451 features from OSM
# 1112 features selected
#
# processing AOI: 0732w-413n
# getting OSM features
# 9638 features from OSM
# 2709 features selected
#
# processing AOI: 0732w-415n
# getting OSM features
# 7652 features from OSM
# 1826 features selected
#
# processing AOI: 0732w-418n
# getting OSM features
# 4346 features from OSM
# 1303 features selected
#
# processing AOI: 0732w-426n
# getting OSM features
# 5632 features from OSM
# 1534 features selected
#
# processing AOI: 0732w-444n
# getting OSM features
# 19137 features from OSM
# 3692 features selected
#
# processing AOI: 0732w-445n
# getting OSM features
# 7136 features from OSM
# 1901 features selected
#
# processing AOI: 0731w-413n
# getting OSM features
# 14505 features from OSM
# 4015 features selected
#
# processing AOI: 0731w-414n
# getting OSM features
# 10308 features from OSM
# 3000 features selected
#
# processing AOI: 0731w-415n
# getting OSM features
# 14460 features from OSM
# 4735 features selected
#
# processing AOI: 0731w-416n
# getting OSM features
# 5804 features from OSM
# 1816 features selected
#
# processing AOI: 0731w-418n
# getting OSM features
# 4777 features from OSM
# 935 features selected
#
# processing AOI: 0730w-413n
# getting OSM features
# 40613 features from OSM
# 7113 features selected
#
# processing AOI: 0730w-414n
# getting OSM features
# 10067 features from OSM
# 2285 features selected
#
# processing AOI: 0730w-415n
# getting OSM features
# 9510 features from OSM
# 2564 features selected
#
# processing AOI: 0730w-416n
# getting OSM features
# 13002 features from OSM
# 3225 features selected
#
# processing AOI: 0730w-417n
# getting OSM features
# 8027 features from OSM
# 1935 features selected
#
# processing AOI: 0730w-436n
# getting OSM features
# 4870 features from OSM
# 1070 features selected
#
# processing AOI: 0729w-413n
# getting OSM features
# 21323 features from OSM
# 4373 features selected
#
# processing AOI: 0729w-414n
# getting OSM features
# 15157 features from OSM
# 3469 features selected
#
# processing AOI: 0729w-415n
# getting OSM features
# 13798 features from OSM
# 3425 features selected
#
# processing AOI: 0729w-416n
# getting OSM features
# 14069 features from OSM
# 3858 features selected
#
# processing AOI: 0729w-417n
# getting OSM features
# 15795 features from OSM
# 3948 features selected
#
# processing AOI: 0729w-418n
# getting OSM features
# 13477 features from OSM
# 2399 features selected
#
# processing AOI: 0728w-413n
# getting OSM features
# 8183 features from OSM
# 1938 features selected
#
# processing AOI: 0728w-414n
# getting OSM features
# 7831 features from OSM
# 1922 features selected
#
# processing AOI: 0728w-415n
# getting OSM features
# 15091 features from OSM
# 3648 features selected
#
# processing AOI: 0728w-416n
# getting OSM features
# 19378 features from OSM
# 4753 features selected
#
# processing AOI: 0728w-417n
# getting OSM features
# 33405 features from OSM
# 6391 features selected
#
# processing AOI: 0728w-418n
# getting OSM features
# 15800 features from OSM
# 3013 features selected
#
# processing AOI: 0728w-419n
# getting OSM features
# 7858 features from OSM
# 1555 features selected
#
# processing AOI: 0728w-420n
# getting OSM features
# 5026 features from OSM
# 1140 features selected
#
# processing AOI: 0728w-421n
# getting OSM features
# 8826 features from OSM
# 1899 features selected
#
# processing AOI: 0727w-413n
# getting OSM features
# 6417 features from OSM
# 1285 features selected
#
# processing AOI: 0727w-415n
# getting OSM features
# 20768 features from OSM
# 4207 features selected
#
# processing AOI: 0727w-416n
# getting OSM features
# 14706 features from OSM
# 3531 features selected
#
# processing AOI: 0727w-417n
# getting OSM features
# 33256 features from OSM
# 7687 features selected
#
# processing AOI: 0727w-418n
# getting OSM features
# 13834 features from OSM
# 3315 features selected
#
# processing AOI: 0727w-419n
# getting OSM features
# 11853 features from OSM
# 2456 features selected
#
# processing AOI: 0727w-420n
# getting OSM features
# 10584 features from OSM
# 2718 features selected
#
# processing AOI: 0727w-421n
# getting OSM features
# 16944 features from OSM
# 4946 features selected
#
# processing AOI: 0727w-422n
# getting OSM features
# 10084 features from OSM
# 2736 features selected
#
# processing AOI: 0727w-423n
# getting OSM features
# 9690 features from OSM
# 2008 features selected
#
# processing AOI: 0726w-416n
# getting OSM features
# 7515 features from OSM
# 1655 features selected
#
# processing AOI: 0726w-417n
# getting OSM features
# 20342 features from OSM
# 4625 features selected
#
# processing AOI: 0726w-418n
# getting OSM features
# 12108 features from OSM
# 2719 features selected
#
# processing AOI: 0726w-419n
# getting OSM features
# 8522 features from OSM
# 1891 features selected
#
# processing AOI: 0726w-420n
# getting OSM features
# 16025 features from OSM
# 4433 features selected
#
# processing AOI: 0726w-421n
# getting OSM features
# 20514 features from OSM
# 6334 features selected
#
# processing AOI: 0726w-422n
# getting OSM features
# 9580 features from OSM
# 2205 features selected
#
# processing AOI: 0726w-423n
# getting OSM features
# 13417 features from OSM
# 2446 features selected
#
# processing AOI: 0726w-442n
# getting OSM features
# 7494 features from OSM
# 1800 features selected
#
# processing AOI: 0725w-413n
# getting OSM features
# 7127 features from OSM
# 1534 features selected
#
# processing AOI: 0725w-418n
# getting OSM features
# 8706 features from OSM
# 2018 features selected
#
# processing AOI: 0725w-419n
# getting OSM features
# 4765 features from OSM
# 1108 features selected
#
# processing AOI: 0725w-420n
# getting OSM features
# 5574 features from OSM
# 1605 features selected
#
# processing AOI: 0725w-421n
# getting OSM features
# 7464 features from OSM
# 2347 features selected
#
# processing AOI: 0724w-421n
# getting OSM features
# 4632 features from OSM
# 1394 features selected
#
# processing AOI: 0724w-436n
# getting OSM features
# 7975 features from OSM
# 1629 features selected
#
# processing AOI: 0723w-413n
# getting OSM features
# 6852 features from OSM
# 1716 features selected
#
# processing AOI: 0723w-417n
# getting OSM features
# 14732 features from OSM
# 2538 features selected
#
# processing AOI: 0723w-429n
# getting OSM features
# 9709 features from OSM
# 1582 features selected
#
# processing AOI: 0723w-436n
# getting OSM features
# 9372 features from OSM
# 1680 features selected
#
# processing AOI: 0722w-413n
# getting OSM features
# 12176 features from OSM
# 2949 features selected
#
# processing AOI: 0722w-414n
# getting OSM features
# 4325 features from OSM
# 1131 features selected
#
# processing AOI: 0722w-415n
# getting OSM features
# 7267 features from OSM
# 1973 features selected
#
# processing AOI: 0721w-413n
# getting OSM features
# 11709 features from OSM
# 2954 features selected
#
# processing AOI: 0721w-414n
# getting OSM features
# 5834 features from OSM
# 1526 features selected
#
# processing AOI: 0721w-415n
# getting OSM features
# 11591 features from OSM
# 2997 features selected
#
# processing AOI: 0720w-413n
# getting OSM features
# 7937 features from OSM
# 1741 features selected
#
# processing AOI: 0720w-422n
# getting OSM features
# 4117 features from OSM
# 1172 features selected
#
# processing AOI: 0720w-425n
# getting OSM features
# 11759 features from OSM
# 2085 features selected
#
# processing AOI: 0719w-413n
# getting OSM features
# 7217 features from OSM
# 2006 features selected
#
# processing AOI: 0719w-418n
# getting OSM features
# 5252 features from OSM
# 1580 features selected
#
# processing AOI: 0719w-420n
# getting OSM features
# 5310 features from OSM
# 1521 features selected
#
# processing AOI: 0719w-421n
# getting OSM features
# 8667 features from OSM
# 1822 features selected
#
# processing AOI: 0719w-422n
# getting OSM features
# 31995 features from OSM
# 5628 features selected
#
# processing AOI: 0719w-423n
# getting OSM features
# 11112 features from OSM
# 2115 features selected
#
# processing AOI: 0719w-425n
# getting OSM features
# 7936 features from OSM
# 2042 features selected
#
# processing AOI: 0718w-421n
# getting OSM features
# 6849 features from OSM
# 1488 features selected
#
# processing AOI: 0718w-422n
# getting OSM features
# 52344 features from OSM
# 6871 features selected
#
# processing AOI: 0718w-423n
# getting OSM features
# 20546 features from OSM
# 2757 features selected
#
# processing AOI: 0718w-424n
# getting OSM features
# 7504 features from OSM
# 1537 features selected
#
# processing AOI: 0718w-425n
# getting OSM features
# 18162 features from OSM
# 3776 features selected
#
# processing AOI: 0717w-420n
# getting OSM features
# 5761 features from OSM
# 1640 features selected
#
# processing AOI: 0717w-421n
# getting OSM features
# 6819 features from OSM
# 1558 features selected
#
# processing AOI: 0717w-422n
# getting OSM features
# 16334 features from OSM
# 2375 features selected
#
# processing AOI: 0717w-423n
# getting OSM features
# 12335 features from OSM
# 2034 features selected
#
# processing AOI: 0717w-424n
# getting OSM features
# 7808 features from OSM
# 1543 features selected
#
# processing AOI: 0717w-425n
# getting OSM features
# 6670 features from OSM
# 1350 features selected
#
# processing AOI: 0717w-428n
# getting OSM features
# 6056 features from OSM
# 1183 features selected
#
# processing AOI: 0716w-416n
# getting OSM features
# 11729 features from OSM
# 4000 features selected
#
# processing AOI: 0716w-417n
# getting OSM features
# 8896 features from OSM
# 3260 features selected
#
# processing AOI: 0716w-418n
# getting OSM features
# 10312 features from OSM
# 3499 features selected
#
# processing AOI: 0716w-419n
# getting OSM features
# 9562 features from OSM
# 3682 features selected
#
# processing AOI: 0716w-420n
# getting OSM features
# 8440 features from OSM
# 2614 features selected
#
# processing AOI: 0716w-421n
# getting OSM features
# 10662 features from OSM
# 2089 features selected
#
# processing AOI: 0716w-422n
# getting OSM features
# 9472 features from OSM
# 2004 features selected
#
# processing AOI: 0716w-423n
# getting OSM features
# 16924 features from OSM
# 3199 features selected
#
# processing AOI: 0716w-424n
# getting OSM features
# 9875 features from OSM
# 2059 features selected
#
# processing AOI: 0716w-425n
# getting OSM features
# 9561 features from OSM
# 2198 features selected
#
# processing AOI: 0716w-426n
# getting OSM features
# 6846 features from OSM
# 1382 features selected
#
# processing AOI: 0716w-427n
# getting OSM features
# 12221 features from OSM
# 2554 features selected
#
# processing AOI: 0716w-428n
# getting OSM features
# 8323 features from OSM
# 1626 features selected
#
# processing AOI: 0716w-429n
# getting OSM features
# 7967 features from OSM
# 1386 features selected
#
# processing AOI: 0716w-432n
# getting OSM features
# 13488 features from OSM
# 2377 features selected
#
# processing AOI: 0715w-414n
# getting OSM features
# 6821 features from OSM
# 2463 features selected
#
# processing AOI: 0715w-415n
# getting OSM features
# 7694 features from OSM
# 2813 features selected
#
# processing AOI: 0715w-416n
# getting OSM features
# 15856 features from OSM
# 4573 features selected
#
# processing AOI: 0715w-417n
# getting OSM features
# 21851 features from OSM
# 7136 features selected
#
# processing AOI: 0715w-418n
# getting OSM features
# 41081 features from OSM
# 9290 features selected
#
# processing AOI: 0715w-419n
# getting OSM features
# 17738 features from OSM
# 4148 features selected
#
# processing AOI: 0715w-420n
# getting OSM features
# 10900 features from OSM
# 2859 features selected
#
# processing AOI: 0715w-421n
# getting OSM features
# 9821 features from OSM
# 2282 features selected
#
# processing AOI: 0715w-422n
# getting OSM features
# 14715 features from OSM
# 3499 features selected
#
# processing AOI: 0715w-423n
# getting OSM features
# 13420 features from OSM
# 3267 features selected
#
# processing AOI: 0715w-424n
# getting OSM features
# 15046 features from OSM
# 2847 features selected
#
# processing AOI: 0715w-425n
# getting OSM features
# 12158 features from OSM
# 2475 features selected
#
# processing AOI: 0715w-426n
# getting OSM features
# 8771 features from OSM
# 2255 features selected
#
# processing AOI: 0715w-427n
# getting OSM features
# 23096 features from OSM
# 3984 features selected
#
# processing AOI: 0715w-428n
# getting OSM features
# 7784 features from OSM
# 1684 features selected
#
# processing AOI: 0715w-429n
# getting OSM features
# 33693 features from OSM
# 5153 features selected
#
# processing AOI: 0715w-430n
# getting OSM features
# 17841 features from OSM
# 3350 features selected
#
# processing AOI: 0715w-435n
# getting OSM features
# 7291 features from OSM
# 1888 features selected
#
# processing AOI: 0714w-417n
# getting OSM features
# 11994 features from OSM
# 3926 features selected
#
# processing AOI: 0714w-418n
# getting OSM features
# 28807 features from OSM
# 6362 features selected
#
# processing AOI: 0714w-419n
# getting OSM features
# 15578 features from OSM
# 4303 features selected
#
# processing AOI: 0714w-420n
# getting OSM features
# 11064 features from OSM
# 2212 features selected
#
# processing AOI: 0714w-421n
# getting OSM features
# 8714 features from OSM
# 2068 features selected
#
# processing AOI: 0714w-422n
# getting OSM features
# 16700 features from OSM
# 3445 features selected
#
# processing AOI: 0714w-423n
# getting OSM features
# 17457 features from OSM
# 3866 features selected
#
# processing AOI: 0714w-424n
# getting OSM features
# 13980 features from OSM
# 2642 features selected
#
# processing AOI: 0714w-425n
# getting OSM features
# 10602 features from OSM
# 2386 features selected
#
# processing AOI: 0714w-426n
# getting OSM features
# 19173 features from OSM
# 5225 features selected
#
# processing AOI: 0714w-427n
# getting OSM features
# 6119 features from OSM
# 1267 features selected
#
# processing AOI: 0714w-428n
# getting OSM features
# 10117 features from OSM
# 1961 features selected
#
# processing AOI: 0714w-429n
# getting OSM features
# 6575 features from OSM
# 1316 features selected
#
# processing AOI: 0713w-415n
# getting OSM features
# 9432 features from OSM
# 2408 features selected
#
# processing AOI: 0713w-416n
# getting OSM features
# 6972 features from OSM
# 2192 features selected
#
# processing AOI: 0713w-417n
# getting OSM features
# 7988 features from OSM
# 2581 features selected
#
# processing AOI: 0713w-419n
# getting OSM features
# 10527 features from OSM
# 2426 features selected
#
# processing AOI: 0713w-420n
# getting OSM features
# 10825 features from OSM
# 2758 features selected
#
# processing AOI: 0713w-421n
# getting OSM features
# 14115 features from OSM
# 3410 features selected
#
# processing AOI: 0713w-422n
# getting OSM features
# 17162 features from OSM
# 3884 features selected
#
# processing AOI: 0713w-423n
# getting OSM features
# 41238 features from OSM
# 8392 features selected
#
# processing AOI: 0713w-424n
# getting OSM features
# 29323 features from OSM
# 5251 features selected
#
# processing AOI: 0713w-425n
# getting OSM features
# 15284 features from OSM
# 3876 features selected
#
# processing AOI: 0713w-426n
# getting OSM features
# 12480 features from OSM
# 3401 features selected
#
# processing AOI: 0713w-427n
# getting OSM features
# 12379 features from OSM
# 2531 features selected
#
# processing AOI: 0713w-428n
# getting OSM features
# 6950 features from OSM
# 1518 features selected
#
# processing AOI: 0712w-416n
# getting OSM features
# 8788 features from OSM
# 3430 features selected
#
# processing AOI: 0712w-417n
# getting OSM features
# 9886 features from OSM
# 3150 features selected
#
# processing AOI: 0712w-418n
# getting OSM features
# 4742 features from OSM
# 1298 features selected
#
# processing AOI: 0712w-419n
# getting OSM features
# 5817 features from OSM
# 1775 features selected
#
# processing AOI: 0712w-420n
# getting OSM features
# 7485 features from OSM
# 1785 features selected
#
# processing AOI: 0712w-421n
# getting OSM features
# 18108 features from OSM
# 3867 features selected
#
# processing AOI: 0712w-422n
# getting OSM features
# 32489 features from OSM
# 7261 features selected
#
# processing AOI: 0712w-423n
# getting OSM features
# 108420 features from OSM
# 15677 features selected
#
# processing AOI: 0712w-424n
# getting OSM features
# 43820 features from OSM
# 9879 features selected
#
# processing AOI: 0712w-425n
# getting OSM features
# 17687 features from OSM
# 4969 features selected
#
# processing AOI: 0712w-426n
# getting OSM features
# 20884 features from OSM
# 4437 features selected
#
# processing AOI: 0712w-427n
# getting OSM features
# 16857 features from OSM
# 4775 features selected
#
# processing AOI: 0712w-428n
# getting OSM features
# 7671 features from OSM
# 1673 features selected
#
# processing AOI: 0711w-416n
# getting OSM features
# 6017 features from OSM
# 1334 features selected
#
# processing AOI: 0711w-418n
# getting OSM features
# 6789 features from OSM
# 1952 features selected
#
# processing AOI: 0711w-419n
# getting OSM features
# 6298 features from OSM
# 1790 features selected
#
# processing AOI: 0711w-420n
# getting OSM features
# 13533 features from OSM
# 3589 features selected
#
# processing AOI: 0711w-421n
# getting OSM features
# 16815 features from OSM
# 4698 features selected
#
# processing AOI: 0711w-422n
# getting OSM features
# 29088 features from OSM
# 7249 features selected
#
# processing AOI: 0711w-423n
# getting OSM features
# 117656 features from OSM
# 17049 features selected
#
# processing AOI: 0711w-424n
# getting OSM features
# 47918 features from OSM
# 10180 features selected
#
# processing AOI: 0711w-425n
# getting OSM features
# 15616 features from OSM
# 3925 features selected
#
# processing AOI: 0711w-426n
# getting OSM features
# 7458 features from OSM
# 1450 features selected
#
# processing AOI: 0711w-427n
# getting OSM features
# 9900 features from OSM
# 2722 features selected
#
# processing AOI: 0711w-428n
# getting OSM features
# 7044 features from OSM
# 1846 features selected
#
# processing AOI: 0710w-416n
# getting OSM features
# 14941 features from OSM
# 3971 features selected
#
# processing AOI: 0710w-417n
# getting OSM features
# 4921 features from OSM
# 1126 features selected
#
# processing AOI: 0710w-418n
# getting OSM features
# 4828 features from OSM
# 1469 features selected
#
# processing AOI: 0710w-419n
# getting OSM features
# 6236 features from OSM
# 1744 features selected
#
# processing AOI: 0710w-420n
# getting OSM features
# 8169 features from OSM
# 2698 features selected
#
# processing AOI: 0710w-421n
# getting OSM features
# 14745 features from OSM
# 4071 features selected
#
# processing AOI: 0710w-422n
# getting OSM features
# 16108 features from OSM
# 4831 features selected
#
# processing AOI: 0710w-424n
# getting OSM features
# 32255 features from OSM
# 5281 features selected
#
# processing AOI: 0710w-425n
# getting OSM features
# 25577 features from OSM
# 5225 features selected
#
# processing AOI: 0710w-426n
# getting OSM features
# 7163 features from OSM
# 1459 features selected
#
# processing AOI: 0710w-427n
# getting OSM features
# 7890 features from OSM
# 1854 features selected
#
# processing AOI: 0710w-428n
# getting OSM features
# 9357 features from OSM
# 2648 features selected
#
# processing AOI: 0710w-429n
# getting OSM features
# 16321 features from OSM
# 3214 features selected
#
# processing AOI: 0710w-430n
# getting OSM features
# 9559 features from OSM
# 2456 features selected
#
# processing AOI: 0710w-432n
# getting OSM features
# 9517 features from OSM
# 1850 features selected
#
# processing AOI: 0710w-433n
# getting OSM features
# 6649 features from OSM
# 1444 features selected
#
# processing AOI: 0709w-416n
# getting OSM features
# 6196 features from OSM
# 1445 features selected
#
# processing AOI: 0709w-420n
# getting OSM features
# 5668 features from OSM
# 1752 features selected
#
# processing AOI: 0709w-421n
# getting OSM features
# 8966 features from OSM
# 2176 features selected
#
# processing AOI: 0709w-422n
# getting OSM features
# 9274 features from OSM
# 2042 features selected
#
# processing AOI: 0709w-425n
# getting OSM features
# 17662 features from OSM
# 3494 features selected
#
# processing AOI: 0709w-426n
# getting OSM features
# 6962 features from OSM
# 1625 features selected
#
# processing AOI: 0709w-428n
# getting OSM features
# 16893 features from OSM
# 3061 features selected
#
# processing AOI: 0709w-429n
# getting OSM features
# 14258 features from OSM
# 2771 features selected
#
# processing AOI: 0709w-430n
# getting OSM features
# 11373 features from OSM
# 2209 features selected
#
# processing AOI: 0709w-431n
# getting OSM features
# 12103 features from OSM
# 2783 features selected
#
# processing AOI: 0709w-432n
# getting OSM features
# 10556 features from OSM
# 2261 features selected
#
# processing AOI: 0708w-417n
# getting OSM features
# 6175 features from OSM
# 1917 features selected
#
# processing AOI: 0708w-419n
# getting OSM features
# 7652 features from OSM
# 2208 features selected
#
# processing AOI: 0708w-420n
# getting OSM features
# 7040 features from OSM
# 2184 features selected
#
# processing AOI: 0708w-421n
# getting OSM features
# 8169 features from OSM
# 2017 features selected
#
# processing AOI: 0708w-422n
# getting OSM features
# 4469 features from OSM
# 1021 features selected
#
# processing AOI: 0708w-430n
# getting OSM features
# 26174 features from OSM
# 4073 features selected
#
# processing AOI: 0708w-431n
# getting OSM features
# 11075 features from OSM
# 2270 features selected
#
# processing AOI: 0707w-415n
# getting OSM features
# 9459 features from OSM
# 1776 features selected
#
# processing AOI: 0707w-416n
# getting OSM features
# 4895 features from OSM
# 1188 features selected
#
# processing AOI: 0707w-417n
# getting OSM features
# 8726 features from OSM
# 2384 features selected
#
# processing AOI: 0707w-419n
# getting OSM features
# 7637 features from OSM
# 1772 features selected
#
# processing AOI: 0707w-420n
# getting OSM features
# 3688 features from OSM
# 1163 features selected
#
# processing AOI: 0707w-426n
# getting OSM features
# 7626 features from OSM
# 1759 features selected
#
# processing AOI: 0707w-431n
# getting OSM features
# 4499 features from OSM
# 1506 features selected
#
# processing AOI: 0706w-414n
# getting OSM features
# 4504 features from OSM
# 1350 features selected
#
# processing AOI: 0706w-415n
# getting OSM features
# 9018 features from OSM
# 2083 features selected
#
# processing AOI: 0706w-416n
# getting OSM features
# 9675 features from OSM
# 1802 features selected
#
# processing AOI: 0706w-417n
# getting OSM features
# 8323 features from OSM
# 2031 features selected
#
# processing AOI: 0706w-418n
# getting OSM features
# 4304 features from OSM
# 1411 features selected
#
# processing AOI: 0706w-433n
# getting OSM features
# 3974 features from OSM
# 1365 features selected
#
# processing AOI: 0705w-416n
# getting OSM features
# 16583 features from OSM
# 2825 features selected
#
# processing AOI: 0705w-417n
# getting OSM features
# 5500 features from OSM
# 1254 features selected
#
# processing AOI: 0705w-434n
# getting OSM features
# 7135 features from OSM
# 2454 features selected
#
# processing AOI: 0705w-435n
# getting OSM features
# 7530 features from OSM
# 2430 features selected
#
# processing AOI: 0705w-438n
# getting OSM features
# 2745 features from OSM
# 966 features selected
#
# processing AOI: 0704w-416n
# getting OSM features
# 12790 features from OSM
# 2703 features selected
#
# processing AOI: 0704w-435n
# getting OSM features
# 9929 features from OSM
# 3367 features selected
#
# processing AOI: 0704w-436n
# getting OSM features
# 15099 features from OSM
# 4445 features selected
#
# processing AOI: 0704w-437n
# getting OSM features
# 3812 features from OSM
# 1297 features selected
#
# processing AOI: 0703w-416n
# getting OSM features
# 12409 features from OSM
# 3169 features selected
#
# processing AOI: 0703w-436n
# getting OSM features
# 17476 features from OSM
# 4593 features selected
#
# processing AOI: 0703w-437n
# getting OSM features
# 6605 features from OSM
# 1964 features selected
#
# processing AOI: 0703w-440n
# getting OSM features
# 4792 features from OSM
# 1535 features selected
#
# processing AOI: 0702w-416n
# getting OSM features
# 5194 features from OSM
# 1898 features selected
#
# processing AOI: 0702w-417n
# getting OSM features
# 4818 features from OSM
# 1531 features selected
#
# processing AOI: 0702w-440n
# getting OSM features
# 2672 features from OSM
# 968 features selected
#
# processing AOI: 0701w-416n
# getting OSM features
# 4343 features from OSM
# 1838 features selected
#
# processing AOI: 0701w-417n
# getting OSM features
# 6027 features from OSM
# 2040 features selected
#
# processing AOI: 0701w-419n
# getting OSM features
# 3220 features from OSM
# 870 features selected
#
# processing AOI: 0700w-417n
# getting OSM features
# 5532 features from OSM
# 1629 features selected
#
# processing AOI: 0700w-418n
# getting OSM features
# 5515 features from OSM
# 1442 features selected
#
# processing AOI: 0700w-439n
# getting OSM features
# 7028 features from OSM
# 1776 features selected
#
# processing AOI: 0699w-439n
# getting OSM features
# 2650 features from OSM
# 1052 features selected
#
# processing AOI: 0698w-442n
# getting OSM features
# 3883 features from OSM
# 1120 features selected
#
# processing AOI: 0698w-443n
# getting OSM features
# 8647 features from OSM
# 1816 features selected
#
# processing AOI: 0697w-438n
# getting OSM features
# 4385 features from OSM
# 1162 features selected
#
# processing AOI: 0697w-445n
# getting OSM features
# 7481 features from OSM
# 1760 features selected
#
# processing AOI: 0689w-447n
# getting OSM features
# 4333 features from OSM
# 774 features selected
#
# processing AOI: 0688w-447n
# getting OSM features
# 7290 features from OSM
# 1446 features selected
#
# processing AOI: 0688w-448n
# getting OSM features
# 7595 features from OSM
# 1735 features selected
#
# processing AOI: 0687w-449n
# getting OSM features
# 3654 features from OSM
# 902 features selected
# saved tile info in /content/drive/MyDrive/Projects/verge/data/newengland/tile_info.csv

# %%
# for g in tile_gents:
#     print(g['geometry'].bounds)

# %%
# For debugging.

# def pr_feature(f):
#     print('feature')
#     for k in f:
#         if str(f[k]) != 'nan':
#             print('    ', k, f[k])

# def pr_gent(g):
#     for k in g:
#         if k == 'feature':
#             pr_feature(g[k])
#         else:
#             print(k, g[k])
#         geomxy = shapely.ops.transform(proj_inverse, feature['geometry'])

# pr_gent(gents[121])

# %%
pd.DataFrame(gents)[['category', 'label', 'gtype']].value_counts().sort_index()
# Out:
# category  label               gtype
# amenity   commercial          Point             7
#           food and drink      Point             2
#           parking lot         Polygon         210
# landuse   agricultural        Polygon           7
#           forest              Polygon          18
#           industrial          Polygon           6
#           meadow              Polygon           1
#           recreation          Polygon           1
#           residential         Polygon          17
#           retail              Polygon           1
# railway   rail                LineString       30
# route     highway             LineString       35
#           primary road        LineString       43
#           residential road    LineString      362
#           secondary road      LineString       63
#           tertiary road       LineString        8
# waterway  lakes and ponds     Polygon           3
#           land                MultiPolygon      1
#           rivers and streams  LineString       74
#                               Polygon          14
# Name: count, dtype: int64

# %% [markdown]
# ## QA Check

# %%
# # Take a look at the land/water polygons.
# import folium
# center_lon = (lon0 + lon1) / 2.0
# center_lat = (lat0 + lat1) / 2.0

# map_center = [center_lat, center_lon]
# m = folium.Map(location=map_center, zoom_start=10)
# geo_json = folium.GeoJson(landwater)
# geo_json.add_to(m)
# m

# %%
# import folium
# center_lon = (lon0 + lon1) / 2.0
# center_lat = (lat0 + lat1) / 2.0

# map_center = [center_lat, center_lon]
# m = folium.Map(location=map_center, zoom_start=10)
# for gent in tile_gents:
#     g0 = gent['geometry']
#     g1 = shapely.affinity.translate(g0, xoff=gent['xoff'], yoff=gent['yoff'])
#     g2 = shapely.ops.transform(proj_inverse, g1)
#     geo_json = folium.GeoJson(g2)
#     geo_json.add_to(m)
# m
