# %% [markdown]
# ### VERGE: Vector-mode Regional Geospatial Embeddings
#
# # Assemble geographical data for the VERGE project
#
# This notebook pulls and organizes the geospatial data that we will use in this effort.
#
# We have a list of AOIs, defined as lon/lat bounding boxes. Here we pull data for each one,
# and divide it up into tiles of a given size.
#
# ## Outputs
# * [roi_name]/tiles/[aoi_tag]/[tile_tag].pq: geo data for a tile

# %% [markdown]
# ## Processing setup

# %%
# Google colab setup
import os
from google.colab import drive
drive.mount('/content/drive')
project_home = '/content/drive/MyDrive/Projects/verge'
os.chdir(project_home)
# !pip install osmnx pygeohash geo-encodings
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: osmnx in /usr/local/lib/python3.11/dist-packages (2.0.6)
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: geo-encodings in /usr/local/lib/python3.11/dist-packages (1.0.4)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from geo-encodings) (1.16.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)

# %%
# # Local processing setup
# project_home = '..'

# %% [markdown]
# ## Notebook setup

# %%
import numpy as np
import pandas as pd
import pyproj
import shapely
import osmnx
import pygeohash
import geopandas as gpd
import os
import copy
import json

import plotly
from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter

from geo_encodings import draw_shape

import sys
sys.path.append(project_home)
from utils.verge import rules

# %% [markdown]
# ## Parameters

# %%
# The name of the ROI to use.
roi_name = 'newengland'

# The name of the general-purpose data directory.
data_home = '%s/data' % (project_home)

# The name of the ROI-specific data directory.
roi_home = '%s/data/%s' % (project_home, roi_name)

# A tile has to contain this many entities in order to be retained.
min_entity_count = 20

# Set to True if we want to include the overall land/water polygon for each tile.
include_land_water = True

# If not None, then only process this many AOIs
aoi_limit = None

# %% [markdown]
# ## Preliminaries

# %%
# Read the ROI definition.
fname = '%s/roi.json' % roi_home
with open(fname) as source:
    roi = json.load(source)

tile_size = roi['tile_size']
tile_shift = roi['tile_shift']
encoding_resolution = roi['encoding_resolution']

# %%
# Define a local map projection, using the definition from the ROI file.
def get_projections(proj_def):
    ltm_crs = pyproj.CRS.from_proj4(proj_def)
    wgs84_crs = pyproj.CRS.from_epsg(4326)
    proj_forward = pyproj.Transformer.from_crs(wgs84_crs, ltm_crs, always_xy=True).transform
    proj_inverse = pyproj.Transformer.from_crs(ltm_crs, wgs84_crs, always_xy=True).transform
    return proj_forward, proj_inverse

proj_forward, proj_inverse = get_projections(roi['proj_def'])

# %%
# This function gets an overall land/water polygon for an AOI.
# It does it by conasidering both the "coastlines" shapefile
# and all polygonal water features.

# Read the coastline file.
if include_land_water:
    fname = '%s/coastlines' % (roi_home)
    coastlines_gdf = gpd.read_file(fname)
    print('%d coastline polygons' % len(coastlines_gdf))

def get_land_water(bounds, features):

    # Create a baseline polygon consisting of the whole AOI.
    landwater = copy.deepcopy(bounds)

    # Intersect that with the coastlines data.
    coastlines = shapely.union_all(coastlines_gdf['geometry'].values)
    landwater = landwater.intersection(coastlines)

    # subtract out any polygonal water feature.
    for _, f in features.iterrows():
        if f['geometry'].geom_type in ['Polygon', 'MultiPolygon']:
            if f['natural'] == 'water':
                landwater = shapely.difference(landwater, f['geometry'])

    return landwater
# Out:
# 3514 coastline polygons

# %% [markdown]
# ## Processing

# %%
# Read the file with the list of AOIs
fname = '%s/aois.csv' % (roi_home)
aois = pd.read_csv(fname).to_dict('records')
# aois = np.random.permutation(aois)
print('%d areas of interest' % len(aois))
# Out:
# 263 areas of interest

# %%
aois[0]
# Out:
# {'aoi_tag': '0735w-413n',
#  'lon0': -73.5,
#  'lat0': 41.3,
#  'lon1': -73.4,
#  'lat1': 41.4}

# %%
# This will save some extra info that we will need.
tile_info = []

if aoi_limit is None:
    aoi_list = aois
else:
    aoi_list = aois[:aoi_limit]

for k, aoi in enumerate(aoi_list):

    print('\nprocessing AOI %s (%d / %d)' % (aoi['aoi_tag'], k, len(aoi_list)))

    # Use that projection to define lon/lat bounds for the query below. Make sure the bounds go
    # a little farther out than necessary to avoid edge artifacts from map projections.
    buffer = 0.01
    lon0 = aoi['lon0'] - buffer
    lat0 = aoi['lat0'] - buffer
    lon1 = aoi['lon1'] + buffer
    lat1 = aoi['lat1'] + buffer
    query_bounds = [lon0, lat0, lon1, lat1]

    # print('re-projected query bounds, with buffer:')
    # print(proj_forward(lon0, lat0))
    # print(proj_forward(lon1, lat1))

    # Query for all the geospatial entities we need within the bounding box.
    tags = {
        'landuse': True,
        'place': True,
        'highway': True,
        'railway': True,
        #'aeroway': True,
        'bridge': True,
        'tunnel': True,
        #'power': True,
        'natural': True,
        'waterway': True,
        'landcover': True,
        #'building': True,
        'amenity': True,
        'shop': True,
        'leisure': True
    }
    features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
    print('%d features from OSM' % len(features))

    # Re-format and filter everything.
    # BTW, "gents" is "geospatial entities".
    gents = []
    for feature in features.to_dict('records'):

        geomxy = shapely.ops.transform(proj_forward, feature['geometry'])
        if geomxy.is_empty:
            continue
        gtype = geomxy.geom_type

        for rule in rules:
            if gtype == rule['gtype']:
                osm_key = rule['osm_key']
                if osm_key in feature:
                    osm_value = str(feature[osm_key])
                    if osm_value in rule['osm_values']:
                        gents.append({
                            'feature': feature,
                            'category': rule['gent_category'],
                            'label': rule['gent_label'],
                            'geomxy': geomxy,
                            'gtype': gtype
                        })
    print('%d features selected' % len(gents))

    # We need some special handling to create a general "land/water" polygon.
    if include_land_water:
        lons = [lon0, lon1, lon1, lon0, lon0]
        lats = [lat0, lat0, lat1, lat1, lat0]
        lonlat_bounds = shapely.Polygon(list(zip(lons, lats)))
        landwater = get_land_water(lonlat_bounds, features)
        landwaterxy = shapely.ops.transform(proj_forward, landwater)
        gents.append({
            'category': 'waterway',
            'label': 'land',
            'geomxy': landwaterxy,
            'gtype': landwaterxy.geom_type
        })

    # Determine the AOI bounds in projected coordinates.
    aoi_x0, aoi_y0 = proj_forward(aoi['lon0'], aoi['lat0'])
    aoi_x1, aoi_y1 = proj_forward(aoi['lon1'], aoi['lat1'])

    # Loop over tiles within this AOI.
    x0 = aoi_x0
    while x0 + tile_size < aoi_x1:

        y0 = aoi_y0
        while y0 + tile_size < aoi_y1:

            # print('tile xo, yo:', x0, y0)

            # Figure out the lon/lat center of this tile. We will need it
            # for some later processing.
            tile_lon0, tile_lat0 = proj_inverse(x0, y0)
            tile_lon1, tile_lat1 = proj_inverse(x0 + tile_size, y0 + tile_size)
            tile_lon_center = (tile_lon0 + tile_lon1) / 2
            tile_lat_center = (tile_lat0 + tile_lat1) / 2
            # xc = x0 + tile_size / 2
            # yc = y0 + tile_size / 2
            # tile_lon, tile_lat = proj_inverse(xc, yc)
            # print('tile lon, lat', tile_lon, tile_lat)

            # Define a bounding box in projected coordinates. It will be used
            # to clip geospatial entities below.
            x1 = x0 + tile_size
            y1 = y0 + tile_size
            xx = [x0, x1, x1, x0, x0]
            yy = [y0, y0, y1, y1, y0]
            tile_bbox = shapely.Polygon(list(zip(xx, yy)))

            tile_gents = []
            for gent in gents:
                geomxy = shapely.affinity.translate(
                    gent['geomxy'].intersection(tile_bbox),
                    xoff=-x0, yoff=-y0
                )
                if geomxy.is_empty:
                    continue
                tile_gents.append({
                    'category': gent['category'],
                    'label': gent['label'],
                    'geometry': geomxy,
                    'gtype': gent['gtype'],
                    'xoff': x0,
                    'yoff': y0,
                })
            # print('%d geospatial entities' % len(tile_gents))

            # Save that if it's big enough.
            if len(tile_gents) >= min_entity_count:
                tx = '%03d' % (x0 / tile_shift)
                ty = '%03d' % (y0 / tile_shift)
                tile_tag = '%s-%s' % (tx, ty)
                fname = '%s/tiles/%s/%s.pq' % (roi_home, aoi['aoi_tag'], tile_tag)
                os.makedirs(os.path.dirname(fname), exist_ok=True)
                gdf = gpd.GeoDataFrame(tile_gents).drop_duplicates()
                gdf.to_parquet(fname, index=False, compression="zstd")
                print('saved %s (%4d entities)' % (fname, len(gdf)))

                # Save the tile info.
                tile_info.append({
                    'aoi_tag': aoi['aoi_tag'],
                    'tile_tag': tile_tag,
                    'lon0': tile_lon0,
                    'lat0': tile_lat0,
                    'lon1': tile_lon1,
                    'lat1': tile_lat1,
                    'center_lon': tile_lon_center,
                    'center_lat': tile_lat_center,
                })

            y0 += tile_shift
        x0 += tile_shift

# Save the tile info.
fname = '%s/tiles.csv' % roi_home
pd.DataFrame(tile_info).to_csv(fname, index=False)
print('\nsaved tile info in %s' % fname)
# Out:
# processing AOI 0735w-413n (0 / 263)
# 11946 features from OSM
# 3258 features selected
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-005.pq (  71 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-006.pq (  57 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-007.pq (  68 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-008.pq (  87 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-009.pq (  48 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-010.pq (  23 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-011.pq (  53 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-012.pq ( 130 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/005-013.pq ( 210 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-005.pq (  81 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-006.pq (  64 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-007.pq (  53 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-008.pq (  45 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-009.pq (  31 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-010.pq (  26 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-011.pq (  62 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-012.pq ( 176 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/006-013.pq ( 274 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-005.pq (  65 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-006.pq (  44 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-007.pq (  41 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-008.pq (  35 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-009.pq (  44 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-010.pq (  38 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-011.pq (  53 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-012.pq ( 143 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/007-013.pq ( 246 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-005.pq (  64 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-006.pq (  41 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-007.pq (  47 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-008.pq (  43 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-009.pq (  44 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-010.pq (  49 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-011.pq (  28 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-012.pq (  64 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/008-013.pq ( 247 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-005.pq (  52 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-006.pq (  66 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-007.pq (  79 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-008.pq (  47 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-009.pq (  27 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-010.pq (  40 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-011.pq (  41 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-012.pq (  87 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/009-013.pq ( 253 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/010-005.pq (  23 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n/010-006.pq (  68 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0735w-413n
entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/027-120.pq (  69 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/027-121.pq (  62 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/027-122.pq (  37 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/027-123.pq (  29 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-115.pq ( 128 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-116.pq (  87 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-117.pq (  71 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-118.pq (  68 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-119.pq (  74 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-120.pq (  57 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-121.pq (  34 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-122.pq (  26 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/028-123.pq (  21 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/029-115.pq (  94 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/029-116.pq (  74 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/029-117.pq (  72 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/029-118.pq (  54 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/029-119.pq (  52 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/029-120.pq (  40 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/030-115.pq (  25 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/030-116.pq (  35 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-423n/030-117.pq (  29 entities)
#
# processing AOI 0733w-424n (8 / 263)
# 5875 features from OSM
# 2192 features selected
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-424n/026-128.pq (  25 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0733w-424n/026-129.pq (  79 entities)
# ...
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/086-108.pq (  74 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/086-109.pq (  47 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/086-110.pq (  48 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/086-111.pq (  43 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-103.pq (  38 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-104.pq (  39 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-105.pq (  43 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-106.pq (  48 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-107.pq (  76 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-108.pq (  62 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-109.pq (  21 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-110.pq (  29 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/087-111.pq (  53 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-104.pq (  43 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-105.pq (  41 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-106.pq (  28 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-107.pq (  42 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-108.pq (  47 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-109.pq (  32 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-110.pq (  30 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/088-111.pq (  47 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-103.pq (  21 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-104.pq (  23 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-107.pq (  20 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-108.pq (  32 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-109.pq (  30 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-110.pq (  36 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-422n/089-111.pq (  32 entities)
#
# processing AOI 0726w-423n (60 / 263)
# 13449 features from OSM
# 2446 features selected
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-114.pq (  35 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-115.pq (  34 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-116.pq (  65 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-117.pq ( 142 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-118.pq ( 128 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-119.pq (  65 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-120.pq (  59 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-121.pq (  57 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/083-122.pq (  52 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-114.pq (  32 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-115.pq (  38 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-116.pq (  62 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-117.pq ( 105 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-118.pq ( 117 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-119.pq (  94 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-120.pq (  56 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-121.pq (  40 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/084-122.pq (  34 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-115.pq (  36 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-116.pq (  53 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-117.pq (  61 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-118.pq ( 113 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-119.pq ( 122 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-120.pq (  76 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-121.pq (  46 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/085-122.pq (  28 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-115.pq (  38 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-116.pq (  58 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-117.pq (  59 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-118.pq (  89 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-119.pq ( 154 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-120.pq ( 142 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-121.pq (  67 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/086-122.pq (  66 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-114.pq (  43 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-115.pq ( 103 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-116.pq ( 106 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-117.pq (  69 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-118.pq (  89 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-119.pq ( 161 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-120.pq ( 207 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-121.pq ( 188 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/087-122.pq ( 203 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-114.pq (  45 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-115.pq ( 119 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-116.pq ( 117 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-117.pq ( 114 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-118.pq ( 157 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-119.pq ( 124 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-120.pq ( 178 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-121.pq ( 357 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/088-122.pq ( 449 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-114.pq (  21 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-115.pq (  58 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-116.pq (  66 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-117.pq ( 102 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-118.pq ( 133 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-119.pq (  80 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-120.pq ( 109 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-121.pq ( 297 entities)
# saved /content/drive/MyDrive/Projects/verge/data/newengland/tiles/0726w-423n/089-122.pq ( 380 entities)
#
# processing AOI 0726w-442n (61 / 263)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3994735355.py in <cell line: 0>()
#      42         'leisure': True
#      43     }
# ---> 44     features = osmnx.features.features_from_bbox(query_bounds, tags=tags).reset_index()
#      45     print('%d features from OSM' % len(features))
#      46
#
# /usr/local/lib/python3.11/dist-packages/osmnx/features.py in features_from_bbox(bbox, tags)
#     128     # convert bbox to polygon then create GeoDataFrame of features within it
#     129     polygon = utils_geo.bbox_to_poly(bbox)
# --> 130     return features_from_polygon(polygon, tags)
#     131
#     132
#
# /usr/local/lib/python3.11/dist-packages/osmnx/features.py in features_from_polygon(polygon, tags)
#     330     # retrieve the data from Overpass then turn it into a GeoDataFrame
#     331     response_jsons = _overpass._download_overpass_features(polygon, tags)
# --> 332     return _create_gdf(response_jsons, polygon, tags)
#     333
#     334
#
# /usr/local/lib/python3.11/dist-packages/osmnx/features.py in _create_gdf(response_jsons, polygon, tags)
#     404     elements = []
#     405     response_count = 0
# --> 406     for response_json in response_jsons:
#     407         response_count += 1
#     408         if not settings.cache_only_mode:
#
# /usr/local/lib/python3.11/dist-packages/osmnx/_overpass.py in _download_overpass_features(polygon, tags)
#     430     for polygon_coord_str in polygon_coord_strs:
#     431         query_str = _create_overpass_features_query(polygon_coord_str, tags)
# --> 432         yield _overpass_request(OrderedDict(data=query_str))
#     433
#     434
#
# /usr/local/lib/python3.11/dist-packages/osmnx/_overpass.py in _overpass_request(data)
#     458
#     459     # pause then request this URL
# --> 460     pause = _get_overpass_pause(settings.overpass_url)
#     461     hostname = _http._hostname_from_url(url)
#     462     msg = f"Pausing {pause} second(s) before making HTTP POST request to {hostname!r}"
#
# /usr/local/lib/python3.11/dist-packages/osmnx/_overpass.py in _get_overpass_pause(base_endpoint, recursion_pause, default_pause)
#     179     # try to retrieve the URL
#     180     try:
# --> 181         response = requests.get(
#     182             url,
#     183             headers=_http._get_http_headers(),
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Save the tile info.
fname = '%s/tiles.csv' % roi_home
pd.DataFrame(tile_info).to_csv(fname, index=False)
print('\nsaved tile info in %s' % fname)
# Out:
# saved tile info in /content/drive/MyDrive/Projects/verge/data/newengland/tiles.csv

# %%
# for g in tile_gents:
#     print(g['geometry'].bounds)

# %%
# For debugging.

# def pr_feature(f):
#     print('feature')
#     for k in f:
#         if str(f[k]) != 'nan':
#             print('    ', k, f[k])

# def pr_gent(g):
#     for k in g:
#         if k == 'feature':
#             pr_feature(g[k])
#         else:
#             print(k, g[k])
#         geomxy = shapely.ops.transform(proj_inverse, feature['geometry'])

# pr_gent(gents[121])

# %%
pd.DataFrame(gents)[['category', 'label', 'gtype']].value_counts().sort_index()

# %% [markdown]
# ## QA Check

# %%
# # Take a look at the land/water polygons.
# import folium
# center_lon = (lon0 + lon1) / 2.0
# center_lat = (lat0 + lat1) / 2.0

# map_center = [center_lat, center_lon]
# m = folium.Map(location=map_center, zoom_start=10)
# geo_json = folium.GeoJson(landwater)
# geo_json.add_to(m)
# m

# %%
# import folium
# center_lon = (lon0 + lon1) / 2.0
# center_lat = (lat0 + lat1) / 2.0

# map_center = [center_lat, center_lon]
# m = folium.Map(location=map_center, zoom_start=10)
# for gent in tile_gents:
#     g0 = gent['geometry']
#     g1 = shapely.affinity.translate(g0, xoff=gent['xoff'], yoff=gent['yoff'])
#     g2 = shapely.ops.transform(proj_inverse, g1)
#     geo_json = folium.GeoJson(g2)
#     geo_json.add_to(m)
# m
